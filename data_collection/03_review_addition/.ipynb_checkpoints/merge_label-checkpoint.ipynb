# %%
file_name="02+03_341dataset_clean" # ชื่อไฟล์คลังข้อมูล

# %%
import codecs
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from nltk.tokenize import RegexpTokenizer
import glob
import nltk
import re
import warnings
warnings.filterwarnings('ignore')

# %%
#จัดการประโยคซ้ำ
data_not=[]
def Unique(p):
 text=re.sub("<[^>]*>","",p)
 text=re.sub("\[(.*?)\]","",text)
 text=re.sub("\[\/(.*?)\]","",text)
 if text not in data_not:
  data_not.append(text)
  return True
 else:
  return False
# เตรียมตัวตัด tag ด้วย re
pattern = r'\[(.*?)\](.*?)\[\/(.*?)\]'
tokenizer = RegexpTokenizer(pattern) # ใช้ nltk.tokenize.RegexpTokenizer เพื่อตัด [TIME]8.00[/TIME] ให้เป็น ('TIME','ไง','TIME')
# จัดการกับ tag ที่ไม่ได้ tag
def toolner_to_tag(text):
 text=text.strip()
 text=re.sub("<[^>]*>","",text)
 text=re.sub("(\[\/(.*?)\])","\\1***",text)#.replace('(\[(.*?)\])','***\\1')#  ตัดการกับพวกไม่มี tag word
 text=re.sub("(\[\w+\])","***\\1",text)
 text2=[]
 for i in text.split('***'):
  if "[" in i:
   text2.append(i)
  else:
   text2.append("[word]"+i+"[/word]")
 text="".join(text2)#re.sub("[word][/word]","","".join(text2))
 return text.replace("[word][/word]","")
# แปลง text ให้เป็น conll2002
def text2conll2002(text,pos=True):
    """
    ใช้แปลงข้อความให้กลายเป็น conll2002
    """
    text=toolner_to_tag(text) # นำไปใส่ tag [word]
    text=text.replace("''",'"')
    text=text.replace("’",'"').replace("‘",'"')#.replace('"',"")
    tag=tokenizer.tokenize(text) # แยก tag ออกมาจากข้อความ
    j=0
    conll2002="" # ประกาศตัวแปรเก็บ conll2002
    for tagopen,text,tagclose in tag: # ลูปใน tag โดยเป็น (tagopen,text,tagclose)
        word_cut=word_tokenize(text,engine="newmm") # ใช้ตัวตัดคำ newmm ของ PyThaiNLP
        i=0
        txt5=""
        while i<len(word_cut): #ลูปตามจำนวน token ที่ตัดในtag
            if word_cut[i]=="''" or word_cut[i]=='"':pass
            elif i==0 and tagopen!='word': # ไม่เป็น tag [word] และเป็น i หรือตัวเริ่มต้น tag
                txt5+=word_cut[i]
                txt5+='\t'+'B-'+tagopen
            elif tagopen!='word':
                txt5+=word_cut[i]
                txt5+='\t'+'I-'+tagopen
            else: # เป็น [word]
                txt5+=word_cut[i]
                txt5+='\t'+'O'
            txt5+='\n'
            #j+=1
            i+=1
        conll2002+=txt5
    if pos==False:
        return conll2002
    return postag(conll2002) # เพิ่ม postag ใส่
# ใช้สำหรับกำกับ pos tag เพื่อใช้กับ NER
# print(text2conll2002(t,pos=False))
def postag(text):
    listtxt=[i for i in text.split('\n') if i!='']
    list_word=[]
    for data in listtxt:
        list_word.append(data.split('\t')[0])
    #print(text)
    list_word=pos_tag(list_word,engine="perceptron")
    text=""
    i=0
    for data in listtxt:
        text+=data.split('\t')[0]+'\t'+list_word[i][1]+'\t'+data.split('\t')[1]+'\n'
        i+=1
    return text
# อ่านข้อมูลจากไฟล์
def get_data(fileopen):
	"""
    สำหรับใช้อ่านทั้งหมดทั้งในไฟล์ทีละรรทัดออกมาเป็น list
    """
	with codecs.open(fileopen, 'r',encoding='utf-8-sig') as f:
		lines = f.read().splitlines()
	return [a for a in lines if Unique(a)] # เอาไม่ซ้ำกัน

def alldata(lists):
    text=""
    for data in lists:
        text+=text2conll2002(data)
        text+='\n'
    return text

def alldata_list(lists):
    data_all=[]
    for data in lists:
        data_num=[]
        try:
            txt=text2conll2002(data,pos=True).split('\n') # นำไปแปลงเป็น conll2002
            for d in txt:
                tt=d.split('\t')
                if d!="":
                    if len(tt)==3:
                        data_num.append((tt[0],tt[1],tt[2]))
                    else:
                        data_num.append((tt[0],tt[1]))
            #print(data_num)
            data_all.append(data_num)
        except:
            print(data)
    #print(data_all)
    return data_all

def alldata_list_str(lists):
	string=""
	for data in lists:
		string1=""
		for j in data:
			string1+=j[0]+"	"+j[1]+"	"+j[2]+"\n"
		string1+="\n"
		string+=string1
	return string

def get_data_tag(listd):
	list_all=[]
	c=[]
	for i in listd:
		if i !='':
			c.append((i.split("\t")[0],i.split("\t")[1],i.split("\t")[2]))
		else:
			list_all.append(c)
			c=[]
	return list_all
def getall(lista):
    ll=[]
    for i in lista:
        o=True
        for j in ll:
            if re.sub("\[(.*?)\]","",i)==re.sub("\[(.*?)\]","",j):
                o=False
                break
        if o==True:
            ll.append(i)
    return ll

# %%
data1=getall(get_data(file_name+".txt")) # นำคลังเข้าไป แยกออกเป็น list ละบรรทัด
datatofile=alldata_list(data1) # นำไปผ่านขั้นตอน 1 2 3 4
tt=[]

# %%
datatofile[0][:10]
# Out:
# [('มา', 'XVAE', 'O'),
#  ('แย้', 'VACT', 'O'),
#  ('วววววววววววววววววววววว', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('รีวิว', 'NCMN', 'O'),
#  ('ง่ายๆ', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เห็นภาพ', 'NCMN', 'O'),
#  ('สดๆ', 'VSTA', 'O')]

# %%
len(datatofile)
# Out:
# 265

# %%
from sklearn_crfsuite import scorers,metrics
from sklearn.metrics import make_scorer, confusion_matrix, classification_report, accuracy_score, make_scorer
from sklearn.model_selection import cross_validate,train_test_split, KFold, StratifiedKFold, cross_val_predict, cross_val_score
import sklearn_crfsuite

# %%
def doc2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
    # Features from current word
    features={
        'word.word': word,
        'word.isspace':word.isspace(),
        'postag':postag,
        'word.isdigit()': word.isdigit()
    }
    if i > 0:
        prevword = doc[i-1][0]
        postag1 = doc[i-1][1]
        features['word.prevword'] = prevword
        features['word.previsspace']=prevword.isspace()
        features['word.prepostag'] = postag1
        features['word.prevwordisdigit'] = prevword.isdigit()
    else:
        features['BOS'] = True # Special "Beginning of Sequence" tag
    # Features from next word
    if i < len(doc)-1:
        nextword = doc[i+1][0]
        postag1 = doc[i+1][1]
        features['word.nextword'] = nextword
        features['word.nextisspace']=nextword.isspace()
        features['word.nextpostag'] = postag1
        features['word.nextwordisdigit'] = nextword.isdigit()
    else:
        features['EOS'] = True # Special "End of Sequence" tag
    return features

def extract_features(doc):
    return [doc2features(doc, i) for i in range(len(doc))]

def get_labels(doc):
    return [tag for (token,postag,tag) in doc]

# %% [markdown]
# # Create features

# %%
X_data = [extract_features(doc) for doc in datatofile] 
y_data = [get_labels(doc) for doc in datatofile]
# print(X_data[0][:5])
# print(y_data[0][:20])

# %%
X_data[0] #token features ของกระทู้ที่ 1
# Out:
# [{'word.word': 'มา',
#   'word.isspace': False,
#   'postag': 'XVAE',
#   'word.isdigit()': False,
#   'BOS': True,
#   'word.nextword': 'แย้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แย้',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'มา',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'วววววววววววววววววววววว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'วววววววววววววววววววววว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'แย้',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'วววววววววววววววววววววว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กับ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'รีวิว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'รีวิว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'กับ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ง่ายๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VATT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ง่ายๆ',
#   'word.isspace': False,
#   'postag': 'VATT',
#   'word.isdigit()': False,
#   'word.prevword': 'รีวิว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ง่ายๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'VATT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เห็นภาพ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เห็นภาพ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สดๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สดๆ',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'เห็นภาพ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กับ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'สดๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กล้อง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กล้อง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'กับ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'โทรศัพท์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'โทรศัพท์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'กล้อง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ธรรมดาๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ธรรมดาๆ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'โทรศัพท์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นี่แหละ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นี่แหละ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ธรรมดาๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ครับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ครับ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'นี่แหละ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': '   ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': '   ',
#   'word.isspace': True,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ครับ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': '3',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCNM',
#   'word.nextwordisdigit': True},
#  {'word.word': '3',
#   'word.isspace': False,
#   'postag': 'NCNM',
#   'word.isdigit()': True,
#   'word.prevword': '   ',
#   'word.previsspace': True,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '3',
#   'word.previsspace': False,
#   'word.prepostag': 'NCNM',
#   'word.prevwordisdigit': True,
#   'word.nextword': '-',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': '-',
#   'word.isspace': False,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '-',
#   'word.previsspace': False,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': '4',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DCNM',
#   'word.nextwordisdigit': True},
#  {'word.word': '4',
#   'word.isspace': False,
#   'postag': 'DCNM',
#   'word.isdigit()': True,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '4',
#   'word.previsspace': False,
#   'word.prepostag': 'DCNM',
#   'word.prevwordisdigit': True,
#   'word.nextword': 'FEB',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'FEB',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': '.',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': '.',
#   'word.isspace': False,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'FEB',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '.',
#   'word.previsspace': False,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': '2018',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCNM',
#   'word.nextwordisdigit': True},
#  {'word.word': '2018',
#   'word.isspace': False,
#   'postag': 'NCNM',
#   'word.isdigit()': True,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': '   ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': '   ',
#   'word.isspace': True,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': '2018',
#   'word.previsspace': False,
#   'word.prepostag': 'NCNM',
#   'word.prevwordisdigit': True,
#   'word.nextword': 'มา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'มา',
#   'word.isspace': False,
#   'postag': 'XVAM',
#   'word.isdigit()': False,
#   'word.prevword': '   ',
#   'word.previsspace': True,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เริ่ม',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เริ่ม',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'มา',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กัน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'ADVN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กัน',
#   'word.isspace': False,
#   'postag': 'ADVN',
#   'word.isdigit()': False,
#   'word.prevword': 'เริ่ม',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เลย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เลย',
#   'word.isspace': False,
#   'postag': 'XVAE',
#   'word.isdigit()': False,
#   'word.prevword': 'กัน',
#   'word.previsspace': False,
#   'word.prepostag': 'ADVN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'โจทย์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'โจทย์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'เลย',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใน',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'โจทย์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ทริป',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ทริป',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใน',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นี้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DDAC',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นี้',
#   'word.isspace': False,
#   'postag': 'DDAC',
#   'word.isdigit()': False,
#   'word.prevword': 'ทริป',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ขอ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ขอ',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'นี้',
#   'word.previsspace': False,
#   'word.prepostag': 'DDAC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'บรรยากาศ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'บรรยากาศ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ขอ',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แบบ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แบบ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'บรรยากาศ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ฟินๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ฟินๆ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'แบบ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นั่ง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นั่ง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ฟินๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แช่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แช่',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'นั่ง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สระน้ำ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สระน้ำ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'แช่',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'สระน้ำ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'มอง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'มอง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'วิว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'วิว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'มอง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ทะเล',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ทะเล',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'วิว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ทะเล',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ที่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PREL',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ที่',
#   'word.isspace': False,
#   'postag': 'PREL',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ลอง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVMM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ลอง',
#   'word.isspace': False,
#   'postag': 'XVMM',
#   'word.isdigit()': False,
#   'word.prevword': 'ที่',
#   'word.previsspace': False,
#   'word.prepostag': 'PREL',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'หา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'หา',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'ลอง',
#   'word.previsspace': False,
#   'word.prepostag': 'XVMM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ๆ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'หา',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ดู',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ดู',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'ๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ราคาแพง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ราคาแพง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ดู',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ๆ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ราคาแพง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ทั้ง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DDBQ',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ทั้ง',
#   'word.isspace': False,
#   'postag': 'DDBQ',
#   'word.isdigit()': False,
#   'word.prevword': 'ๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'น้านนนนนน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'น้านนนนนน',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ทั้ง',
#   'word.previsspace': False,
#   'word.prepostag': 'DDBQ',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'น',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'น',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'น้านนนนนน',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'น',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แต่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JCRG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แต่',
#   'word.isspace': False,
#   'postag': 'JCRG',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สุดท้าย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DONM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สุดท้าย',
#   'word.isspace': False,
#   'postag': 'DONM',
#   'word.isdigit()': False,
#   'word.prevword': 'แต่',
#   'word.previsspace': False,
#   'word.prepostag': 'JCRG',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'มา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'มา',
#   'word.isspace': False,
#   'postag': 'XVAE',
#   'word.isdigit()': False,
#   'word.prevword': 'สุดท้าย',
#   'word.previsspace': False,
#   'word.prepostag': 'DONM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'จบ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'จบ',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'มา',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ที่นี่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ที่นี่',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'จบ',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': '  ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': '  ',
#   'word.isspace': True,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ที่นี่',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ซัน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ซัน',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': '  ',
#   'word.previsspace': True,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไช',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไช',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ซัน',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'น์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'น์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ไช',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'น์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'พาราไดซ์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'พาราไดซ์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'พาราไดซ์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'รีสอร์ต',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'รีสอร์ต',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': '  ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': '  ',
#   'word.isspace': True,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'รีสอร์ต',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': '(',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': '(',
#   'word.isspace': False,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '  ',
#   'word.previsspace': True,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Sunshine',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Sunshine',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': '(',
#   'word.previsspace': False,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Sunshine',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Paradise',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Paradise',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Paradise',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Resort',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Resort',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ')',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ')',
#   'word.isspace': False,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Resort',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': ')',
#   'word.previsspace': False,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ห้อง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ห้อง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แบบ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แบบ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ห้อง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'แบบ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Beachfront',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Beachfront',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Beachfront',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Pool',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Pool',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Pool',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'Villa',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'Villa',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'Villa',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'การ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'FIXN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'การ',
#   'word.isspace': False,
#   'postag': 'FIXN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เดินทาง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เดินทาง',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'การ',
#   'word.previsspace': False,
#   'word.prepostag': 'FIXN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'เดินทาง',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใช้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใช้',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ถนน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ถนน',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใช้',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เพชรเกษม',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เพชรเกษม',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ถนน',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เลย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เลย',
#   'word.isspace': False,
#   'postag': 'XVAE',
#   'word.isdigit()': False,
#   'word.prevword': 'เพชรเกษม',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ตัวเมือง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ตัวเมือง',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'เลย',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAE',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ตัวเมือง',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ทับสะแก',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ทับสะแก',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ทับสะแก',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'จังหวัด',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'จังหวัด',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ประจวบคีรีขันธ์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ประจวบคีรีขันธ์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'จังหวัด',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ประจวบคีรีขันธ์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ระยะทาง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ระยะทาง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'อาจจะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVMM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'อาจจะ',
#   'word.isspace': False,
#   'postag': 'XVMM',
#   'word.isdigit()': False,
#   'word.prevword': 'ระยะทาง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไกล',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไกล',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'อาจจะ',
#   'word.previsspace': False,
#   'word.prepostag': 'XVMM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'หน่อย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'หน่อย',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ไกล',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'หน่อย',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แต่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JCRG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แต่',
#   'word.isspace': False,
#   'postag': 'JCRG',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไม่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NEG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไม่',
#   'word.isspace': False,
#   'postag': 'NEG',
#   'word.isdigit()': False,
#   'word.prevword': 'แต่',
#   'word.previsspace': False,
#   'word.prepostag': 'JCRG',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใช่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใช่',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'ไม่',
#   'word.previsspace': False,
#   'word.prepostag': 'NEG',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'อุปสรรค',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'อุปสรรค',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใช่',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใน',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'อุปสรรค',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'การเที่ยว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'การเที่ยว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใน',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ของ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ของ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'การเที่ยว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ผม',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PPRS',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ผม',
#   'word.isspace': False,
#   'postag': 'PPRS',
#   'word.isdigit()': False,
#   'word.prevword': 'ของ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ครับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ครับ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'ผม',
#   'word.previsspace': False,
#   'word.prepostag': 'PPRS',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ครับ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใช้เวลา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใช้เวลา',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เดินทาง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เดินทาง',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'ใช้เวลา',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ประ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ประ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'เดินทาง',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'มาน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'มาน',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ประ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'มาน',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': '4.5',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DCNM',
#   'word.nextwordisdigit': False},
#  {'word.word': '4.5',
#   'word.isspace': False,
#   'postag': 'DCNM',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': '4.5',
#   'word.previsspace': False,
#   'word.prepostag': 'DCNM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ชม.',
#   'word.nextisspace': False,
#   'word.nextpostag': 'CMTR',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ชม.',
#   'word.isspace': False,
#   'postag': 'CMTR',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ชม.',
#   'word.previsspace': False,
#   'word.prepostag': 'CMTR',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'จาก',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'จาก',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ฟิวเจอร์',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ฟิวเจอร์',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'จาก',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'พาร์ค',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'พาร์ค',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ฟิวเจอร์',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'รังสิต',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'รังสิต',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'พาร์ค',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'รังสิต',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ออกเดินทาง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ออกเดินทาง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เช้า',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VATT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เช้า',
#   'word.isspace': False,
#   'postag': 'VATT',
#   'word.isdigit()': False,
#   'word.prevword': 'ออกเดินทาง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ๆ',
#   'word.isspace': False,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'เช้า',
#   'word.previsspace': False,
#   'word.prepostag': 'VATT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แวะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แวะ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เที่ยว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เที่ยว',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'แวะ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ชะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ชะ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'เที่ยว',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'อำ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'อำ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ชะ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'อำ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กับ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'อ่าว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'อ่าว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'กับ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'มะนาว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'มะนาว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'อ่าว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ได้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ได้',
#   'word.isspace': False,
#   'postag': 'XVAM',
#   'word.isdigit()': False,
#   'word.prevword': 'มะนาว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แบบ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แบบ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ได้',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ชิวๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
# ...
#   'word.prevword': 'นะ',
#   'word.previsspace': False,
#   'word.prepostag': 'ADVN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แต่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JCRG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แต่',
#   'word.isspace': False,
#   'postag': 'JCRG',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ก็',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JSBR',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ก็',
#   'word.isspace': False,
#   'postag': 'JSBR',
#   'word.isdigit()': False,
#   'word.prevword': 'แต่',
#   'word.previsspace': False,
#   'word.prepostag': 'JCRG',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นะ',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'ก็',
#   'word.previsspace': False,
#   'word.prepostag': 'JSBR',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ครับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ครับ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'นะ',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ครับ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นานๆ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นานๆ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ที',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DONM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ที',
#   'word.isspace': False,
#   'postag': 'DONM',
#   'word.isdigit()': False,
#   'word.prevword': 'นานๆ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ที',
#   'word.previsspace': False,
#   'word.prepostag': 'DONM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เรา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PPRS',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เรา',
#   'word.isspace': False,
#   'postag': 'PPRS',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ต้อง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVMM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ต้อง',
#   'word.isspace': False,
#   'postag': 'XVMM',
#   'word.isdigit()': False,
#   'word.prevword': 'เรา',
#   'word.previsspace': False,
#   'word.prepostag': 'PPRS',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใช้ชีวิต',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใช้ชีวิต',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'ต้อง',
#   'word.previsspace': False,
#   'word.prepostag': 'XVMM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ให้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JSBR',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ให้',
#   'word.isspace': False,
#   'postag': 'JSBR',
#   'word.isdigit()': False,
#   'word.prevword': 'ใช้ชีวิต',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'คุ้มค่า',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'คุ้มค่า',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'ให้',
#   'word.previsspace': False,
#   'word.prepostag': 'JSBR',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'คุ้มค่า',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สนุก',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สนุก',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'กับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'กับ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'สนุก',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'การท่องเที่ยว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'การท่องเที่ยว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'กับ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใน',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'การท่องเที่ยว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'แบบฉบับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'แบบฉบับ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใน',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ของ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ของ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'แบบฉบับ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เรา',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PPRS',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เรา',
#   'word.isspace': False,
#   'postag': 'PPRS',
#   'word.isdigit()': False,
#   'word.prevword': 'ของ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เอง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'PDMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เอง',
#   'word.isspace': False,
#   'postag': 'PDMN',
#   'word.isdigit()': False,
#   'word.prevword': 'เรา',
#   'word.previsspace': False,
#   'word.prepostag': 'PPRS',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'เอง',
#   'word.previsspace': False,
#   'word.prepostag': 'PDMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'หวัง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'หวัง',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ว่า',
#   'word.nextisspace': False,
#   'word.nextpostag': 'JSBR',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ว่า',
#   'word.isspace': False,
#   'postag': 'JSBR',
#   'word.isdigit()': False,
#   'word.prevword': 'หวัง',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'รีวิว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'รีวิว',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ว่า',
#   'word.previsspace': False,
#   'word.prepostag': 'JSBR',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ครั้งนี้',
#   'word.nextisspace': False,
#   'word.nextpostag': 'DDAC',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ครั้งนี้',
#   'word.isspace': False,
#   'postag': 'DDAC',
#   'word.isdigit()': False,
#   'word.prevword': 'รีวิว',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'จะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVBM',
#   'word.nextwordisdigit': False},
#  {'word.word': 'จะ',
#   'word.isspace': False,
#   'postag': 'XVBM',
#   'word.isdigit()': False,
#   'word.prevword': 'ครั้งนี้',
#   'word.previsspace': False,
#   'word.prepostag': 'DDAC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เป็น',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เป็น',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'จะ',
#   'word.previsspace': False,
#   'word.prepostag': 'XVBM',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'อีก',
#   'word.nextisspace': False,
#   'word.nextpostag': 'ADVN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'อีก',
#   'word.isspace': False,
#   'postag': 'ADVN',
#   'word.isdigit()': False,
#   'word.prevword': 'เป็น',
#   'word.previsspace': False,
#   'word.prepostag': 'VSTA',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สถานที่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สถานที่',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'อีก',
#   'word.previsspace': False,
#   'word.prepostag': 'ADVN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ใน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ใน',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'สถานที่',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'การพักผ่อน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'การพักผ่อน',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ใน',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ของ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ของ',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'การพักผ่อน',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'สมาชิก',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'สมาชิก',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ของ',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ทุกท่าน',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ทุกท่าน',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': 'สมาชิก',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ด้วย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'RPRE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ด้วย',
#   'word.isspace': False,
#   'postag': 'RPRE',
#   'word.isdigit()': False,
#   'word.prevword': 'ทุกท่าน',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'นะ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'นะ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'ด้วย',
#   'word.previsspace': False,
#   'word.prepostag': 'RPRE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ครับ',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ครับ',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'นะ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': ' ',
#   'word.nextisspace': True,
#   'word.nextpostag': 'PUNC',
#   'word.nextwordisdigit': False},
#  {'word.word': ' ',
#   'word.isspace': True,
#   'postag': 'PUNC',
#   'word.isdigit()': False,
#   'word.prevword': 'ครับ',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': '#',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': '#',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': ' ',
#   'word.previsspace': True,
#   'word.prepostag': 'PUNC',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เที่ยว',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VACT',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เที่ยว',
#   'word.isspace': False,
#   'postag': 'VACT',
#   'word.isdigit()': False,
#   'word.prevword': '#',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เมือง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NCMN',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เมือง',
#   'word.isspace': False,
#   'postag': 'NCMN',
#   'word.isdigit()': False,
#   'word.prevword': 'เที่ยว',
#   'word.previsspace': False,
#   'word.prepostag': 'VACT',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไทย',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NPRP',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไทย',
#   'word.isspace': False,
#   'postag': 'NPRP',
#   'word.isdigit()': False,
#   'word.prevword': 'เมือง',
#   'word.previsspace': False,
#   'word.prepostag': 'NCMN',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไม่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NEG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไม่',
#   'word.isspace': False,
#   'postag': 'NEG',
#   'word.isdigit()': False,
#   'word.prevword': 'ไทย',
#   'word.previsspace': False,
#   'word.prepostag': 'NPRP',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไป',
#   'word.nextisspace': False,
#   'word.nextpostag': 'XVAE',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไป',
#   'word.isspace': False,
#   'postag': 'XVAE',
#   'word.isdigit()': False,
#   'word.prevword': 'ไม่',
#   'word.previsspace': False,
#   'word.prepostag': 'NEG',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'ไม่',
#   'word.nextisspace': False,
#   'word.nextpostag': 'NEG',
#   'word.nextwordisdigit': False},
#  {'word.word': 'ไม่',
#   'word.isspace': False,
#   'postag': 'NEG',
#   'word.isdigit()': False,
#   'word.prevword': 'ไป',
#   'word.previsspace': False,
#   'word.prepostag': 'XVAE',
#   'word.prevwordisdigit': False,
#   'word.nextword': 'เปลือง',
#   'word.nextisspace': False,
#   'word.nextpostag': 'VSTA',
#   'word.nextwordisdigit': False},
#  {'word.word': 'เปลือง',
#   'word.isspace': False,
#   'postag': 'VSTA',
#   'word.isdigit()': False,
#   'word.prevword': 'ไม่',
#   'word.previsspace': False,
#   'word.prepostag': 'NEG',
#   'word.prevwordisdigit': False,
#   'EOS': True}]

# %%
print(str(len(X_data))+' , '+str(len(y_data)))
# Out:
# 265 , 265

# %%
y_data[0][:2]
# Out:
# ['O', 'O']

# %% [markdown]
# # KFold = 10-Fold

# %%
X, X_test, y, y_test = train_test_split(X_data, y_data, test_size=0.1) # แบ่ง 0.1 หรือ 10%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=500,
    all_possible_transitions=True,
    model_filename=file_name+"-pos.model0" # ตั้งชื่อโมเดล
)
crf.fit(X, y); # train

# %%
print(X[0])
print(y[0])
# Out:
# [{'word.word': 'พอดี', 'word.isspace': False, 'postag': 'ADVN', 'word.isdigit()': False, 'BOS': True, 'word.nextword': 'ว่า', 'word.nextisspace': False, 'word.nextpostag': 'JSBR', 'word.nextwordisdigit': False}, {'word.word': 'ว่า', 'word.isspace': False, 'postag': 'JSBR', 'word.isdigit()': False, 'word.prevword': 'พอดี', 'word.previsspace': False, 'word.prepostag': 'ADVN', 'word.prevwordisdigit': False, 'word.nextword': 'หัวหน้างาน', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}, {'word.word': 'หัวหน้างาน', 'word.isspace': False, 'postag': 'NCMN', 'word.isdigit()': False, 'word.prevword': 'ว่า', 'word.previsspace': False, 'word.prepostag': 'JSBR', 'word.prevwordisdigit': False, 'word.nextword': 'ลาพักร้อน', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}, {'word.word': 'ลาพักร้อน', 'word.isspace': False, 'postag': 'NCMN', 'word.isdigit()': False, 'word.prevword': 'หัวหน้างาน', 'word.previsspace': False, 'word.prepostag': 'NCMN', 'word.prevwordisdigit': False, 'word.nextword': 'จะ', 'word.nextisspace': False, 'word.nextpostag': 'XVBM', 'word.nextwordisdigit': False}, {'word.word': 'จะ', 'word.isspace': False, 'postag': 'XVBM', 'word.isdigit()': False, 'word.prevword': 'ลาพักร้อน', 'word.previsspace': False, 'word.prepostag': 'NCMN', 'word.prevwordisdigit': False, 'word.nextword': 'แวะ', 'word.nextisspace': False, 'word.nextpostag': 'VACT', 'word.nextwordisdigit': False}, {'word.word': 'แวะ', 'word.isspace': False, 'postag': 'VACT', 'word.isdigit()': False, 'word.prevword': 'จะ', 'word.previsspace': False, 'word.prepostag': 'XVBM', 'word.prevwordisdigit': False, 'word.nextword': 'เที่ยว', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}, {'word.word': 'เที่ยว', 'word.isspace': False, 'postag': 'NCMN', 'word.isdigit()': False, 'word.prevword': 'แวะ', 'word.previsspace': False, 'word.prepostag': 'VACT', 'word.prevwordisdigit': False, 'word.nextword': 'เมือง', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}, {'word.word': 'เมือง', 'word.isspace': False, 'postag': 'NCMN', 'word.isdigit()': False, 'word.prevword': 'เที่ยว', 'word.previsspace': False, 'word.prepostag': 'NCMN', 'word.prevwordisdigit': False, 'word.nextword': 'ไทย', 'word.nextisspace': False, 'word.nextpostag': 'NPRP', 'word.nextwordisdigit': False}, {'word.word': 'ไทย', 'word.isspace': False, 'postag': 'NPRP', 'word.isdigit()': False, 'word.prevword': 'เมือง', 'word.previsspace': False, 'word.prepostag': 'NCMN', 'word.prevwordisdigit': False, 'word.nextword': '2', 'word.nextisspace': False, 'word.nextpostag': 'DCNM', 'word.nextwordisdigit': True}, {'word.word': '2', 'word.isspace': False, 'postag': 'DCNM', 'word.isdigit()': True, 'word.prevword': 'ไทย', 'word.previsspace': False, 'word.prepostag': 'NPRP', 'word.prevwordisdigit': False, 'word.nextword': 'วัน', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}, {'word.word': 'วัน', 'word.isspace': False, 'postag': 'NCMN', 'word.isdigit()': False, 'word.prevword': '2', 'word.previsspace': False, 'word.prepostag': 'DCNM', 'word.prevwordisdigit': True, 'word.nextword': ' ', 'word.nextisspace': True, 'word.nextpostag': 'PUNC', 'word.nextwordisdigit': False}, {'word.word': ' ', 'word.isspace': True, 'postag': 'PUNC', 'word.isdigit()': False, 'word.prevword': 'วัน', 'word.previsspace': False, 'word.prepostag': 'NCMN', 'word.prevwordisdigit': False, 'word.nextword': 'ผม', 'word.nextisspace': False, 'word.nextpostag': 'PPRS', 'word.nextwordisdigit': False}, {'word.word': 'ผม', 'word.isspace': False, 'postag': 'PPRS', 'word.isdigit()': False, 'word.prevword': ' ', 'word.previsspace': True, 'word.prepostag': 'PUNC', 'word.prevwordisdigit': False, 'word.nextword': 'ก็', 'word.nextisspace': False, 'word.nextpostag': 'JSBR', 'word.nextwordisdigit': False}, {'word.word': 'ก็', 'word.isspace': False, 'postag': 'JSBR', 'word.isdigit()': False, 'word.prevw ...
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
labels = list(crf.classes_)
labels.remove('O')
# e=metrics.flat_f1_score(y_test, y_pred,
#                       average='weighted', labels=labels)
# print(e) # โชว์ประสิทธิภาพ

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)

# %%
sorted_labels
# Out:
# ['B-HOTEL',
#  'I-HOTEL',
#  'B-LOCATION',
#  'I-LOCATION',
#  'B-RESTAURANT',
#  'I-RESTAURANT']

# %% [markdown]
# ### No 10-Fold Classification Report

# %%
y_pred = crf.predict(X_test)

# %%
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#      B-HOTEL      0.667     0.148     0.242        27
#      I-HOTEL      0.722     0.220     0.338       118
#   B-LOCATION      0.839     0.542     0.659       577
#   I-LOCATION      0.751     0.524     0.618       778
# B-RESTAURANT      0.750     0.125     0.214        24
# I-RESTAURANT      0.292     0.161     0.207        87
#
#    micro avg      0.760     0.477     0.586      1611
#    macro avg      0.670     0.287     0.380      1611
# weighted avg      0.754     0.477     0.578      1611

# %% [markdown]
# ### 10-Fold Classification Report

# %%
pred = cross_val_predict(estimator=crf, X=X, y=y, cv=10)

# %%
report = metrics.flat_classification_report(y_pred=pred, y_true=y, labels=sorted_labels, digits=3)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      B-HOTEL      0.571     0.148     0.235       324
#      I-HOTEL      0.659     0.365     0.470      1501
#   B-LOCATION      0.806     0.580     0.674      5011
#   I-LOCATION      0.795     0.624     0.699      9338
# B-RESTAURANT      0.658     0.186     0.290       258
# I-RESTAURANT      0.603     0.227     0.330      1057
#
#    micro avg      0.780     0.550     0.645     17489
#    macro avg      0.682     0.355     0.450     17489
# weighted avg      0.768     0.550     0.635     17489

# %% [markdown]
# ## Merge Label

# %%
print(len(y), len(pred))
# Out:
# 238 238

# %%
pred[:2]
# Out:
# array([list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#        list(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O' ...
#       dtype=object)

# %%
y[:2]
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOCATION',
#   'I-LOCATION',
#   'I-LOCATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B
 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}
# {'word.word': 'ขอ', 'word.isspace': False, 'postag': 'VACT', 'word.isdigit()': False, 'word.prevword': ' ', 'word.previsspace': True, 'word.prepostag': 'PUNC', 'word.prevwordisdigit': False, 'word.nextword': 'เป็นที่', 'word.nextisspace': False, 'word.nextpostag': 'RPRE', 'word.nextwordisdigit': False}
# {'word.word': 'เป็นที่', 'word.isspace': False, 'postag': 'RPRE', 'word.isdigit()': False, 'word.prevword': 'ขอ', 'word.previsspace': False, 'word.prepostag': 'VACT', 'word.prevwordisdigit': False, 'word.nextword': 'ช็อปปิ้ง', 'word.nextisspace': False, 'word.nextpostag': 'NCMN', 'word.nextwordisdigit': False}

# %%
mw = X[0][8]['word.word']+X[0][9]['word.word']
mw
# Out:
# 'ไทย2'

# %%
pred_data = []
for i in range(len(pred)): #วน ทีละกระทู้
    for j in range(len(pred[i])): #วน ภายใน 1 กระทู้
        pred_data.append(pred[i][j])

# %%
pred_data[:10]
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O']

# %%
pred_data[60:90]
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-LOCATION',
#  'I-LOCATION',
#  'I-LOCATION',
#  'I-LOCATION']

# %%
len(pred_data)
# Out:
# 266177

# %%
true_data = []
for i in range(len(y)): #วน ทีละกระทู้
    for j in range(len(y[i])): #วน ภายใน 1 กระทู้
        true_data.append(y[i][j])

# %%
true_data[:10]
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
len(true_data)
# Out:
# 266177

# %%
start=[n for n in range(200, 1000, 200)]
limit = [m for m in range(400, 1200, 200)]

# %%
start
# Out:
# [200, 400, 600, 800]

# %%
limit
# Out:
# [400, 600, 800, 1000]

# %%
for i,j in zip(start,limit):
    print((i,j))
# Out:
# (200, 400)
# (400, 600)
# (600, 800)
# (800, 1000)

# %% [markdown]
# ### Predict list (index(B-LOCATION), count(I-LOCATION))

# %%
loc_pred_list = []

# %%
i=0
n=100
while(i < n):
    if(pred_data[i]=='B-LOCATION' and i!=n-1):
        start_loc = i
        count = 0
        while(pred_data[i+1] == 'I-LOCATION'):
            count += 1
            i += 1
        loc_pred_list.append((start_loc, count))
    elif(pred_data[i]=='B-LOCATION' and i==n-1):
        loc_pred_list.append((i, 0))
    else:
        i += 1

# %%
loc_pred_list[:10]

# %% [markdown]
# ### True list (index(B-LOCATION), count(I-LOCATION))

# %%
loc_true_list = []
i=0
while(i < len(true_data)):
    if(true_data[i]=='B-LOCATION' and i!=len(true_data)):
        start_loc = i
        count = 0
        while(true_data[i+1] == 'I-LOCATION'):
            count += 1
            i += 1
        loc_true_list.append((start_loc, count))
    elif(pred_data[i]=='B-LOCATION' and i==len(pred_data)):
        loc_true_list.append((i, 0))
    else:
        i += 1

# %%
loc_true_list[:10]

# %%
report = classification_report(y_pred=pred_data, y_true=true_data, labels=sorted_labels, digits=3)
print(report)
