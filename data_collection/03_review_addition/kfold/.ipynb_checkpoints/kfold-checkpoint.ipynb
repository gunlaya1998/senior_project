# %%
file_name="kfold_train_dataset" # ชื่อไฟล์คลังข้อมูล

# %%
import codecs
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from nltk.tokenize import RegexpTokenizer
import glob
import nltk
import re

# %%
#จัดการประโยคซ้ำ
data_not=[]
def Unique(p):
 text=re.sub("<[^>]*>","",p)
 text=re.sub("\[(.*?)\]","",text)
 text=re.sub("\[\/(.*?)\]","",text)
 if text not in data_not:
  data_not.append(text)
  return True
 else:
  return False
# เตรียมตัวตัด tag ด้วย re
pattern = r'\[(.*?)\](.*?)\[\/(.*?)\]'
tokenizer = RegexpTokenizer(pattern) # ใช้ nltk.tokenize.RegexpTokenizer เพื่อตัด [TIME]8.00[/TIME] ให้เป็น ('TIME','ไง','TIME')
# จัดการกับ tag ที่ไม่ได้ tag
def toolner_to_tag(text):
 text=text.strip()
 text=re.sub("<[^>]*>","",text)
 text=re.sub("(\[\/(.*?)\])","\\1***",text)#.replace('(\[(.*?)\])','***\\1')#  ตัดการกับพวกไม่มี tag word
 text=re.sub("(\[\w+\])","***\\1",text)
 text2=[]
 for i in text.split('***'):
  if "[" in i:
   text2.append(i)
  else:
   text2.append("[word]"+i+"[/word]")
 text="".join(text2)#re.sub("[word][/word]","","".join(text2))
 return text.replace("[word][/word]","")
# แปลง text ให้เป็น conll2002
def text2conll2002(text,pos=True):
    """
    ใช้แปลงข้อความให้กลายเป็น conll2002
    """
    text=toolner_to_tag(text) # นำไปใส่ tag [word]
    text=text.replace("''",'"')
    text=text.replace("’",'"').replace("‘",'"')#.replace('"',"")
    tag=tokenizer.tokenize(text) # แยก tag ออกมาจากข้อความ
    j=0
    conll2002="" # ประกาศตัวแปรเก็บ conll2002
    for tagopen,text,tagclose in tag: # ลูปใน tag โดยเป็น (tagopen,text,tagclose)
        word_cut=word_tokenize(text,engine="newmm") # ใช้ตัวตัดคำ newmm ของ PyThaiNLP
        i=0
        txt5=""
        while i<len(word_cut): #ลูปตามจำนวน token ที่ตัดในtag
            if word_cut[i]=="''" or word_cut[i]=='"':pass
            elif i==0 and tagopen!='word': # ไม่เป็น tag [word] และเป็น i หรือตัวเริ่มต้น tag
                txt5+=word_cut[i]
                txt5+='\t'+'B-'+tagopen
            elif tagopen!='word':
                txt5+=word_cut[i]
                txt5+='\t'+'I-'+tagopen
            else: # เป็น [word]
                txt5+=word_cut[i]
                txt5+='\t'+'O'
            txt5+='\n'
            #j+=1
            i+=1
        conll2002+=txt5
    if pos==False:
        return conll2002
    return postag(conll2002) # เพิ่ม postag ใส่
# ใช้สำหรับกำกับ pos tag เพื่อใช้กับ NER
# print(text2conll2002(t,pos=False))
def postag(text):
    listtxt=[i for i in text.split('\n') if i!='']
    list_word=[]
    for data in listtxt:
        list_word.append(data.split('\t')[0])
    #print(text)
    list_word=pos_tag(list_word,engine="perceptron")
    text=""
    i=0
    for data in listtxt:
        text+=data.split('\t')[0]+'\t'+list_word[i][1]+'\t'+data.split('\t')[1]+'\n'
        i+=1
    return text
# อ่านข้อมูลจากไฟล์
def get_data(fileopen):
	"""
    สำหรับใช้อ่านทั้งหมดทั้งในไฟล์ทีละรรทัดออกมาเป็น list
    """
	with codecs.open(fileopen, 'r',encoding='utf-8-sig') as f:
		lines = f.read().splitlines()
	return [a for a in lines if Unique(a)] # เอาไม่ซ้ำกัน

def alldata(lists):
    text=""
    for data in lists:
        text+=text2conll2002(data)
        text+='\n'
    return text

def alldata_list(lists):
    data_all=[]
    for data in lists:
        data_num=[]
        try:
            txt=text2conll2002(data,pos=True).split('\n') # นำไปแปลงเป็น conll2002
            for d in txt:
                tt=d.split('\t')
                if d!="":
                    if len(tt)==3:
                        data_num.append((tt[0],tt[1],tt[2]))
                    else:
                        data_num.append((tt[0],tt[1]))
            #print(data_num)
            data_all.append(data_num)
        except:
            print(data)
    #print(data_all)
    return data_all

def alldata_list_str(lists):
	string=""
	for data in lists:
		string1=""
		for j in data:
			string1+=j[0]+"	"+j[1]+"	"+j[2]+"\n"
		string1+="\n"
		string+=string1
	return string

def get_data_tag(listd):
	list_all=[]
	c=[]
	for i in listd:
		if i !='':
			c.append((i.split("\t")[0],i.split("\t")[1],i.split("\t")[2]))
		else:
			list_all.append(c)
			c=[]
	return list_all
def getall(lista):
    ll=[]
    for i in lista:
        o=True
        for j in ll:
            if re.sub("\[(.*?)\]","",i)==re.sub("\[(.*?)\]","",j):
                o=False
                break
        if o==True:
            ll.append(i)
    return ll

# %%
data1=getall(get_data(file_name+".txt")) # นำคลังเข้าไป แยกออกเป็น list ละบรรทัด
datatofile=alldata_list(data1) # นำไปผ่านขั้นตอน 1 2 3 4
tt=[]

# %%
datatofile[1]
# Out:
# [('ได้', 'XVAM', 'O'),
#  ('ค้นพบ', 'VACT', 'O'),
#  ('สิ่ง', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('อ', 'NCMN', 'O'),
#  ('เม', 'VACT', 'O'),
#  ('ซิ่ง', 'NCMN', 'O'),
#  ('ไทยแลนด์', 'NCMN', 'O'),
#  ('โดยไม่ตั้งใจ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่', 'PREL', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'B-LOCATION'),
#  ('ท่า', 'NCMN', 'I-LOCATION'),
#  ('ระแนะ', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('ตำบล', 'NCMN', 'I-LOCATION'),
#  ('หนอง', 'NCMN', 'I-LOCATION'),
#  ('คันทรง', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('อ', 'NCMN', 'I-LOCATION'),
#  ('เมือง', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('จ', 'NCMN', 'I-LOCATION'),
#  ('ตราด', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('แทบ', 'NCMN', 'O'),
#  ('อยาก', 'NCMN', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เตะ', 'VACT', 'O'),
#  ('ตรู', 'NCMN', 'O'),
#  ('ด', 'NCMN', 'O'),
#  ('ตัวเอง', 'PDMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('อยู่', 'XVAE', 'O'),
#  ('ไหน', 'PNTR', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ตั้ง', 'VACT', 'O'),
#  ('นาน', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ร้อยเอ็ดเจ็ดย่านน้ำ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จน', 'JSBR', 'O'),
#  ('ป่านนี้', 'VSTA', 'O'),
#  ('อายุ', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('25', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ปี', 'CMTR', 'O'),
#  ('แล้ว', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ป้า', 'VACT', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('รู้จัก', 'VSTA', 'O'),
#  ('ที่เที่ยว', 'DDAN', 'O'),
#  ('แห่ง', 'CNIT', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อิอิ', 'NPRP', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตราด', 'NCMN', 'B-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('โดย', 'JSBR', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('รู้เรื่อง', 'NCMN', 'O'),
#  ('อะไร', 'PNTR', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แค่', 'DDBQ', 'O'),
#  ('อยาก', 'XVMM', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ทำ', 'VACT', 'O'),
#  ('สถิติ', 'NCMN', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ครบ', 'ADVN', 'O'),
#  ('ทุก', 'DIBQ', 'O'),
#  ('จังหวัด', 'CNIT', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('ภาค', 'NCMN', 'O'),
#  ('ตะวันออก', 'NCMN', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  ('เท่านั้น', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('เคย', 'XVMM', 'O'),
#  ('ได้ยิน', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ฟัง', 'NCMN', 'O'),
#  ('คน', 'NCMN', 'O'),
#  ('รอบข้าง', 'VATT', 'O'),
#  ('หรือ', 'JCRG', 'O'),
#  ('ตาม', 'RPRE', 'O'),
#  ('สื่อ', 'NCMN', 'O'),
#  ('ต่างๆ', 'DIAC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('มัน', 'PPRS', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('จังหวัด', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('น่า', 'XVAM', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('ขนาด', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ก่อน', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('ใคร', 'PNTR', 'O'),
#  ('ไปเที่ยว', 'VACT', 'O'),
#  ('ตราด', 'NCMN', 'B-LOCATION'),
#  ('ทีไร', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('พูดถึง', 'VACT', 'O'),
#  ('เกาะ', 'NCMN', 'B-LOCATION'),
#  ('ช้าง', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จึง', 'XVBM', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('คาดหวัง', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('สิ่ง', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ได้รับ', 'VSTA', 'O'),
#  ('กลับมา', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตอนนี้', 'NCMN', 'O'),
#  ('แทบ', 'ADVN', 'O'),
#  ('ทุก', 'DIBQ', 'O'),
#  ('ลมหายใจ', 'CNIT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('หัวใจ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ทิ้ง', 'VACT', 'O'),
#  ('ไว้', 'XVAE', 'O'),
#  ('ที่', 'RPRE', 'O'),
#  ('เมือง', 'NCMN', 'O'),
#  ('ตราด', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่นั่ง', 'NCMN', 'O'),
#  ('ทำ', 'VACT', 'O'),
#  ('รีวิว', 'NCMN', 'O'),
#  ('อยู่', 'XVAE', 'O'),
#  ('นี่', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผี', 'NCMN', 'O'),
#  ('พิมพ์', 'VACT', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ค', 'NCMN', 'O'),
#  ('ริ', 'NCMN', 'O'),
#  ('ค', 'NCMN', 'O'),
#  ('ริ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('วิว', 'NCMN', 'O'),
#  ('สอง', 'DCNM', 'O'),
#  ('ข้าง', 'CNIT', 'O'),
#  ('ฝั่งคลอง', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ป่า', 'NCMN', 'O'),
#  ('ต้น', 'VATT', 'O'),
#  ('จาก', 'RPRE', 'O'),
#  ('ยักษ์', 'NCMN', 'O'),
#  ('ขึ้น', 'XVAE', 'O'),
#  ('เต็มไปหมด', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เหมือน', 'JCMP', 'O'),
#  ('นั่ง', 'NCMN', 'O'),
#  ('เรือ', 'VACT', 'O'),
#  ('เข้าไป', 'XVAE', 'O'),
#  ('ล่อง', 'ADVN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('อุโมงค์', 'NCMN', 'O'),
#  ('จู', 'NCMN', 'O'),
#  ('รา', 'NCMN', 'O'),
#  ('ส', 'NCMN', 'O'),
#  ('สิ', 'NCMN', 'O'),
#  ('ค', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('มั้ย', 'ADVN', 'O'),
#  ('ล่า', 'NCMN', 'O'),
#  ('า', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ขับรถ', 'NCMN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('เมือง', 'NCMN', 'B-LOCATION'),
#  ('ตราด', 'NCMN', 'I-LOCATION'),
#  ('ก็', 'JSBR', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ค้นหา', 'VACT', 'O'),
#  ('ที่เที่ยว', 'NCMN', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('สดๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่นั่น', 'NCMN', 'O'),
#  ('เปิด', 'VACT', 'O'),
#  ('เน็ต', 'NCMN', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('รูป', 'NCMN', 'O'),
#  ('ลาน', 'NCMN', 'O'),
#  ('ราก', 'NCMN', 'O'),
#  ('ไม้', 'NCMN', 'O'),
#  ('แปลกตา', 'NCMN', 'O'),
#  ('น่าสนใจ', 'VATT', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ตั้งค่า', 'VSTA', 'O'),
#  ('จีพีเอส', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('นำทาง', 'VSTA', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('พอ', 'ADVN', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('ปาก', 'NCMN', 'O'),
#  ('ทางเข้า', 'NCMN', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เจ้าหน้าที่', 'NCMN', 'O'),
#  ('ทหาร', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('เครื่องแบบ', 'NCMN', 'O'),
#  ('ยืน', 'VACT', 'O'),
#  ('อยู่', 'XVAE', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('หลาย', 'DIBQ', 'O'),
#  ('คน', 'CNIT', 'O'),
#  ('เหมือน', 'JCMP', 'O'),
#  ('รอ', 'VSTA', 'O'),
#  ('อะไร', 'PNTR', 'O'),
#  ('อยู่', 'VSTA', 'O'),
#  ('เอ๊ะ', 'NCMN', 'O'),
#  ('สงสัย', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('รอ', 'VSTA', 'O'),
#  ('ต้อนรับ', 'VACT', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อิอิ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('พอ', 'ADVN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('ลานจอดรถ', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'B-LOCATION'),
#  ('ท่า', 'NCMN', 'I-LOCATION'),
#  ('ระแนะ', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ตำรวจ', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('เครื่องแบบ', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ยืน', 'VACT', 'O'),
#  ('โบก', 'NCMN', 'O'),
#  ('รถ', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('แน่ะ', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('เอ๊ะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ยังไง', 'VACT', 'O'),
#  ('เตรียม', 'VACT', 'O'),
#  ('ต้อนรับ', 'VACT', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ขนาด', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('หรอ', 'NCMN', 'O'),
#  ('รู้', 'VSTA', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ไง', 'NCMN', 'O'),
#  ('คะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('วีไอพี', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ฟู', 'NCMN', 'O'),
#  ('กำลัง', 'XVBM', 'O'),
#  ('มา', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อิอิ', 'NCMN', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('เข้าไป', 'XVAE', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('ลาน', 'NCMN', 'O'),
#  ('เล็ก', 'VATT', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ริมน้ำ', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'O'),
#  ('เท่า', 'VSTA', 'O'),
#  ('นั้นแหละ', 'NCMN', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('คน', 'CNIT', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('ร้อย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ยืน', 'VACT', 'O'),
#  ('จับกลุ่ม', 'VACT', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('อยู่', 'XVAE', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เต้นท์', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เก้าอี้', 'NCMN', 'O'),
#  ('ฯลฯ', 'PDMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ดด', 'NCMN', 'O'),
#  ('จัดงาน', 'NCMN', 'O'),
#  ('อะไร', 'PNTR', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('นั่นเอง', 'ADVN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('เริ่ม', 'VSTA', 'O'),
#  ('กังวล', 'VACT', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ถาม', 'VACT', 'O'),
#  ('คนใน', 'NCMN', 'O'),
#  ('นั้น', 'DDAC', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('ขึ้น', 'VACT', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('ไปดู', 'NCMN', 'O'),
#  ('ราก', 'NCMN', 'O'),
#  ('ตะบูน', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ที่ไหน', 'PNTR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('คำตอบ', 'NCMN', 'O'),
#  ('คือ', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('วันนี้', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('นำเที่ยว', 'VATT', 'O'),
#  ('เจ้าค่ะ', 'VACT', 'O'),
#  ('เพราะ', 'JSBR', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('ทุก', 'DIBQ', 'O'),
#  ('ลำ', 'CNIT', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('เตรียมพร้อม', 'VSTA', 'O'),
#  ('ที่จะ', 'JSBR', 'O'),
#  ('พา', 'VACT', 'O'),
#  ('ผู้ว่าราชการจังหวัด', 'NCMN', 'O'),
#  ('ตราด', 'NCMN', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('คณะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไปเที่ยว', 'NCMN', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('ดูงาน', 'NCMN', 'O'),
#  ('ที่นี่', 'NCMN', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('วันนี้', 'NCMN', 'O'),
#  ('มัน', 'PPRS', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('วัน', 'NCMN', 'O'),
#  ('เปิดงาน', 'VACT', 'O'),
#  ('ส่งเสริม', 'VACT', 'O'),
#  ('การท่องเที่ยว', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ท่า', 'VSTA', 'O'),
#  ('ระแนะ', 'NCMN', 'O'),
#  ('ทุกคน', 'NCMN', 'O'),
#  ('ยุ่ง', 'VACT', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  ('จึง', 'XVBM', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('พา', 'VACT', 'O'),
#  ('นักท่องเที่ยว', 'FIXN', 'O'),
#  ('อย่าง', 'FIXV', 'O'),
#  ('ป้า', 'VSTA', 'O'),
#  ('ฟู', 'NCMN', 'O'),
#  ('ไปเที่ยว', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ก', 'NCMN', 'O'),
#  ('รี้', 'NCMN', 'O'),
#  ('ดดดด', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnnn', 'NCMN', 'O'),
#  ('เอาล่ะ', 'NCMN', 'O'),
#  ('เซ่', 'NCMN', 'O'),
#  ('ทำไม', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('จึง', 'XVBM', 'O'),
#  ('ซวย', 'VACT', 'O'),
#  ('ขนาด', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตั้ง', 'VACT', 'O'),
#  ('ใจมา', 'NCMN', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('ทั้งที', 'NCMN', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ดัน', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('เจอ', 'VACT', 'O'),
#  ('วัน', 'NCMN', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('สำคัญ', 'VATT', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'O'),
#  ('พอดี', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แง ๆ', 'NCMN', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('เอา', 'VACT', 'O'),
#  ('ไง', 'NCMN', 'O'),
#  ('ดี', 'VATT', 'O'),
#  ('หว่า', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ยอมแพ้', 'VACT', 'O'),
#  ('ถอยทัพ', 'NCMN', 'O'),
#  ('กลับ', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('แล้ว', 'ADVN', 'O'),
#  ('ค่อย', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ใหม่', 'ADVN', 'O'),
#  ('วันหลัง', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ซึ่ง', 'JSBR', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('รู้', 'VSTA', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('เมื่อไร', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('กว่า', 'DIAQ', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ได้', 'VSTA', 'O'),
#  ('กลับมา', 'VACT', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('เมือง', 'NCMN', 'O'),
#  ('ไทย', 'NPRP', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('อาจจะ', 'XVBM', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('ปี', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แล้', 'NCMN', 'O'),
#  ('วจะ', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เวลา', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ตราด', 'VACT', 'B-LOCATION'),
#  ('อีก', 'ADVN', 'O'),
#  ('ไหม', 'NCMN', 'O'),
#  ('เนี่ย', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('งุ่นง่าน', 'NCMN', 'O'),
#  ('ไปมา', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('คุย', 'NCMN', 'O'),
#  ('ออดอ้อน', 'VACT', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('คน', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('คน', 'NCMN', 'O'),
#  ('นั้น', 'DDAC', 'O'),
#  ('บ้าง', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ใคร', 'PNTR', 'O'),
#  ('ช่วย', 'VACT', 'O'),
#  ('ป้า', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เพราะ', 'JSBR', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('ว่าง', 'VSTA', 'O'),
#  ('จริงๆ', 'ADVI', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('เขา', 'PPRS', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('บอ', 'VATT', 'O'),
#  ('กว่า', 'JCMP', 'O'),
#  ('ใจเย็น', 'NCMN', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  ('ตรง', 'RPRE', 'O'),
#  ('ใกล้', 'VATT', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('ก่อน', 'RPRE', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('เลิก', 'VACT', 'O'),
#  ('แล้ว', 'ADVN', 'O'),
#  ('อาจ', 'XVMM', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('ว่าง', 'VSTA', 'O'),
#  ('ก็ได้', 'XVAE', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('คน', 'CNIT', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('แย้ง', 'VACT', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('แน่', 'VSTA', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('ตอนนั้น', 'JSBR', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เพราะ', 'JSBR', 'O'),
#  ('น้ำขึ้น', 'VSTA', 'O'),
#  ('น้ำลง', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อ้าว', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ชุมชน', 'NCMN', 'B-LOCATION'),
#  ('บ้าน', 'NCMN', 'I-LOCATION'),
#  ('ท่า', 'NCMN', 'I-LOCATION'),
#  ('ระแนะ', 'NCMN', 'I-LOCATION'),
#  ('มี', 'VSTA', 'O'),
#  ('ต้นไม้', 'NCMN', 'O'),
#  ('หลาก', 'NCMN', 'O'),
#  ('ชนิด', 'NCMN', 'O'),
#  ('ราก', 'NCMN', 'O'),
#  ('ต้น', 'VATT', 'O'),
#  ('โกงกาง', 'NCMN', 'O'),
#  ('ใหญ่', 'VATT', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('น่าทึ่ง', 'JSBR', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('ที่สุด', 'ADVN', 'O'),
#  ('nnnnnnn', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  ('หลาย', 'DIBQ', 'O'),
#  ('แห่ง', 'CNIT', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('จังหวัด', 'NCMN', 'B-LOCATION'),
#  ('ตราด', 'NCMN', 'I-LOCATION'),
#  ('อยาก', 'XVMM', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('บอ', 'VSTA', 'O'),
#  ('กว่า', 'JCMP', 'O'),
#  ('มัน', 'PPRS', 'O'),
#  ('สวย', 'VATT', 'O'),
#  ('ที่สุด', 'ADVN', 'O'),
#  ('ในประเทศ', 'NCMN', 'O'),
#  ('ไทย', 'NPRP', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ยัง', 'XVBM', 'O'),
#  ('พูด', 'VACT', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('เต็มปาก', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เพราะ', 'JSBR', 'O'),
#  ('เคย', 'XVMM', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('กี่', 'DIBQ', 'O'),
#  ('จังหวัด', 'NCMN', 'O'),
#  ('เอง', 'PDMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เอาเป็นว่า', 'JSBR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ถ้า', 'JSBR', 'O'),
#  ('ใคร', 'PNTR', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  ('ที่นี่', 'PDMN', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('ประทับใจ', 'VACT', 'O'),
#  ('แน่นอน', 'VATT', 'O'),
#  ('n', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ออกมา', 'XVAE', 'O'),
#  ('ปรึกษา', 'VACT', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('เพื่อน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ถอดใจ', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('แล้วแต่', 'RPRE', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('ยอม', 'VSTA', 'O'),
#  ('ตอนแรก', 'ADVN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('อยาก', 'XVAM', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('ราก', 'NCMN', 'O'),
#  ('ตะบูน', 'NCMN', 'O'),
#  ('ระดับ', 'NCMN', 'O'),
#  ('ธรรมดา', 'VATT', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ตอนนี้', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('อุปสรรค', 'NCMN', 'O'),
#  ('ใหญ่', 'VATT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ขวางกั้น', 'VACT', 'O'),
#  ('รัก', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ทำให้', 'VACT', 'O'),
#  ('ความอยาก', 'NCMN', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('เพิ่ม', 'ADVN', 'O'),
#  ('ทวีคูณ', 'NCMN', 'O'),
#  ('รัก', 'NCMN', 'O'),
#  ('ต้องห้าม', 'VACT', 'O'),
#  ('แม้', 'NCMN', 'O'),
#  ('ข้าม', 'VACT', 'O'),
#  ('ขุนเขา', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หรือ', 'JCRG', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ว่ายน้ำ', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('เอง', 'PDMN', 'O'),
#  ('ดี', 'VATT', 'O'),
#  ('นะ', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อิอิ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nn', 'NCMN', 'O'),
#  ('เค', 'NCMN', 'O'),
#  ('ร', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ๆๆๆ', 'NCMN', 'O'),
#  ('ว่ายน้ำ', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จบ', 'VSTA', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('จน', 'JSBR', 'O'),
#  ('สุด', 'VSTA', 'O'),
#  ('เส้นทาง', 'NCMN', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  ('เจอ', 'NCMN', 'O'),
#  ('ท่าน้ำ', 'NCMN', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ป้าย', 'NCMN', 'O'),
#  ('บอ', 'VATT', 'O'),
#  ('กว่า', 'JCMP', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('สาม', 'DCNM', 'O'),
#  ('ร้อย', 'DCNM', 'O'),
#  ('เมตร', 'CMTR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('ลาน', 'NCMN', 'B-LOCATION'),
#  ('ตะบูน', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('ก', 'NLBL', 'O'),
#  ('รี้', 'NCMN', 'O'),
#  ('ดดดด', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ใกล้', 'VATT', 'O'),
#  ('แค่นี้', 'ADVS', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ไง', 'NCMN', 'O'),
#  ('เนี่ย', 'VACT', 'O'),
#  ('n', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('ตอนนั้น', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('งุ่น', 'NCMN', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หาทาง', 'NCMN', 'O'),
#  ('ที่จะ', 'JSBR', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('ลาน', 'NCMN', 'B-LOCATION'),
#  ('ตะบูน', 'NCMN', 'I-LOCATION'),
#  ('ให้ได้', 'XVAM', 'O'),
#  ('แม้', 'JSBR', 'O'),
#  ('เพื่อน', 'ADVN', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ถอดใจ', 'VACT', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ฮึด', 'VACT', 'O'),
#  ('สู้', 'NCMN', 'O'),
#  ('บอก', 'VACT', 'O'),
#  ('เพื่อน', 'ADVN', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('ยังไง', 'NCMN', 'O'),
#  ('ข้าพเจ้า', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('มัน', 'PPRS', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('วันนี้', 'NCMN', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('เดิน', 'VACT', 'O'),
#  ('ดิ่ง', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไปหา', 'NCMN', 'O'),
#  ('หนึ่ง', 'DCNM', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('คน', 'NCMN', 'O'),
#  ('จัดงาน', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('หมู่บ้าน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ป้า', 'VACT', 'O'),
#  ('พูดคุย', 'VSTA', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('สักครู่', 'NCMN', 'O'),
#  ('ก่อน', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('บอก', 'VACT', 'O'),
#  ('เขา', 'PPRS', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ตัดสินใจ', 'VACT', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('ไปดู', 'VACT', 'O'),
#  ('ลาน', 'NCMN', 'B-LOCATION'),
#  ('ตะบูน', 'NCMN', 'I-LOCATION'),
#  ('กับ', 'RPRE', 'O'),
#  ('คณะ', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ผู้ว่าฯ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('น้องชาย', 'NCMN', 'O'),
#  ('เตรียม', 'VACT', 'O'),
#  ('เผื่อ', 'JSBR', 'O'),
#  ('ที่นั่ง', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('เรือ', 'NCMN', 'O'),
#  ('ไว้', 'XVAE', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('ขุ่น', 'NCMN', 'O'),
#  ('พี่', 'NCMN', 'O'),
#  ('ทั้งสอง', 'DDAN', 'O'),
#  ('คน', 'CNIT', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มิ', 'NEG', 'O'),
#  ('ใย', 'XVAM', 'O'),
#  ('ที่จะ', 'JSBR', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  ('น้อง', 'NCMN', 'O'),
#  ('สำลัก', 'NCMN', 'O'),
#  ('กาแฟ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('ได้', 'VSTA', 'O'),
#  ('ฟัง', 'VACT', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('หา', 'VACT', 'O'),
#  ('แคร์', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('nn', 'RPRE', 'O'),
#  ('ด้าน', 'NCMN', 'O'),
#  ('ได้', 'XVAM', 'O'),
#  ('อา', 'VACT', 'O'),
#  ('ยอด', 'NCMN', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('สู', 'NCMN', 'O'),
#  ('จง', 'NCMN', 'O'),
#  ('จำ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('แหม', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หลัก', 'NCMN', 'O'),
#  ('คิด', 'VACT', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ป้า', 'NCMN', 'O'),
#  ('ตอนนั้น', 'DDAC', 'O'),
#  ('อ่ะ', 'VACT', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('วันนี้', 'JSBR', 'O'),
#  ('จัด', 'VACT', 'O'),
#  ('ขึ้น', 'XVAE', 'O'),
#  ('เพื่อ', 'RPRE', 'O'),
#  ('ส่งเสริม', 'VACT', 'O'),
#  ('การท่องเที่ยว', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ท่า', 'NCMN', 'O'),
#  ('ระแนะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('คน', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('หลาย', 'DIBQ', 'O'),
#  ('ฝ่าย', 'NCMN', 'O'),
#  ('ทั้ง', 'JCRG', 'O'),
#  ('คนใน', 'NCMN', 'O'),
#  ('ชุมชน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผู้ใหญ่บ้าน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เจ้าหน้าที่', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ข้าราชการ', 'NCMN', 'O'),
#  ('หน่วยงาน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('เกี่ยวข้อง', 'VSTA', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('การ', 'FIXN', 'O'),
#  ('ส่งเสริม', 'VACT', 'O'),
#  ('การท่องเที่ยว', 'NCMN', 'O'),
#  ('nnn', 'NCMN', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('ขาด', 'VSTA', 'O'),
#  ('ฝ่าย', 'NCMN', 'O'),
#  ('ไหนล่ะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ติ๊ก', 'NCMN', 'O'),
#  ('ต่อ', 'RPRE', 'O'),
#  ('ก', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ๆๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('ขาด', 'VSTA', 'O'),
#  ('นักท่องเที่ยว', 'NCMN', 'O'),
#  ('น่ะ', 'NCMN', 'O'),
#  ('เซ่', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แล้ว', 'JSBR', 'O'),
#  ('ป้า', 'VACT', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('ใคร๊', 'NCMN', 'O'),
#  ('วันนั้น', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('นักท่องเที่ยว', 'NCMN', 'O'),
#  ('อยู่', 'XVAE', 'O'),
#  ('สอง', 'DCNM', 'O'),
#  ('คน', 'CNIT', 'O'),
#  ('นี่แหละ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อิอิ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('n', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ป่าชายเลน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('บ้าน', 'NCMN', 'B-LOCATION'),
#  ('ท่า', 'NCMN', 'I-LOCATION'),
#  ('ระแนะ', 'VACT', 'I-LOCATION'),
#  ('มี', 'VSTA', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ต้นไม้', 'NCMN', 'O'),
#  ('สูงใหญ่', 'DDAN', 'O'),
#  ('หลาก', 'NCMN', 'O'),
#  ('หลายชนิด', 'NCMN', 'O'),
#  ('คละ', 'NCMN', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ตื่นตาตื่นใจ', 'VACT', 'O'),
#  ('ตลอดทาง', 'NCMN', 'O'),
#  ('n', 'NCMN', 'O'),
#  ('ยัง', 'XVBM', 'O'),
#  ('ได้', 'XVAM', 'O'),
#  ('เห็น', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ลูก', 'NCMN', 'O'),
#  ('ร้อย', 'VACT', 'O'),
#  ('รู', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ชาวบ้าน', 'NCMN', 'O'),
#  ('เอา', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ทำ', 'VACT', 'O'),
#  ('ชา', 'NCMN', 'O'),
#  ('ไว้', 'XVAE', 'O'),
#  ('ชง', 'ADVN', 'O'),
#  ('ดื่ม', 'ADVN', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เสียดาย', 'NCMN', 'O'),
#  ...]

# %%
with open(file_name+"-pos.conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[1]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

# %%
with open(file_name+".conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

# %%
from sklearn_crfsuite import scorers,metrics
from sklearn.metrics import make_scorer, confusion_matrix, classification_report, accuracy_score, make_scorer
from sklearn.model_selection import cross_validate,train_test_split, KFold, StratifiedKFold, cross_val_predict, cross_val_score
import sklearn_crfsuite

# %%
def doc2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
    # Features from current word
    features={
        'word.word': word,
        'word.isspace':word.isspace(),
        'postag':postag,
        'word.isdigit()': word.isdigit()
    }
    if i > 0:
        prevword = doc[i-1][0]
        postag1 = doc[i-1][1]
        features['word.prevword'] = prevword
        features['word.previsspace']=prevword.isspace()
        features['word.prepostag'] = postag1
        features['word.prevwordisdigit'] = prevword.isdigit()
    else:
        features['BOS'] = True # Special "Beginning of Sequence" tag
    # Features from next word
    if i < len(doc)-1:
        nextword = doc[i+1][0]
        postag1 = doc[i+1][1]
        features['word.nextword'] = nextword
        features['word.nextisspace']=nextword.isspace()
        features['word.nextpostag'] = postag1
        features['word.nextwordisdigit'] = nextword.isdigit()
    else:
        features['EOS'] = True # Special "End of Sequence" tag
    return features

def extract_features(doc):
    return [doc2features(doc, i) for i in range(len(doc))]

def get_labels(doc):
    return [tag for (token,postag,tag) in doc]

# %%
X_data = [extract_features(doc) for doc in datatofile] # เอา คำ แยกออกมา : [[จังหวัด, ชุมพร],...,[]]
y_data = [get_labels(doc) for doc in datatofile] # เอา tag แยกออกมา : [[B-LOCATION, I-LOCATION],...,[]]

# %%
import pandas as pd

# %%
datatofile[0]
# Out:
# [('มา', 'XVAE', 'O'),
#  ('แย้', 'VACT', 'O'),
#  ('วววววววววววววววววววววว', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('รีวิว', 'NCMN', 'O'),
#  ('ง่ายๆ', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เห็นภาพ', 'NCMN', 'O'),
#  ('สดๆ', 'VSTA', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('กล้อง', 'NCMN', 'O'),
#  ('โทรศัพท์', 'NCMN', 'O'),
#  ('ธรรมดาๆ', 'NCMN', 'O'),
#  ('นี่แหละ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('   ', 'NCMN', 'O'),
#  ('3', 'NCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('-', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('4', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('FEB', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('2018', 'NCNM', 'O'),
#  ('   ', 'NCMN', 'O'),
#  ('มา', 'XVAM', 'O'),
#  ('เริ่ม', 'VSTA', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('โจทย์', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('ทริป', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('ขอ', 'VACT', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('ฟินๆ', 'NCMN', 'O'),
#  ('นั่ง', 'NCMN', 'O'),
#  ('แช่', 'VACT', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มอง', 'NCMN', 'O'),
#  ('วิว', 'NCMN', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ลอง', 'XVMM', 'O'),
#  ('หา', 'VACT', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('ราคาแพง', 'NCMN', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ทั้ง', 'DDBQ', 'O'),
#  ('น้านนนนนน', 'NCMN', 'O'),
#  ('น', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('สุดท้าย', 'DONM', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('จบ', 'VSTA', 'O'),
#  ('ที่นี่', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('ซัน', 'NCMN', 'B-LOCATION'),
#  ('ไช', 'NCMN', 'I-LOCATION'),
#  ('น์', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('พาราไดซ์', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('รีสอร์ต', 'NCMN', 'I-LOCATION'),
#  ('  ', 'NCMN', 'O'),
#  ('(', 'PUNC', 'O'),
#  ('Sunshine', 'NCMN', 'B-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('Paradise', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('Resort', 'NCMN', 'I-LOCATION'),
#  (')', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ห้อง', 'NCMN', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Beachfront', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Pool', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Villa', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('การ', 'FIXN', 'O'),
#  ('เดินทาง', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ใช้', 'VACT', 'O'),
#  ('ถนน', 'NCMN', 'O'),
#  ('เพชรเกษม', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ตัวเมือง', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ทับสะแก', 'NCMN', 'B-LOCATION'),
#  (' ', 'PUNC', 'I-LOCATION'),
#  ('จังหวัด', 'NCMN', 'I-LOCATION'),
#  ('ประจวบคีรีขันธ์', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('ระยะทาง', 'NCMN', 'O'),
#  ('อาจจะ', 'XVMM', 'O'),
#  ('ไกล', 'VSTA', 'O'),
#  ('หน่อย', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('ใช่', 'VSTA', 'O'),
#  ('อุปสรรค', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('การเที่ยว', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ใช้เวลา', 'VSTA', 'O'),
#  ('เดินทาง', 'RPRE', 'O'),
#  ('ประ', 'NCMN', 'O'),
#  ('มาน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('45', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ชม', 'CNIT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จาก', 'RPRE', 'O'),
#  ('ฟิวเจอร์', 'NCMN', 'B-LOCATION'),
#  ('พาร์ค', 'NCMN', 'I-LOCATION'),
#  ('รังสิต', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('ออกเดินทาง', 'NCMN', 'O'),
#  ('เช้า', 'VATT', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('แวะ', 'NCMN', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('ชะ', 'NCMN', 'B-LOCATION'),
#  ('อำ', 'NCMN', 'I-LOCATION'),
#  (' ', 'PUNC', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('อ่าว', 'NCMN', 'B-LOCATION'),
#  ('มะนาว', 'NCMN', 'I-LOCATION'),
#  ('ได้', 'XVAM', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('ชิวๆ', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เส้น', 'NCMN', 'O'),
#  ('ทางเข้า', 'NCMN', 'O'),
#  ('ที่พัก', 'NCMN', 'O'),
#  ('อาจ', 'XVMM', 'O'),
#  ('ดู', 'VACT', 'O'),
#  ('ลุย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('หน่อย', 'NCMN', 'O'),
#  ('รถ', 'NCMN', 'O'),
#  ('เตี้ย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('คลาน', 'VACT', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('เข้าไป', 'XVAE', 'O'),
#  ('นะ', 'VACT', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ฮ่า', 'NCMN', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('พอ', 'ADVN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ถึง', 'RPRE', 'O'),
#  ('บอก', 'VACT', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('หาย', 'NCMN', 'O'),
#  ('เหนื่อย', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หาย', 'NCMN', 'O'),
#  ('เมื่อย', 'VACT', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('จริงๆ', 'ADVI', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มาถึง', 'VACT', 'O'),
#  ('ปุ๊', 'NCMN', 'O'),
#  ('ป', 'NCMN', 'O'),
#  ('เช็ด', 'VACT', 'O'),
#  ('อิน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ล็อบบี้', 'VACT', 'O'),
#  ('ก่อน', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่จอดรถ', 'DDAN', 'O'),
#  ('มากมาย', 'ADVN', 'O'),
#  ('เลือก', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ตามสบาย', 'NCMN', 'O'),
#  ('ครับ', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('มา', 'VACT', 'O'),
#  ('ชม', 'VACT', 'O'),
#  ('สถานที่', 'NCMN', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ล็อบบี้', 'NCMN', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('หวือหวา', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('สบาย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('พี่', 'NCMN', 'O'),
#  ('พนักงาน', 'NCMN', 'O'),
#  ('น่ารัก', 'NCMN', 'O'),
#  ('ต้อนรับ', 'VACT', 'O'),
#  ('เป็น', 'FIXN', 'O'),
#  ('อย่าง', 'FIXV', 'O'),
#  ('ดี', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แนะนำ', 'VACT', 'O'),
#  ('ทุกอย่าง', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('ครบ', 'VSTA', 'O'),
#  ('เลย', 'ADVN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('ถ้า', 'JSBR', 'O'),
#  ('ให้', 'VACT', 'O'),
#  ('ดี', 'ADVN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เอกสาร', 'NCMN', 'O'),
#  ('แนะนำ', 'VACT', 'O'),
#  ('ก็ได้', 'XVAE', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ฮ่า', 'NCMN', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เดินผ่าน', 'NCMN', 'O'),
#  ('ล็อบบี้', 'NCMN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เจอ', 'VACT', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('ส่วนกลาง', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สระ', 'NCMN', 'O'),
#  ('กว้างใหญ่', 'NCMN', 'O'),
#  ('ดี', 'VATT', 'O'),
#  ('ครับ', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('แบ่งระดับ', 'NCMN', 'O'),
#  ('สำหรับ', 'RPRE', 'O'),
#  ('เด็ก', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ว่ายน้ำ', 'NCMN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('วิว', 'NCMN', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หู', 'NCMN', 'O'),
#  ('ยยยยยฟินนนนนนน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ใคร', 'PNTR', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('โรคกลัวน้ำ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่นี่', 'NCMN', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ห้อง', 'NCMN', 'O'),
#  ('ฟิตเนส', 'VACT', 'O'),
#  ('ไว้', 'XVAE', 'O'),
#  ('เรียก', 'VACT', 'O'),
#  ('เหงื่อ', 'JSBR', 'O'),
#  ('บริเวณ', 'NCMN', 'O'),
#  ('ใกล้', 'RPRE', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('สระว่ายน้ำ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หลังจาก', 'JSBR', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('ด้านหน้า', 'NCMN', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('ภายใน', 'RPRE', 'O'),
#  ('ห้องพัก', 'NCMN', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ต่อ', 'RPRE', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ห้องพัก', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Beachfront', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Pool', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('Villa', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('ขับรถ', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('จอด', 'VACT', 'O'),
#  ('หน้า', 'NCMN', 'O'),
#  ('บ้านพัก', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เลย', 'ADVN', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สะดวก', 'VSTA', 'O'),
#  ('ดี', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('ชอบ', 'VACT', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แบก', 'NCMN', 'O'),
#  ('ของส่วนตัว', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('เต็มที่', 'VSTA', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('เลย', 'ADVN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไม่ต้อง', 'NCMN', 'O'),
#  ('เกรงใจ', 'VACT', 'O'),
#  ('ใคร', 'PNTR', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('5555', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เปิด', 'VACT', 'O'),
#  ('ประตู', 'NCMN', 'O'),
#  ('เข้ามา', 'XVAE', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('รู้สึก', 'VACT', 'O'),
#  ('สบาย', 'ADVI', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('เมือ', 'NCMN', 'O'),
#  ('น', 'NCMN', 'O'),
#  ('บ้าน', 'NCMN', 'O'),
#  ('ตัวเอง', 'PDMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กว้าง', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ใหญ่', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ดีจริง', 'VATT', 'O'),
#  ('ครับ', 'CFQC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('พื้นที่', 'NCMN', 'O'),
#  ('สำหรับ', 'RPRE', 'O'),
#  ('เตรียม', 'VACT', 'O'),
#  ('อาหาร', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('อนุ', 'VACT', 'O'),
#  ('ญาติ', 'NCMN', 'O'),
#  ('ให้', 'RPRE', 'O'),
#  ('ทำอาหาร', 'NCMN', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('เพราะ', 'JSBR', 'O'),
#  ('บ้านพัก', 'NCMN', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('แอร์', 'NCMN', 'O'),
#  ('ทั้ง', 'JCRG', 'O'),
#  ('หลัง', 'RPRE', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อุปกรณ์', 'NCMN', 'O'),
#  ('ครัว', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เตาไมโครเวฟ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กา', 'NCMN', 'O'),
#  ('น้ำร้อน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จาน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ชาม', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ช้อน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ซ้อม', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตู้เย็น', 'NCMN', 'O'),
#  ('(', 'PUNC', 'O'),
#  ('อันนี้', 'JCRG', 'O'),
#  ('ชอบ', 'NCMN', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตู้เย็น', 'NCMN', 'O'),
#  ('ใหญ่', 'VATT', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ช่อง', 'NCMN', 'O'),
#  ('ฟรี', 'NCMN', 'O'),
#  ('ซ', 'NCMN', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('เร็ว', 'VATT', 'O'),
#  ('ทันใจ', 'NCMN', 'O'),
#  ('จริงๆ', 'ADVI', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (')', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มุมมอง', 'NCMN', 'O'),
#  ('จาก', 'RPRE', 'O'),
#  ('โซฟา', 'NCMN', 'O'),
#  ('สู่', 'RPRE', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ฉาก', 'VACT', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ระ', 'NCMN', 'O'),
#  ('หว่ง', 'NCMN', 'O'),
#  ('ห้องนอน', 'NCMN', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('หมุน', 'VACT', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เหมือน', 'VSTA', 'O'),
#  ('ประตู', 'NCMN', 'O'),
#  ('นินจา', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('หมุน', 'VACT', 'O'),
#  ('ประตู', 'NCMN', 'O'),
#  ('นินจา', 'DDAC', 'O'),
#  ('แล้', 'VACT', 'O'),
#  ('วจะ', 'NCMN', 'O'),
#  ('พบ', 'VSTA', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('ห้องนอน', 'NCMN', 'O'),
#  ('แสน', 'NCMN', 'O'),
#  ('สบาย', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('นอน', 'VACT', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  ('ในเวลาเดียวกัน', 'ADVS', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สำหรับ', 'JSBR', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('แล้ว', 'JSBR', 'O'),
#  ('ชอบ', 'VACT', 'O'),
#  ('ห้องน้ำ', 'NCMN', 'O'),
#  ('ที่นี่', 'DDBQ', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('บอ', 'VSTA', 'O'),
#  ('กว่า', 'JCMP', 'O'),
#  ('ใหญ่', 'VATT', 'O'),
#  ('กว่า', 'JCMP', 'O'),
#  ('ห้องนอน', 'NCMN', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('อ่าง', 'FIXV', 'O'),
#  ('อาบน้ำ', 'NCMN', 'O'),
#  ('ที่นี่', 'DONM', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('จา', 'NCMN', 'O'),
#  ('กุ', 'NCMN', 'O'),
#  ('ซี่', 'NCMN', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ซื้อ', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('bubble', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('bath', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เพิ่ม', 'VSTA', 'O'),
#  ('ความสนุก', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('การอาบน้ำ', 'NCMN', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หลังจาก', 'JSBR', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('ภายใน', 'RPRE', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('มา', 'VACT', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('ส่วนตัว', 'PDMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('เถอะ', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('กว้างใหญ่', 'NPRP', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กำลังดี', 'NPRP', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('เบาะ', 'NCMN', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('นั่ง', 'VACT', 'O'),
#  ('ชิวๆ', 'NCMN', 'O'),
#  ('อาบ', 'NCMN', 'O'),
#  ('แสงแดด', 'NCMN', 'O'),
#  ('แบบ', 'NCMN', 'O'),
#  ('ส่วนตัว', 'VATT', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อีก', 'DDBQ', 'O'),
#  ('หนึ่ง', 'DCNM', 'O'),
#  ('จุดเด่น', 'CNIT', 'O'),
#  ('คือ', 'VSTA', 'O'),
#  ('จาก', 'RPRE', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('เดินทาง', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ที่', 'RPRE', 'O'),
#  ('ชายหาด', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เลย', 'ADVN', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ยังกับ', 'RPRE', 'O'),
#  ('ชายหาด', 'NCMN', 'O'),
#  ('ส่วนตัว', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('เอง', 'PDMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('คง', 'XVBM', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('อะไร', 'PNTR', 'O'),
#  ('ดี', 'VATT', 'O'),
#  ('เท่ากับ', 'JCMP', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('สระน้ำ', 'NCMN', 'O'),
#  ('ส่วนตัว', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  ('ส่วนตัว', 'VATT', 'O'),
#  ('ตรงหน้า', 'ADVN', 'O'),
#  ('ที่พัก', 'NCMN', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('แล้ว', 'JSBR', 'O'),
#  ('ล่ะ', 'VACT', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('ห้องพัก', 'NCMN', 'O'),
#  ('เสร็จ', 'VSTA', 'O'),
#  ('แล้ว', 'XVAE', 'O'),
#  ('มัน', 'PPRS', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เริ่ม', 'VSTA', 'O'),
#  ('หิว', 'NCMN', 'O'),
#  ('หน่อย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('งั้น', 'NCMN', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ไป', 'VACT', 'O'),
#  ('ลุย', 'NCMN', 'O'),
#  ('ห้องอาหาร', 'NCMN', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เมนู', 'NCMN', 'O'),
#  ('แนะนำ', 'VACT', 'O'),
#  ('เลย', 'ADVN', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผัดไทย', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อันนี้', 'JSBR', 'O'),
#  ('ปลาหมึก', 'NCMN', 'O'),
#  ('แดดเดียว', 'DIAC', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('อร่อย', 'XVBM', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('แพ้', 'VSTA', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ครับ', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ส่วน', 'CLTV', 'O'),
#  ('อันนี้', 'DDAC', 'O'),
#  ('ข้าวคลุกกะปิ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เอาเป็นว่า', 'JSBR', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('ขอ', 'VACT', 'O'),
#  ('เอ่ยถึง', 'VACT', 'O'),
#  ('ละ', 'VACT', 'O'),
#  ('กัน', 'ADVN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('555', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('และ', 'JCRG', 'O'),
#  ('เมนู', 'NCMN', 'O'),
#  ('ซี๊ด', 'NCMN', 'O'),
#  ('ๆคอ', 'NCMN', 'O'),
#  ('หมู', 'NCMN', 'O'),
#  ('ย่าง', 'VATT', 'O'),
#  ('มะนาว', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('อิ่ม', 'VACT', 'O'),
#  ('ท้อง', 'XVMM', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('มา', 'VACT', 'O'),
#  ('ชม', 'NCMN', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('รอบ', 'CFQC', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ห้องอาหาร', 'NCMN', 'O'),
#  ('ต่อ', 'RPRE', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เสียดาย', 'NCMN', 'O'),
#  ('วันที่', 'NCMN', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ผนตก', 'NCMN', 'O'),
#  ('โปรย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('ได้', 'XVAM', 'O'),
#  ('นั่ง', 'VACT', 'O'),
#  ('ด้านนอก', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เกือบ', 'DIBQ', 'O'),
#  ('ลืม', 'VSTA', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ที่นี่', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('BBQ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('กิน', 'VACT', 'O'),
#  ('ฟรี', 'NCMN', 'O'),
#  ('คนละ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('1', 'DCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ไม้', 'CMTR', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('ฮ่า', 'NCMN', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เนื่องจาก', 'JSBR', 'O'),
#  ('คืนนี้', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ฝน', 'NCMN', 'O'),
#  ('โปรย', 'NCMN', 'O'),
#  ('ลงมา', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('อด', 'NCMN', 'O'),
#  ('นั่ง', 'NCMN', 'O'),
#  ('ชิ', 'NCMN', 'O'),
#  ('ว', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('บาร์', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('รีสอร์ท', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('เมื่อ', 'JSBR', 'O'),
#  ('บรรยากาศ', 'NCMN', 'O'),
#  ('แบบนี้', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('กลับมา', 'VACT', 'O'),
#  ('นั่ง', 'RPRE', 'O'),
#  ('ชิ', 'NCMN', 'O'),
#  ('ว', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ห้อง', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สบาย', 'NCMN', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('คะแนน', 'NCMN', 'O'),
#  ('สำหรับ', 'RPRE', 'O'),
#  ('ทริป', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('สถาน', 'NCMN', 'O'),
#  ('ที', 'DONM', 'O'),
#  ('โดยรวม', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  (':', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('10', 'NCNM', 'O'),
#  ('/', 'PUNC', 'O'),
#  ('10', 'NCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ที่พัก', 'CNIT', 'O'),
#  ('สะอาด', 'NCMN', 'O'),
#  ('ถึงแม้', 'JSBR', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เปิด', 'VACT', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('นาน', 'ADVN', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('การ', 'FIXN', 'O'),
#  ('ดูแล', 'VACT', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('อย่างนี้', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('สระว่ายน้ำ', 'NCMN', 'O'),
#  ('ส่วนตัว', 'VATT', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('มองเห็น', 'VACT', 'O'),
#  ('ทะเล', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สามารถ', 'XVAM', 'O'),
#  ('จอด', 'VACT', 'O'),
#  ('รถ', 'NCMN', 'O'),
#  ('หน้า', 'VATT', 'O'),
#  ('บ้านพัก', 'NCMN', 'O'),
#  ('ได้', 'XVAE', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('อันนี้', 'ADVS', 'O'),
#  ('ชอบ', 'VSTA', 'O'),
#  ('มาก', 'ADVN', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('บอก', 'VACT', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('ว่าที่', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('อันดับ', 'NCMN', 'O'),
#  ('หนึ่ง', 'DCNM', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('ใจ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ณ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ตอน', 'NCMN', 'O'),
#  ('เลย', 'XVAE', 'O'),
#  ('จริงๆ', 'ADVI', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ด้าน', 'NCMN', 'O'),
#  ('บริการ', 'VACT', 'O'),
#  (' ', 'PUNC', 'O'),
#  (':', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('8', 'NCNM', 'O'),
#  ('/', 'PUNC', 'O'),
#  ('10', 'NCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('พนักงานต้อนรับ', 'VACT', 'O'),
#  ('น่ารัก', 'NCMN', 'O'),
#  ('ดี', 'VATT', 'O'),
#  ('ครับ', 'RPRE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แนะนำ', 'VACT', 'O'),
#  ('ทุกอย่าง', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ทั้ง', 'JCRG', 'O'),
#  ('ตอน', 'NCMN', 'O'),
#  ('เช็ค', 'VACT', 'O'),
#  ('อิน', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('และ', 'JCRG', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เช็ค', 'VACT', 'O'),
#  ('ท์เอ้า', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('พนักงาน', 'NCMN', 'O'),
#  ('ห้องอาหาร', 'NCMN', 'O'),
#  ('หน้า', 'VATT', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('บึ้ง', 'VSTA', 'O'),
#  ('ๆ', 'NCMN', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('นิด', 'NCMN', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สงสัย', 'NCMN', 'O'),
#  ('งาน', 'NCMN', 'O'),
#  ('วันนั้น', 'NCMN', 'O'),
#  ('เครียด', 'VATT', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ฮ่า', 'NCMN', 'O'),
#  ('ๆๆ', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('สั่งอาหาร', 'NCMN', 'O'),
#  ('มา', 'XVAE', 'O'),
#  ('ทาน', 'NCMN', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ห้องพัก', 'NCMN', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('บวก', 'NCMN', 'O'),
#  ('เพิ่ม', 'VACT', 'O'),
#  ('นะจ๊ะ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ราคา', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  (':', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('8', 'NCNM', 'O'),
#  ('/', 'PUNC', 'O'),
#  ('10', 'NCNM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สำหรับ', 'JSBR', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('แล้ว', 'JSBR', 'O'),
#  ('ราคา', 'NCMN', 'O'),
#  ('ค่อย', 'NCMN', 'O'),
#  ('ข้าง', 'VATT', 'O'),
#  ('สูง', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ถ้า', 'JSBR', 'O'),
#  ('เทียบ', 'VACT', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('การ', 'FIXN', 'O'),
#  ('ให้บริการ', 'VACT', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  ('  ', 'NCMN', 'O'),
#  ('ถ้า', 'JSBR', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('การ', 'FIXN', 'O'),
#  ('ปรับ', 'VACT', 'O'),
#  ('บริการ', 'VACT', 'O'),
#  ('เรื่อง', 'NCMN', 'O'),
#  ('อาหาร', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('มี', 'VSTA', 'O'),
#  ('ห้องอาหาร', 'NCMN', 'O'),
#  ('สวย', 'VATT', 'O'),
#  ('ๆ', 'PUNC', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('อาหาร', 'NCMN', 'O'),
#  ('แนว', 'NCMN', 'O'),
#  ('ฟิวชั่น', 'NCMN', 'O'),
#  ('ขึ้น', 'XVAE', 'O'),
#  ('มา', 'XVAE', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('เต็ม', 'VSTA', 'O'),
#  ('สิบ', 'VACT', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('เล๊ยยยย', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สำหรับ', 'JSBR', 'O'),
#  ('ทริป', 'NCMN', 'O'),
#  ('นี้', 'DDAC', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('อีก', 'ADVN', 'O'),
#  ('หนึ่ง', 'DCNM', 'O'),
#  ('ทริป', 'CMTR', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('ผม', 'PPRS', 'O'),
#  ('ที่', 'PREL', 'O'),
#  ('ราคา', 'NCMN', 'O'),
#  ('ค่อนข้าง', 'ADVN', 'O'),
#  ('สูง', 'VATT', 'O'),
#  ('นะ', 'ADVN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('แต่', 'JCRG', 'O'),
#  ('ก็', 'JSBR', 'O'),
#  ('นะ', 'VACT', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('นานๆ', 'NCMN', 'O'),
#  ('ที', 'DONM', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('ต้อง', 'XVMM', 'O'),
#  ('ใช้ชีวิต', 'VACT', 'O'),
#  ('ให้', 'JSBR', 'O'),
#  ('คุ้มค่า', 'VSTA', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('สนุก', 'NCMN', 'O'),
#  ('กับ', 'RPRE', 'O'),
#  ('การท่องเที่ยว', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('แบบฉบับ', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('เรา', 'PPRS', 'O'),
#  ('เอง', 'PDMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('หวัง', 'VACT', 'O'),
#  ('ว่า', 'JSBR', 'O'),
#  ('รีวิว', 'NCMN', 'O'),
#  ('ครั้งนี้', 'DDAC', 'O'),
#  ('จะ', 'XVBM', 'O'),
#  ('เป็น', 'VSTA', 'O'),
#  ('อีก', 'ADVN', 'O'),
#  ('สถานที่', 'NCMN', 'O'),
#  ('ใน', 'RPRE', 'O'),
#  ('การพักผ่อน', 'NCMN', 'O'),
#  ('ของ', 'RPRE', 'O'),
#  ('สมาชิก', 'NCMN', 'O'),
#  ('ทุกท่าน', 'VACT', 'O'),
#  ('ด้วย', 'RPRE', 'O'),
#  ('นะ', 'NCMN', 'O'),
#  ('ครับ', 'NCMN', 'O'),
#  (' ', 'PUNC', 'O'),
#  ('#', 'NCMN', 'O'),
#  ('เที่ยว', 'VACT', 'O'),
#  ('เมือง', 'NCMN', 'B-LOCATION'),
#  ('ไทย', 'NPRP', 'I-LOCATION'),
#  ('ไม่', 'NEG', 'O'),
#  ('ไป', 'XVAE', 'O'),
#  ('ไม่', 'NEG', 'O'),
#  ('เปลือง', 'VSTA', 'O')]

# %%
df = pd.DataFrame(columns=['dummy'])
df
# Out:
# Empty DataFrame
# Columns: [dummy]
# Index: []

# %%
for data in datatofile:
    df = df.append(data, ignore_index = True)
df
# Out:
#        dummy                            0     1  2
# 0        NaN                           มา  XVAE  O
# 1        NaN                          แย้  VACT  O
# 2        NaN       วววววววววววววววววววววว  NCMN  O
# 3        NaN                               PUNC  O
# 4        NaN                          กับ  RPRE  O
# ...      ...                          ...   ... ..
# 311681   NaN                          พัช  NCMN  O
# 311682   NaN                           มน  NCMN  O
# 311683   NaN                       nhttps  NCMN  O
# 311684   NaN                            :  PUNC  O
# 311685   NaN  wwwfacebookcomOnTheWaySayhi  NCMN  O
#
# [311686 rows x 4 columns]

# %%
df.drop(columns=['dummy'], inplace=True)
df
# Out:
#                                   0     1  2
# 0                                มา  XVAE  O
# 1                               แย้  VACT  O
# 2            วววววววววววววววววววววว  NCMN  O
# 3                                    PUNC  O
# 4                               กับ  RPRE  O
# ...                             ...   ... ..
# 311681                          พัช  NCMN  O
# 311682                           มน  NCMN  O
# 311683                       nhttps  NCMN  O
# 311684                            :  PUNC  O
# 311685  wwwfacebookcomOnTheWaySayhi  NCMN  O
#
# [311686 rows x 3 columns]

# %%
df = df.rename(columns={0: "word", 1: "pos", 2:"target"})
df
# Out:
#                                word   pos target
# 0                                มา  XVAE      O
# 1                               แย้  VACT      O
# 2            วววววววววววววววววววววว  NCMN      O
# 3                                    PUNC      O
# 4                               กับ  RPRE      O
# ...                             ...   ...    ...
# 311681                          พัช  NCMN      O
# 311682                           มน  NCMN      O
# 311683                       nhttps  NCMN      O
# 311684                            :  PUNC      O
# 311685  wwwfacebookcomOnTheWaySayhi  NCMN      O
#
# [311686 rows x 3 columns]

# %%
features = list(df.columns[:2])
features
# Out:
# ['word', 'pos']

# %%
#Train the model
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=500,
    all_possible_transitions=True,
    model_filename=file_name+"-pos.model0" # ตั้งชื่อโมเดล
)

# %%
kf3 = KFold(n_splits=3, shuffle=False)
i = 1
for test_index, train_index in kf3.split(df):
    X_train = df.iloc[train_index].loc[:, features]
    X_test = df.iloc[test_index][features]
    y_train = df.iloc[train_index].loc[:,'target']
    y_test = df.loc[test_index]['target']
    print(X_train.shape, y_train.shape)
    
    crf.fit(X_train, y_train) #Training the model
#     print(f"Accuracy for the fold no. {i} on the test set: {accuracy_score(y_test, crf.predict(X_test))}")
#     i += 1
# Out:
# (103896, 2) (103896,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7926b7ae0d32> in <module>
#       8     print(X_train.shape, y_train.shape)
#       9
# ---> 10     crf.fit(X_train, y_train) #Training the model
#      11 #     print(f"Accuracy for the fold no. {i} on the test set: {accuracy_score(y_test, crf.predict(X_test))}")
#      12 #     i += 1
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn_crfsuite/estimator.py in fit(self, X, y, X_dev, y_dev)
#     312
#     313         for xseq, yseq in train_data:
# --> 314             trainer.append(xseq, yseq)
#     315
#     316         if self.verbose:
#
# pycrfsuite/_pycrfsuite.pyx in pycrfsuite._pycrfsuite.BaseTrainer.append()
#
# ValueError: The numbers of items and labels differ: |x| = 4, |y| = 1

# %%
print(train_index, test_index)
# Out:
# [     0      1      2 ... 103893 103894 103895] [103896 103897 103898 ... 311683 311684 311685]

# %%
print(X_train.shape, y_train.shape)
# Out:
# (103896, 2) (103896,)

# %%
print(X_train)
print(y_train)
# Out:
#                           word   pos
# 0                           มา  XVAE
# 1                          แย้  VACT
# 2       วววววววววววววววววววววว  NCMN
# 3                               PUNC
# 4                          กับ  RPRE
# ...                        ...   ...
# 103891                       ^  PUNC
# 103892                       V  NCMN
# 103893                       ^  PUNC
# 103894                       n  NCMN
# 103895                       (  PUNC
#
# [103896 rows x 2 columns]
# 0         O
# 1         O
# 2         O
# 3         O
# 4         O
#          ..
# 103891    O
# 103892    O
# 103893    O
# 103894    O
# 103895    O
# Name: target, Length: 103896, dtype: object

# %%
print(X_test)
print(y_test)
# Out:
#                                word   pos
# 103896                           GI  NCMN
# 103897                               NCMN
# 103898                 Geographical  NCMN
# 103899                               PUNC
# 103900                   Indication  NCMN
# ...                             ...   ...
# 311681                          พัช  NCMN
# 311682                           มน  NCMN
# 311683                       nhttps  NCMN
# 311684                            :  PUNC
# 311685  wwwfacebookcomOnTheWaySayhi  NCMN
#
# [207790 rows x 2 columns]
# 103896    O
# 103897    O
# 103898    O
# 103899    O
# 103900    O
#          ..
# 311681    O
# 311682    O
# 311683    O
# 311684    O
# 311685    O
# Name: target, Length: 207790, dtype: object

# %%
print("Train Index: ", train_index, "\n")
print("Test Index: ", test_index)
# Out:
# Train Index:  [     0      1      2 ... 103893 103894 103895]
#
# Test Index:  [103896 103897 103898 ... 311683 311684 311685]
