# %%
file_name="unseen_withTag02" # ชื่อไฟล์คลังข้อมูล
import codecs
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from nltk.tokenize import RegexpTokenizer
from sklearn_crfsuite import scorers,metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_validate,train_test_split, cross_val_predict
import sklearn_crfsuite
import pandas as pd
import numpy as np
import csv
import pickle
import glob
import nltk
import re

# %%
#จัดการประโยคซ้ำ
data_not=[]
def Unique(p):
 text=re.sub("<[^>]*>","",p)
 text=re.sub("\[(.*?)\]","",text)
 text=re.sub("\[\/(.*?)\]","",text)
 if text not in data_not:
  data_not.append(text)
  return True
 else:
  return False
# เตรียมตัวตัด tag ด้วย re
pattern = r'\[(.*?)\](.*?)\[\/(.*?)\]'
tokenizer = RegexpTokenizer(pattern) # ใช้ nltk.tokenize.RegexpTokenizer เพื่อตัด [TIME]8.00[/TIME] ให้เป็น ('TIME','ไง','TIME')

# %%
# จัดการกับ tag ที่ไม่ได้ tag
def toolner_to_tag(text):
 text=text.strip()
 text=re.sub("<[^>]*>","",text)
 text=re.sub("(\[\/(.*?)\])","\\1***",text)#.replace('(\[(.*?)\])','***\\1')#  ตัดการกับพวกไม่มี tag word
 text=re.sub("(\[\w+\])","***\\1",text)
 text2=[]
 for i in text.split('***'):
  if "[" in i:
   text2.append(i)
  else:
   text2.append("[word]"+i+"[/word]")
 text="".join(text2)#re.sub("[word][/word]","","".join(text2))
 return text.replace("[word][/word]","")
# แปลง text ให้เป็น conll2002
def text2conll2002(text,pos=True):
    """
    ใช้แปลงข้อความให้กลายเป็น conll2002
    """
    text=toolner_to_tag(text) # นำไปใส่ tag [word]
    text=text.replace("''",'"')
    text=text.replace("’",'"').replace("‘",'"')#.replace('"',"")
    tag=tokenizer.tokenize(text) # แยก tag ออกมาจากข้อความ
    j=0
    conll2002="" # ประกาศตัวแปรเก็บ conll2002
    for tagopen,text,tagclose in tag: # ลูปใน tag โดยเป็น (tagopen,text,tagclose)
        word_cut=word_tokenize(text,engine="newmm") # ใช้ตัวตัดคำ newmm ของ PyThaiNLP
        i=0
        txt5=""
        while i<len(word_cut): #ลูปตามจำนวน token ที่ตัดในtag
            if word_cut[i]=="''" or word_cut[i]=='"':pass
            elif i==0 and tagopen!='word': # ไม่เป็น tag [word] และเป็น i หรือตัวเริ่มต้น tag
                txt5+=word_cut[i]
                txt5+='\t'+'B-'+tagopen
            elif tagopen!='word':
                txt5+=word_cut[i]
                txt5+='\t'+'I-'+tagopen
            else: # เป็น [word]
                txt5+=word_cut[i]
                txt5+='\t'+'O'
            txt5+='\n'
            #j+=1
            i+=1
        conll2002+=txt5
    if pos==False:
        return conll2002
    return postag(conll2002) # เพิ่ม postag ใส่
# ใช้สำหรับกำกับ pos tag เพื่อใช้กับ NER
# print(text2conll2002(t,pos=False))
def postag(text):
    listtxt=[i for i in text.split('\n') if i!='']
    list_word=[]
    for data in listtxt:
        list_word.append(data.split('\t')[0])
    #print(text)
    list_word=pos_tag(list_word,engine="perceptron")
    text=""
    i=0
    for data in listtxt:
        text+=data.split('\t')[0]+'\t'+list_word[i][1]+'\t'+data.split('\t')[1]+'\n'
        i+=1
    return text
# อ่านข้อมูลจากไฟล์
def get_data(fileopen):
	"""
    สำหรับใช้อ่านทั้งหมดทั้งในไฟล์ทีละรรทัดออกมาเป็น list
    """
	with codecs.open(fileopen, 'r',encoding='utf-8-sig') as f:
		lines = f.read().splitlines()
	return [a for a in lines if Unique(a)] # เอาไม่ซ้ำกัน

def alldata(lists):
    text=""
    for data in lists:
        text+=text2conll2002(data)
        text+='\n'
    return text

def alldata_list(lists):
    data_all=[]
    for data in lists:
        data_num=[]
        try:
            txt=text2conll2002(data,pos=True).split('\n') # นำไปแปลงเป็น conll2002
            for d in txt:
                tt=d.split('\t')
                if d!="":
                    if len(tt)==3:
                        data_num.append((tt[0],tt[1],tt[2]))
                    else:
                        data_num.append((tt[0],tt[1]))
            #print(data_num)
            data_all.append(data_num)
        except:
            print(data)
    #print(data_all)
    return data_all

def alldata_list_str(lists):
	string=""
	for data in lists:
		string1=""
		for j in data:
			string1+=j[0]+"	"+j[1]+"	"+j[2]+"\n"
		string1+="\n"
		string+=string1
	return string

def get_data_tag(listd):
	list_all=[]
	c=[]
	for i in listd:
		if i !='':
			c.append((i.split("\t")[0],i.split("\t")[1],i.split("\t")[2]))
		else:
			list_all.append(c)
			c=[]
	return list_all
def getall(lista):
    ll=[]
    for i in lista:
        o=True
        for j in ll:
            if re.sub("\[(.*?)\]","",i)==re.sub("\[(.*?)\]","",j):
                o=False
                break
        if o==True:
            ll.append(i)
    return ll

# %%
data1=getall(get_data(file_name+".txt")) # นำคลังเข้าไป แยกออกเป็น list ละบรรทัด
datatofile=alldata_list(data1) # นำไปผ่านขั้นตอน 1 2 3 4

# %%
print(len(datatofile))
print(datatofile[0][:10])
# Out:
# 10
# [('สวัสดี', 'NCMN', 'O'), ('เพื่อน', 'NCMN', 'O'), ('ๆ', 'PUNC', 'O'), ('ครับ', 'NCMN', 'O'), (' ', 'PUNC', 'O'), ('ทริป', 'NCMN', 'O'), ('นี้', 'DDAC', 'O'), ('ไม่', 'NEG', 'O'), ('ได้', 'XVAM', 'O'), ('เตรียมตัว', 'VACT', 'O')]

# %%
datatofile
# Out:
# [[('สวัสดี', 'NCMN', 'O'),
#   ('เพื่อน', 'NCMN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทริป', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('เตรียมตัว', 'VACT', 'O'),
#   ('นาน', 'ADVN', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('ข้อมูล', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จอง', 'NCMN', 'O'),
#   ('ตัว', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('อาทิตย์', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ร่วม', 'VACT', 'O'),
#   ('กลุ่ม', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('คน', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('วัน', 'NCMN', 'O'),
#   ('จันทร์', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('15', 'DCNM', 'O'),
#   ('กันยา', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('เชียงใหม่', 'VACT', 'B-LOCATION'),
#   ('กัน', 'ADVN', 'O'),
#   ('วัน', 'NCMN', 'O'),
#   ('ศุกร์', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('19', 'DCNM', 'O'),
#   ('กันยา', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อันดับ', 'NCMN', 'O'),
#   ('แรก', 'DONM', 'O'),
#   ('ต้องหา', 'VACT', 'O'),
#   ('ตั๋ว', 'NCMN', 'O'),
#   ('เครื่องบิน', 'NCMN', 'O'),
#   ('ก่อน', 'ADVN', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ข้อมูล', 'NCMN', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('บิน', 'VACT', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ผม', 'PPRS', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ตาม', 'RPRE', 'O'),
#   ('รีวิว', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('http', 'NCMN', 'O'),
#   (':', 'PUNC', 'O'),
#   ('pantip', 'NCMN', 'O'),
#   ('.', 'PUNC', 'O'),
#   ('comtopic', 'NCMN', 'O'),
#   ('32617156', 'NCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('ตั๋ว', 'VACT', 'O'),
#   ('เครื่องบิน', 'NCMN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รีบ', 'VACT', 'O'),
#   ('เขียน', 'VACT', 'O'),
#   ('ใบลา', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ลา', 'NCMN', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ชั่วโมง', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ชา', 'NCMN', 'O'),
#   ('วง', 'NCMN', 'O'),
#   ('บ่าย', 'NCMN', 'O'),
#   ('วัน', 'NCMN', 'O'),
#   ('ศุกร์', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('เครื่อง', 'NCMN', 'O'),
#   ('ออก', 'XVAE', 'O'),
#   ('บ่าย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('3', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครึ่ง', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เขียน', 'VACT', 'O'),
#   ('ใบลา', 'VACT', 'O'),
#   ('เรียบร้อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('โรงแรม', 'NCMN', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เอา', 'VACT', 'O'),
#   ('ที่ไหน', 'PNTR', 'O'),
#   ('ดี', 'VATT', 'O'),
#   ('  ', 'NCMN', 'O'),
#   ('ว้าว', 'NCMN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หัวหน้า', 'NCMN', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('วอ', 'NCMN', 'O'),
#   ('เชอ', 'NCMN', 'O'),
#   ('ร์', 'NCMN', 'O'),
#   ('โรง', 'NCMN', 'O'),
#   ('แรง', 'VATT', 'O'),
#   ('ฟรี', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สบาย', 'NCMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ทริป', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('ประหยัด', 'VACT', 'O'),
#   ('ค่า', 'NCMN', 'O'),
#   ('โรง', 'NCMN', 'O'),
#   ('แม', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อิอิ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต่อไป', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('ข้อมูล', 'NCMN', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('รถเช่า', 'NCMN', 'O'),
#   ('มอเตอร์ไซค์', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อ่าน', 'VACT', 'O'),
#   ('รีวิว', 'NCMN', 'O'),
#   ('เก่าๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('ไหน', 'PNTR', 'O'),
#   ('ดี', 'VATT', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('ล่ะ', 'VACT', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('bikkychiangmai', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โทร', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ถาม', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ราคา', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สรุป', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   ('รถ', 'VACT', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('รุ่น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('KSR', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('2', 'DCNM', 'O'),
#   ('คัน', 'CNIT', 'O'),
#   ('ละ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('400', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('MSX', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('1', 'DCNM', 'O'),
#   ('คัน', 'CNIT', 'O'),
#   ('ละ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('500', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('PCX', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('คัน', 'CNIT', 'O'),
#   ('ละ', 'RPRE', 'O'),
#   ('600', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('เหลือ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('500', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จัดการ', 'VACT', 'O'),
#   ('โอน', 'VACT', 'O'),
#   ('เงิน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('1800', 'DCNM', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   ('รถ', 'VACT', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('มีค่า', 'VSTA', 'O'),
#   ('มัดจำ', 'NCMN', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('นะ', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต่อรอง', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ค่า', 'NCMN', 'O'),
#   ('มัดจำ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('คัน', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('5000', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทาง', 'RPRE', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โอเค', 'NCMN', 'O'),
#   ('ร', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จัดการ', 'VACT', 'O'),
#   ('เรื่อง', 'NCMN', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('เรียบร้อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต่อไป', 'ADVN', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เป็นการ', 'VACT', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('ข้อมูล', 'NCMN', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เส้นทาง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่จะ', 'JSBR', 'O'),
#   ('ขี่', 'VACT', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('อินทนนท์', 'NPRP', 'I-LOCATION'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพื่อน', 'NCMN', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   ('พร้อม', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บิด', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('พวกเรา', 'NCMN', 'O'),
#   ('หรือยัง', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พร้อม', 'JCRG', 'O'),
#   ('แล้วก็', 'JCRG', 'O'),
#   ('ลุย', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ยยยยยยยยยยยยย', 'ADVN', 'O'),
#   ('  ', 'NCMN', 'O'),
#   ('ติดตาม', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('กิน', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่เที่ยว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพิ่มเติม', 'VSTA', 'O'),
#   ('ได้ที่', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('https', 'NCMN', 'O'),
#   (':', 'PUNC', 'O'),
#   ('www', 'NCMN', 'O'),
#   ('.', 'PUNC', 'O'),
#   ('facebook', 'NCMN', 'O'),
#   ('.', 'PUNC', 'O'),
#   ('comKHATANGKLONG', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('http', 'NCMN', 'O'),
#   (':', 'PUNC', 'O'),
#   ('instagram', 'NCMN', 'O'),
#   ('.', 'PUNC', 'O'),
#   ('comronnarong', 'NCMN', 'O'),
#   ('1325', 'NCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('เชียงใหม่', 'NPRP', 'B-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('พวกเรา', 'NPRP', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('นั่ง', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('แดง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('สนามบิน', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ที่', 'RPRE', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('bikkychiangmai', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('เอา', 'VACT', 'O'),
#   ('มอเตอร์ไซค์', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('จอง', 'VACT', 'O'),
#   ('ไว้', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ครับ', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('(', 'PUNC', 'O'),
#   ('นั่ง', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('แดง', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('bikkychiangmai', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ตอนแรก', 'NCMN', 'O'),
#   ('ลุง', 'NCMN', 'O'),
#   ('คนขับ', 'NCMN', 'O'),
#   ('บอก', 'VACT', 'O'),
#   ('คนละ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('50', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('เหลือ', 'VSTA', 'O'),
#   ('คนละ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('40', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   ('ครับ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อิอิ', 'NCMN', 'O'),
#   (')', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('bikkychiangmai', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อยู่', 'VSTA', 'O'),
#   ('ตรง', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถ.', 'NCMN', 'B-LOCATION'),
#   ('ห้วย', 'RPRE', 'I-LOCATION'),
#   ('แก้ว', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('กาด', 'VACT', 'B-LOCATION'),
#   ('สวน', 'NCMN', 'I-LOCATION'),
#   ('แก้ว', 'NCMN', 'I-LOCATION'),
#   ('ไป', 'XVAE', 'O'),
#   ('ทาง', 'RPRE', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('อินทนนท์', 'NPRP', 'I-LOCATION'),
#   ('ไป', 'XVAE', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('400', 'DCNM', 'O'),
#   ('เมตร', 'CMTR', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ปล.', 'NCMN', 'O'),
#   ('ทาง', 'NCMN', 'O'),
#   ('ร้าน', 'NCMN', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ยึด', 'VACT', 'O'),
#   ('บัตรประชาชน', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ผู้เช่า', 'NCMN', 'O'),
#   ('ไว้', 'XVAE', 'O'),
#   ('นะ', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เค้า', 'NCMN', 'O'),
#   ('ให้เหตุผล', 'VSTA', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('หาย', 'NCMN', 'O'),
#   ('บ่อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('เค้า', 'NCMN', 'O'),
#   ('ถ่ายเอกสาร', 'VACT', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('  ', 'NCMN', 'O'),
#   ('เช่า', 'NCMN', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ยนตร์', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('สนามบิน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เค้า', 'NCMN', 'O'),
#   ('ยัง', 'XVBM', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ยึด', 'VACT', 'O'),
#   ('บัตรประชาชน', 'NCMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นี่', 'PDMN', 'O'),
#   ('มอเตอร์ไซค์', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ยึด', 'VACT', 'O'),
#   ('บัตร', 'NCMN', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แอบ', 'NCMN', 'O'),
#   ('อา', 'NCMN', 'O'),
#   ('รม', 'NCMN', 'O'),
#   ('เสีย', 'VSTA', 'O'),
#   ('นิดหน่อย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จับกลุ่ม', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('คน', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ่น', 'NCMN', 'O'),
#   ('ๆๆๆๆๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('5555', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พนักงาน', 'NCMN', 'O'),
#   ('เอา', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ให้', 'VACT', 'O'),
#   ('แล้ว', 'ADVN', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ตรวจ', 'VACT', 'O'),
#   ('สภาพ', 'NCMN', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('รอย', 'NCMN', 'O'),
#   ('ตรงไหน', 'PNTR', 'O'),
#   ('บ้าง', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถ่ายรูป', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('รถ', 'VACT', 'O'),
#   ('แล้วก็', 'NCMN', 'O'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('ลุย', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อันดับ', 'NCMN', 'O'),
#   ('แรก', 'DONM', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ไปหา', 'VACT', 'O'),
#   ('ขนม', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('กันที่', 'JSBR', 'O'),
#   ('ร้าน', 'NCMN', 'B-RESTAURANT'),
#   ('iberry', 'NCMN', 'I-RESTAURANT'),
#   (' ', 'PUNC', 'O'),
#   ('อยู่', 'VSTA', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('ซอย', 'NCMN', 'B-LOCATION'),
#   ('นิมมาน', 'DDAN', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('17', 'DCNM', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เสร็จ', 'VSTA', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('เต็ม', 'VSTA', 'O'),
#   ('น้ำมัน', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ก่อน', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ร้าน', 'NCMN', 'B-RESTAURANT'),
#   ('iberry', 'NCMN', 'I-RESTAURANT'),
#   (' ', 'PUNC', 'O'),
#   ('อยู่', 'VSTA', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('ซอย', 'NCMN', 'B-LOCATION'),
#   ('นิมมาน', 'DDAN', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('17', 'DCNM', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กิน', 'VACT', 'O'),
#   ('เสร็จ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('โรงแรม', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('พรุ่งนี้', 'JSBR', 'O'),
#   ('งานหนัก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('ตื่น', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ตี', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พร้อมกัน', 'ADVN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('05.30', 'NCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('.น', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ล้อหมุน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('ตะลุย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พิชิต', 'NCMN', 'O'),
#   ('ยอด', 'NCMN', 'O'),
#   ('ดอน', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ยย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ทาง', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อ.', 'NCMN', 'B-LOCATION'),
#   ('จอม', 'VACT', 'I-LOCATION'),
#   ('ทอง', 'NCMN', 'I-LOCATION'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   ('40', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กิโล', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('เรื่อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('เยอะ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อากาศ', 'NCMN', 'O'),
#   ('เย็นสบาย', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใกล้', 'VATT', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('อ.', 'NCMN', 'B-LOCATION'),
#   ('จอม', 'VACT', 'I-LOCATION'),
#   ('ทอง', 'NCMN', 'I-LOCATION'),
#   ('ล่ะ', 'NCMN', 'O'),
#   ('แวะ', 'NCMN', 'O'),
#   ('พัก', 'NCMN', 'O'),
#   ('แป', 'NCMN', 'O'),
#   ('ป', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('ตอนเช้า', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พระอาทิตย์', 'NPRP', 'O'),
#   ('กำลัง', 'XVBM', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('ฝน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โชคดี', 'NCMN', 'O'),
#   ('สุด', 'ADVN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('เดินทาง', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('2', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ชม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มาถึง', 'VSTA', 'O'),
#   ('ปั้มน้ำมัน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก่อนที่จะ', 'JSBR', 'O'),
#   ('เลี้ยวขวา', 'VACT', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ดอย', 'RPRE', 'B-LOCATION'),
#   ('อินทนนท์', 'NCMN', 'I-LOCATION'),
#   ('แวะ', 'NCMN', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('ห้องน้ำ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กิน', 'VACT', 'O'),
#   ('กาแฟ', 'NCMN', 'O'),
#   ('ซ่ะ', 'NCMN', 'O'),
#   ('หน่อย', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แล้ว', 'JSBR', 'O'),
#   ('ค่อย', 'XVAM', 'O'),
#   ('ลุย', 'VATT', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ปา', 'VACT', 'O'),
#   ('เข้าไป', 'XVAE', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('9', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โมง', 'CMTR', 'O'),
#   ('ล่ะ', 'NCMN', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('กาแฟ', 'VACT', 'O'),
#   ('รู้สึก', 'NCMN', 'O'),
#   ('สดชื่น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('ลุย', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ออกจาก', 'JSBR', 'O'),
#   ('ปั้ม', 'NCMN', 'O'),
#   ('เลี้ยวขวา', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('ดอย', 'ADVN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ได', 'VACT', 'O'),
#   ('สักพัก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เจอ', 'VACT', 'O'),
#   ('ด่าน', 'NCMN', 'O'),
#   ('ตรวจ', 'VACT', 'O'),
#   ('ที่', 'PREL', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('1', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เสีย', 'VSTA', 'O'),
#   ('ค่า', 'NCMN', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('คนละ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('40', 'DCNM', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   ('ครับ', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จ่าย', 'VACT', 'O'),
#   ('เงิน', 'NCMN', 'O'),
#   ('เสร็จ', 'VSTA', 'O'),
#   ('เรียบร้อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ให้', 'VACT', 'O'),
#   ('เจ้าหน้าที่', 'NCMN', 'O'),
#   ('อุทยาน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถ่ายรูป', 'VACT', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('ซ่ะ', 'NCMN', 'O'),
#   ('หน่อย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อิอิ', 'NCMN', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรียบร้อย', 'VSTA', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   ('ทางขึ้น', 'ADVN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ชัน', 'NCMN', 'O'),
#   ('เท่าไร', 'PNTR', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('สบาย', 'VATT', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อากาศ', 'NCMN', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เย็นสบาย', 'VACT', 'O'),
#   ('nnn', 'NCMN', 'O'),
#   ('   ', 'NCMN', 'O'),
#   ('ในที่สุด', 'ADVS', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ขี่', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   ('ครึ่งทาง', 'NCMN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ท้องฟ้า', 'NCMN', 'O'),
#   ('สวย', 'VATT', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('กก', 'VACT', 'O'),
#   ('กก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แวะ', 'NCMN', 'O'),
#   ('พัก', 'NCMN', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถ่ายรูป', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('แป', 'NCMN', 'O'),
#   ('ป', 'NCMN', 'O'),
#   ('นึ่ง', 'DIAC', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถ่ายรูป', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กระโด', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เหนื่อย', 'ADVN', 'O'),
#   ('ล่ะ', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ลุย', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('หนทาง', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('ยาว', 'VATT', 'O'),
#   ('ไกล', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('แวะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ปก', 'NCMN', 'I-LOCATION'),
#   ('เปีย', 'VACT', 'I-LOCATION'),
#   ('ง', 'NCMN', 'I-LOCATION'),
#   ('กัน', 'ADVN', 'O'),
#   ('ก่อน', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ไปดู', 'VACT', 'O'),
#   ('นา', 'NCMN', 'O'),
#   ('คั้น', 'NCMN', 'O'),
#   ('บันได', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขี่', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ต่อไป', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ผ่าน', 'VSTA', 'O'),
#   ('จุด', 'NCMN', 'O'),
#   ('ตรวจ', 'VACT', 'O'),
#   ('ที่', 'PREL', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('2', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('50', 'DCNM', 'O'),
#   ('เมตร', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เตรียมตัว', 'VSTA', 'O'),
#   ('เลี่ยว', 'VACT', 'O'),
#   ('ซ้าย', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ปก', 'NCMN', 'I-LOCATION'),
#   ('เปีย', 'NCMN', 'I-LOCATION'),
#   ('ง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หนทาง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พูด', 'VACT', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สุด', 'ADVN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถนน', 'NCMN', 'O'),
#   ('ลื่น', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('หลุม', 'NCMN', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('บ่อ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ผลสุดท้าย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ติด', 'VSTA', 'O'),
#   ('ล่ม', 'VSTA', 'O'),
#   ('จนได้', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('5555', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ช่วย', 'VACT', 'O'),
#   ('ๆๆๆๆ', 'NCMN', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('ทุกคน', 'NCMN', 'O'),
#   ('ยัง', 'XVBM', 'O'),
#   ('สู้', 'NCMN', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   ('  ', 'NCMN', 'O'),
#   ('หนทาง', 'NCMN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ใช่', 'VSTA', 'O'),
#   ('อุป', 'NCMN', 'O'),
#   ('สรรค์', 'NCMN', 'O'),
#   ('nnn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ในที่สุด', 'ADVS', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('มา', 'XVBM', 'O'),
#   ('เห็น', 'VSTA', 'O'),
#   ('นา', 'NCMN', 'O'),
#   ('คั้น', 'NCMN', 'O'),
#   ('บันได', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ซ่ะ', 'NCMN', 'O'),
#   ('ที', 'DONM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทำเอา', 'DONM', 'O'),
#   ('ล้า', 'VSTA', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('เหมือนกัน', 'VSTA', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('เส้นทาง', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('แสน', 'VACT', 'O'),
#   ('ทรหด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('n', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('nn', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เสพ', 'NCMN', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('ทุ่งนา', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ปา', 'VACT', 'O'),
#   ('เข้าไป', 'XVAE', 'O'),
#   ('เกือบ', 'DIBQ', 'O'),
#   ('เที่ยงวัน', 'NCMN', 'O'),
#   ('ล่ะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ท้อง', 'NCMN', 'O'),
#   ('เริ่ม', 'VSTA', 'O'),
#   ('ร้อง', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('งั้น', 'NCMN', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('ต่อกัน', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ...],
#  [('เดินทาง', 'VACT', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('แม่', 'NCMN', 'I-LOCATION'),
#   ('ส', 'NCMN', 'I-LOCATION'),
#   ('ลอง', 'NCMN', 'I-LOCATION'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   ('บ่ายโมง', 'DCNM', 'O'),
#   ('กว่า', 'JCMP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ตาม', 'RPRE', 'O'),
#   ('เส้นทาง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('1089', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('เส้นทาง', 'NCMN', 'O'),
#   ('หมายเลข', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('107', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('มุ่งหน้า', 'VSTA', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ที่', 'RPRE', 'O'),
#   ('ทางขึ้น', 'VSTA', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('อ่างขาง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ซึ่ง', 'JSBR', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('ผ่าน', 'VACT', 'O'),
#   ('อำเภอ', 'NCMN', 'B-LOCATION'),
#   ('แม่', 'NCMN', 'I-LOCATION'),
#   ('อาย', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('อำเภอ', 'NCMN', 'B-LOCATION'),
#   ('วชิรปราการ', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('อำเภอ', 'NCMN', 'B-LOCATION'),
#   ('ฝาง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เขต', 'NCMN', 'O'),
#   ('จังหวัด', 'NCMN', 'B-LOCATION'),
#   ('เชียงใหม่', 'NPRP', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ระยะทาง', 'NCMN', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เกือบ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('90', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กะ', 'VSTA', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('เดินทาง', 'ADVN', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เกือบ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สอง', 'DCNM', 'O'),
#   ('ชั่วโมง', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ขับ', 'VACT', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('เรื่อย ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โชเฟอร์', 'NCMN', 'O'),
#   ('มือ', 'NCMN', 'O'),
#   ('เดียว', 'DIAC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('การพักผ่อน', 'VACT', 'O'),
#   ('น้อย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อาศัย', 'VSTA', 'O'),
#   ('จอด', 'NCMN', 'O'),
#   ('พัก', 'VACT', 'O'),
#   ('เป็นช่วง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ระหว่าง', 'RPRE', 'O'),
#   ('ทางผ่าน', 'NCMN', 'O'),
#   ('สวน', 'NCMN', 'B-LOCATION'),
#   ('ส้ม', 'NCMN', 'I-LOCATION'),
#   ('ธนา', 'NCMN', 'I-LOCATION'),
#   ('ธร', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ซึ่ง', 'JSBR', 'O'),
#   ('มีชื่อเสียง', 'NCMN', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('เจ้า', 'NCMN', 'O'),
#   ('ใหญ่', 'VATT', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ทาง', 'NCMN', 'O'),
#   ('ภาคเหนือ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แวะ', 'NCMN', 'O'),
#   ('เที่ยว', 'VACT', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('ชะโงก', 'NCMN', 'O'),
#   ('ทัวร์', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('หาก', 'JSBR', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('เที่ยว', 'VACT', 'O'),
#   ('ชม', 'NCMN', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('ครบ', 'VSTA', 'O'),
#   ('ตาม', 'RPRE', 'O'),
#   ('แพ็กเกจ', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ทาง', 'NCMN', 'O'),
#   ('สวน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ใช้เวลานาน', 'VSTA', 'O'),
#   ('กว่า', 'JCMP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('45', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นาที', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ซึ่ง', 'JSBR', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('จำกัด', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จึง', 'XVBM', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('แค่', 'VACT', 'O'),
#   ('ช็อบ', 'NCMN', 'O'),
#   ('ปิ้ง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('แล้วก็', 'JCRG', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('มาถึง', 'VACT', 'O'),
#   ('คิวรถ', 'NCMN', 'O'),
#   ('ที่จะ', 'JSBR', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('เหมา', 'VACT', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('อ่างขาง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('กล้า', 'VACT', 'O'),
#   ('ขับรถ', 'NCMN', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('เอง', 'PDMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เคย', 'XVMM', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ครั้งแรก', 'ADVN', 'O'),
#   ('เมื่อ', 'RPRE', 'O'),
#   ('ปี', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('2548', 'NCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วัด', 'VACT', 'O'),
#   ('กำลัง', 'NCMN', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('คง', 'XVBM', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ไหว', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('มา', 'VACT', 'O'),
#   ('ติดต่อ', 'VACT', 'O'),
#   ('ตกลง', 'VACT', 'O'),
#   ('ราคา', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('ได้ที่', 'JSBR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('1500', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บาท', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เหมาจ่าย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('แค่', 'DDBQ', 'O'),
#   ('สอง', 'DCNM', 'O'),
#   ('คน', 'CNIT', 'O'),
#   ('ต้องการ', 'VACT', 'O'),
#   ('ความเป็นส่วนตัว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไหน ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ติดต่อ', 'VACT', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ถามหา', 'VACT', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   ('ราคา', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('7', 'DCNM', 'O'),
#   ('-', 'PUNC', 'O'),
#   ('8', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ร้อย', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็ได้', 'EAFF', 'O'),
#   ('พัก', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('รีสอร์ท', 'NCMN', 'O'),
#   ('แห่ง', 'CNIT', 'O'),
#   ('หนึ่ง', 'DCNM', 'O'),
#   ('จำ', 'VACT', 'O'),
#   ('ชื่อ', 'NCMN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   ('ต้น', 'NCMN', 'O'),
#   ('ไผ่', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กอ', 'NCMN', 'O'),
#   ('ไผ่', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ช่วง', 'NCMN', 'O'),
#   ('นั้น', 'DDAC', 'O'),
#   ('ตะวัน', 'VACT', 'O'),
#   ('ใกล้', 'DIAC', 'O'),
#   ('ลับ', 'VACT', 'O'),
#   ('ฟ้า', 'NCMN', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('เพลีย', 'NCMN', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('แรง', 'ADVN', 'O'),
#   ('ที่จะ', 'JSBR', 'O'),
#   ('ถ่าย', 'VACT', 'O'),
#   ('สภาพ', 'NCMN', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กินข้าว', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('รีสอร์ท', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อาบน้ำ', 'NCMN', 'O'),
#   ('หลับ', 'NCMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('รีบ', 'VACT', 'O'),
#   ('นอน', 'NCMN', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('นัด', 'VACT', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('มา', 'VACT', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('ตี', 'RPRE', 'O'),
#   ('สี่', 'DCNM', 'O'),
#   ('ครึ่ง', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('รีสอร์ท', 'NCMN', 'O'),
#   ('ที่ตั้ง', 'JCRG', 'O'),
#   ('ใกล้', 'VATT', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('ทางขึ้น', 'NCMN', 'O'),
#   ('ดอย', 'NCMN', 'B-LOCATION'),
#   ('อ่างขาง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ครั้น', 'DDAC', 'O'),
#   ('พอ', 'ADVN', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('อาบน้ำ', 'NCMN', 'O'),
#   ('แต่งตัว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('โทร', 'NCMN', 'O'),
#   ('ติดต่อ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อ้าว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('คุณ', 'PPRS', 'O'),
#   ('ลุง', 'NPRP', 'O'),
#   ('นอน', 'VATT', 'O'),
#   ('เพลิน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เกือบ', 'DIBQ', 'O'),
#   ('ลืม', 'NCMN', 'O'),
#   ('ลูกค้า', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('เกือบจะ', 'VACT', 'O'),
#   ('ตีห้า', 'NCMN', 'O'),
#   ('แห', 'NCMN', 'O'),
#   ('น่ะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ลุง', 'NCMN', 'O'),
#   ('แก', 'NCMN', 'O'),
#   ('รับประกัน', 'VSTA', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('ทันเวลา', 'VSTA', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('จุดชมวิว', 'NCMN', 'O'),
#   ('ตะวันขึ้น', 'VSTA', 'O'),
#   ('แน่นอน', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ทัน', 'VSTA', 'O'),
#   ('เวลาจริง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขอบคุณ', 'VACT', 'O'),
#   ('คุณ', 'PPRS', 'O'),
#   ('ลุง', 'VATT', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จำ', 'VACT', 'O'),
#   ('ชื่อ', 'NCMN', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ณ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จุดชมวิว', 'NCMN', 'B-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'RPRE', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('ดอย', 'NCMN', 'I-LOCATION'),
#   ('อ่างขาง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ระยะทาง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('25', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('ครึ่ง', 'DCNM', 'O'),
#   ('ชั่วโมง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โชคดี', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   ('ฟ้า', 'NCMN', 'O'),
#   ('เปิด', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เห็น', 'VSTA', 'O'),
#   ('ดวงจันทร์', 'NPRP', 'O'),
#   ('เสี้ยว', 'NCMN', 'O'),
#   ('เล็ก', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขวามือ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ท้องฟ้า', 'NCMN', 'O'),
#   ('เป็นใจ', 'NCMN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทริป', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ค่อนข้าง', 'ADVN', 'O'),
#   ('โชคดี', 'NCMN', 'O'),
#   ('ตั้งแต่', 'RPRE', 'O'),
#   ('ภู', 'NCMN', 'B-LOCATION'),
#   ('ชี้ฟ้า', 'NCMN', 'I-LOCATION'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ฟ้าสาง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ตลาด', 'NCMN', 'O'),
#   ('เช้า', 'NCMN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('ชาวดอย', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('เปิด', 'VACT', 'O'),
#   ('ท้าย', 'NCMN', 'O'),
#   ('ขายของ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('5555', 'NCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('บรรยากาศ', 'VACT', 'O'),
#   ('อีก', 'ADVN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ช็อปปิ้ง', 'VACT', 'O'),
#   ('ตั้ง', 'VACT', 'O'),
#   ('นาน', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('สินค้า', 'NCMN', 'O'),
#   ('ถุงมือ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หมวก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บอก', 'VACT', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('อากาศ', 'NCMN', 'O'),
#   ('หนาวเย็น', 'NCMN', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สัมผัส', 'VACT', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('เต็มอิ่ม', 'VACT', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   ('ครับ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แหม่', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มุม', 'NCMN', 'O'),
#   ('กล้อง', 'NCMN', 'O'),
#   ('ใช้ได้', 'XVAE', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ทีเดียว', 'ADVN', 'O'),
#   ('เชียว', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ยืน', 'VACT', 'O'),
#   ('ห่าง', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('พอควร', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('พี่', 'NCMN', 'O'),
#   ('แก', 'VACT', 'O'),
#   ('หันขวับ', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('พอดี', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('ที่นี่', 'ADVN', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('เวลา', 'NCMN', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('07.00', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('น.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สถานี', 'NCMN', 'O'),
#   ('ต่อไป', 'DDAC', 'O'),
#   ('จุดชมวิว', 'NCMN', 'B-LOCATION'),
#   ('ชายแดน', 'NCMN', 'I-LOCATION'),
#   ('ไทย', 'NPRP', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('-', 'PUNC', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('พม่า', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('นอ', 'NCMN', 'I-LOCATION'),
#   ('แล', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ชาวเขา', 'NCMN', 'O'),
#   ('เผ่า', 'VACT', 'O'),
#   ('ปะ', 'NCMN', 'O'),
#   ('ห', 'NCMN', 'O'),
#   ('ร่อง', 'NCMN', 'O'),
#   ('(', 'PUNC', 'O'),
#   ('เชื้อสาย', 'NCMN', 'O'),
#   ('พม่า', 'NCMN', 'O'),
#   (')', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วันนี้', 'NCMN', 'O'),
#   ('แห', 'NCMN', 'O'),
#   ('ล่ะ', 'NCMN', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('เห็น', 'VACT', 'O'),
#   ('ของจริง', 'NCMN', 'O'),
#   ('ซะ', 'NCMN', 'O'),
#   ('ที', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('ได้ยิน', 'NCMN', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('ข่าว', 'NCMN', 'O'),
#   ('โทรทัศน์', 'NCMN', 'O'),
#   ('ช่วง', 'NCMN', 'O'),
#   ('หนึ่ง', 'DCNM', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('สงคราม', 'NCMN', 'O'),
#   ('ระหว่าง', 'RPRE', 'O'),
#   ('พม่า', 'NCMN', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ไทยใหญ่', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หมู่บ้าน', 'NCMN', 'B-LOCATION'),
#   ('นอ', 'NCMN', 'I-LOCATION'),
#   ('แล', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('พลอย', 'NCMN', 'O'),
#   ('ได้รับ', 'VSTA', 'O'),
#   ('ผลกระทบ', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ระยะ', 'NCMN', 'O'),
#   ('าง', 'NCMN', 'O'),
#   ('ห่าง', 'VATT', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('จุด', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('เดินทาง', 'RPRE', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('10', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นาที', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('นอ', 'NCMN', 'I-LOCATION'),
#   ('แล', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ประชาชน', 'NCMN', 'O'),
#   ('ส่วนใหญ่', 'DDAN', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ชาวเขา', 'NCMN', 'O'),
#   ('เผ่า', 'VACT', 'O'),
#   ('ปะ', 'NCMN', 'O'),
#   ('ห', 'NCMN', 'O'),
#   ('ร่อง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('เชื้อสาย', 'NCMN', 'O'),
#   ('พม่า', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เนิน', 'NCMN', 'O'),
#   ('นั่น', 'PDMN', 'O'),
#   ('คือ', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ฐานทัพ', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('กองกำลัง', 'NCMN', 'O'),
#   ('ทหาร', 'NCMN', 'O'),
#   ('พม่า', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไม้', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('แทง', 'VACT', 'O'),
#   ('ล้อมรอบ', 'ADVN', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('มา', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ด้านล่าง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('น้อง ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทหาร', 'NCMN', 'O'),
#   ('ไทย', 'NPRP', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('รักษา', 'VACT', 'O'),
#   ('ดินแดน', 'NCMN', 'O'),
#   ('อยู่', 'XVAE', 'O'),
#   ('ด้านล่าง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นี่', 'NCMN', 'O'),
#   ('อีก', 'DDBQ', 'O'),
#   ('ฝั่ง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('ประทับ', 'VACT', 'O'),
#   ('สมเด็จ', 'NCMN', 'O'),
#   ('พระ', 'NCMN', 'O'),
#   ('เทพ', 'VACT', 'O'),
#   ('ฯ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เมื่อ', 'JSBR', 'O'),
#   ('พระองค์', 'NCMN', 'O'),
#   ('เสด็จพระราชดำเนิน', 'NCMN', 'O'),
#   ('พระราชกรณียกิจ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทริป', 'NCMN', 'O'),
#   ('นี้', 'DDAC', 'O'),
#   ('เลาะ', 'VACT', 'O'),
#   ('ตะเข็บ', 'NCMN', 'O'),
#   ('ชายแดน', 'NCMN', 'O'),
#   ('จริง ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จากนั้น', 'JSBR', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('ต่อ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขับ', 'VACT', 'O'),
#   ('ย้อน', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ที่', 'RPRE', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'VATT', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ไปเที่ยว', 'NCMN', 'O'),
#   ('ชม', 'NCMN', 'O'),
#   ('สวน', 'NCMN', 'O'),
#   ('สตรอเบอรี', 'VSTA', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('นอ', 'NCMN', 'I-LOCATION'),
#   ('แล', 'NCMN', 'I-LOCATION'),
#   ('ขาออก', 'NCMN', 'O'),
#   ('ครับ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ระยะทาง', 'NCMN', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('นอ', 'NCMN', 'I-LOCATION'),
#   ('แล', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('-', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เกือบ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('4', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('เดินทาง', 'RPRE', 'O'),
#   ('ประมาณ', 'DIBQ', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('8', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นาที', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ระหว่างทาง', 'NCMN', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ภาพ', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('หา', 'VACT', 'O'),
#   ('ดู', 'VACT', 'O'),
#   ('ยาก', 'ADVN', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('โชคดี', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วันนี้', 'NCMN', 'O'),
#   ('ยัง', 'XVBM', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('วันทำการ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('โรงเรียน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('น้อง ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('เดินเท้า', 'VACT', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('โรงเรียน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('-', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กลับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('8', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('กม.', 'CMTR', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นี่', 'PDMN', 'O'),
#   ('ถ้า', 'JSBR', 'O'),
#   ('ส่งเสริม', 'VACT', 'O'),
#   ('ด้าน', 'NCMN', 'O'),
#   ('การกีฬา', 'NCMN', 'O'),
#   ('ดี ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('น้อง ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('นัก', 'NCMN', 'O'),
#   ('วิ่งมาราธอน', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ชาติ', 'NCMN', 'O'),
#   ('ไทย', 'NPRP', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('นะเนี่ย', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('แล้ว', 'JSBR', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   ('โรงเรียน', 'NCMN', 'B-LOCATION'),
#   ('บ้าน', 'NCMN', 'I-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('บ้าน', 'NCMN', 'I-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ชาวเขา', 'NCMN', 'O'),
#   ('เผ่า', 'VACT', 'O'),
#   ('มูเซอ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ครู', 'NCMN', 'O'),
#   ('บรรจุ', 'VACT', 'O'),
#   ('ใหม่', 'ADVN', 'O'),
#   ('ท่าน', 'PPRS', 'O'),
#   ('ใด', 'DIAC', 'O'),
#   ('สนใจ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บ้านพัก', 'NCMN', 'O'),
#   ('มั่นคงแข็งแรง', 'NCMN', 'O'),
#   ('น่าอยู่', 'VSTA', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   ('5555', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สงสัย', 'CNIT', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   ('กลับบ้าน', 'NCMN', 'O'),
#   ('เทอม', 'NCMN', 'O'),
#   ('ละ', 'RPRE', 'O'),
#   ('ครั้ง', 'CFQC', 'O'),
#   ('แน่', 'NCMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('จอด', 'VACT', 'O'),
#   ('รถ', 'NCMN', 'O'),
#   ('ข้าง ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('โรงเรียน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('เดิน', 'VACT', 'O'),
#   ('ชม', 'NCMN', 'O'),
#   ('สวน', 'NCMN', 'O'),
#   ('สตรอเบอรี', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('ช่วง', 'NCMN', 'O'),
#   ('เช้า', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แดด', 'NCMN', 'O'),
#   ('กำลัง', 'XVBM', 'O'),
#   ('อุ่น', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขากลับ', 'NCMN', 'O'),
#   ('โชคดี', 'NCMN', 'O'),
#   ('อีกแล้ว', 'DIAC', 'O'),
#   ('ครับ', 'VACT', 'O'),
#   ('ท่าน', 'PPRS', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('เห็น', 'VSTA', 'O'),
#   ('วิถีชีวิต', 'NCMN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('ดั้งเดิม', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('สมัย', 'NCMN', 'O'),
#   ('เด็ก', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('เคย', 'XVMM', 'O'),
#   ('ทำ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('ปัจจุบัน', 'NCMN', 'O'),
#   ('เด็ก', 'NCMN', 'O'),
#   ('รุ่นใหม่', 'VATT', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('มีโอกาส', 'VSTA', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('เห็น', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('สำหรับ', 'RPRE', 'O'),
#   ('ชาวเขา', 'NCMN', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'VATT', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ยังคง', 'XVBM', 'O'),
#   ('ใช้ชีวิต', 'VSTA', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('ดั้งเดิม', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วิธีการ', 'NCMN', 'O'),
#   ('ตำ', 'VACT', 'O'),
#   ('ข้าว', 'NCMN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('โบราณ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('วิถีชีวิต', 'NCMN', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('จัดฉาก', 'NCMN', 'O'),
#   ('เพื่อ', 'RPRE', 'O'),
#   ('การท่องเที่ยว', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เด็ก', 'NCMN', 'O'),
#   ('เล่น', 'VACT', 'O'),
#   ('ของเล่น', 'NCMN', 'O'),
#   ('อย่าง', 'FIXV', 'O'),
#   ('มีความสุข', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ก่อไฟ', 'NCMN', 'O'),
#   ('ทำครัว', 'NCMN', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('บ้าน', 'NCMN', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('เลย', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นักเรียน', 'NCMN', 'O'),
#   ('ช่วยกัน', 'VACT', 'O'),
#   ('ทำความสะอาด', 'NCMN', 'O'),
#   ('โรงเรียน', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('คง', 'XVBM', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   ('เขา', 'PPRS', 'O'),
#   ('เข้าแถว', 'VACT', 'O'),
#   ('เคารพ', 'NCMN', 'O'),
#   ('ธงชาติ', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จริง ๆ', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อยาก', 'XVMM', 'O'),
#   ('อยู่', 'VSTA', 'O'),
#   ('ฟัง', 'NCMN', 'O'),
#   ('การร้อง', 'NCMN', 'O'),
#   ('เพลงชาติ', 'NCMN', 'O'),
#   ('จัง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('สำเนียง', 'NCMN', 'O'),
#   ('เหมือน', 'VSTA', 'O'),
#   ('นักเรียน', 'NCMN', 'O'),
#   ('พื้นราบ', 'VACT', 'O'),
#   ('รึเปล่า', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เสียดาย', 'NCMN', 'O'),
#   ('จัง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ออกจาก', 'JSBR', 'O'),
#   ('บ้าน', 'NCMN', 'B-LOCATION'),
#   ('ขอบ', 'NCMN', 'I-LOCATION'),
#   ('ด้ง', 'VATT', 'I-LOCATION'),
# ...
#   ('เฟี้ยวฟ้าว', 'VATT', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มัน', 'PPRS', 'O'),
#   ('ไว', 'NCMN', 'O'),
#   ('จน', 'JSBR', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('จับ', 'VACT', 'O'),
#   ('ทุกสิ่ง', 'FIXN', 'O'),
#   ('อย่าง', 'VACT', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('มั่น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('ห่วง', 'NCMN', 'O'),
#   ('ความปลอดภัย', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ตัวเอง', 'PDMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('แชะ', 'VACT', 'O'),
#   ('ภาพ', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ฝาก', 'VACT', 'O'),
#   ('คะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('><', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('รูปหน้า', 'NCMN', 'O'),
#   ('ทาง', 'NCMN', 'O'),
#   ('เข้าที่', 'NCMN', 'O'),
#   ('พี่', 'NCMN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   ('เค้า', 'NCMN', 'O'),
#   ('คอย', 'VACT', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('นักท่องเที่ยว', 'NCMN', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('ระยะไกล', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('ป้าย', 'NCMN', 'O'),
#   ('ต้อนรับ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('Welcome', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('to', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('Koh', 'NCMN', 'B-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('Lipe', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('Walking', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'I-LOCATION'),
#   ('Street', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('หลี', 'NCMN', 'B-LOCATION'),
#   ('เป๊ะ', 'NCMN', 'I-LOCATION'),
#   ('ไม่', 'NEG', 'O'),
#   ('ยาก', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('สมบุกสมบัน', 'VACT', 'O'),
#   ('ใน', 'RPRE', 'O'),
#   ('ระดับ', 'NCMN', 'O'),
#   ('นึง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('หลังจาก', 'JSBR', 'O'),
#   ('ลง', 'VACT', 'O'),
#   ('เครื่อง', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('หาดใหญ่', 'NPRP', 'B-LOCATION'),
#   ('(', 'PUNC', 'I-LOCATION'),
#   ('สงขลา', 'NPRP', 'I-LOCATION'),
#   (')', 'PUNC', 'I-LOCATION'),
#   ('ปุ๊บ', 'NPRP', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('นั่ง', 'VACT', 'O'),
#   ('รถสองแถว', 'NCMN', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ที่', 'RPRE', 'O'),
#   ('ตลาด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรียก', 'VACT', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('ตลาด', 'NCMN', 'B-LOCATION'),
#   ('เกษตร', 'NCMN', 'I-LOCATION'),
#   ('แต่', 'JCRG', 'O'),
#   ('มัน', 'PPRS', 'O'),
#   ('คือ', 'VSTA', 'O'),
#   ('สถานีขนส่ง', 'NCMN', 'O'),
#   ('ชัด', 'ADVN', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อย่า', 'NCMN', 'O'),
#   ('เข้าใจ', 'VSTA', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ตลาด', 'NCMN', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('ชื่อ', 'NCMN', 'O'),
#   ('ตลาด', 'NCMN', 'B-LOCATION'),
#   ('เกษตร', 'NCMN', 'I-LOCATION'),
#   ('นะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จากนั้น', 'JSBR', 'O'),
#   ('ต่อ', 'VACT', 'O'),
#   ('รถตู้', 'NCMN', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('ตลาด', 'NCMN', 'B-LOCATION'),
#   ('เกษตร', 'NCMN', 'I-LOCATION'),
#   ('ไป', 'XVAE', 'O'),
#   ('ลง', 'VACT', 'O'),
#   ('ท่าเรือ', 'NCMN', 'B-LOCATION'),
#   ('ปาก', 'NCMN', 'I-LOCATION'),
#   ('บา', 'NCMN', 'I-LOCATION'),
#   ('รา', 'NCMN', 'I-LOCATION'),
#   ('(', 'PUNC', 'I-LOCATION'),
#   ('สตูล', 'NCMN', 'I-LOCATION'),
#   (')', 'PUNC', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ขึ้น', 'VACT', 'O'),
#   ('สปีด', 'NCMN', 'O'),
#   ('โบ๊ท', 'NCMN', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('ท่าเรือ', 'NCMN', 'B-LOCATION'),
#   ('ปาก', 'NCMN', 'I-LOCATION'),
#   ('บา', 'NCMN', 'I-LOCATION'),
#   ('รา', 'VACT', 'I-LOCATION'),
#   ('ไป', 'XVAE', 'O'),
#   ('ยัง', 'RPRE', 'O'),
#   ('เกาะ', 'NCMN', 'B-LOCATION'),
#   ('หลี', 'NCMN', 'I-LOCATION'),
#   ('เป๊ะ', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('เดี๋ยวก่อน', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พอ', 'VSTA', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('เกาะ', 'NCMN', 'B-LOCATION'),
#   ('หลี', 'NCMN', 'I-LOCATION'),
#   ('เป๊ะ', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('เมา', 'VACT', 'O'),
#   ('น้ำมันเครื่อง', 'NCMN', 'O'),
#   ('เรือหางยาว', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('คอย', 'VACT', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('ส่ง', 'VACT', 'O'),
#   ('นักท่องเที่ยว', 'NCMN', 'O'),
#   ('อยู่', 'XVAE', 'O'),
#   ('ใกล้', 'RPRE', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('สปีด', 'NCMN', 'O'),
#   ('โบ๊ท', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ขับ', 'VACT', 'O'),
#   ('เข้าไป', 'XVAE', 'O'),
#   ('ไม', 'NCMN', 'O'),
#   ('ได้', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('มัน', 'PPRS', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ทำลาย', 'VACT', 'O'),
#   ('แนวปะการัง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('(คห', 'NCMN', 'O'),
#   ('สต.', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ใช่', 'VSTA', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('ทำ', 'VACT', 'O'),
#   ('ลายอย่าง', 'NCMN', 'O'),
#   ('เดียว', 'DCNM', 'O'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('เรือหางยาว', 'VSTA', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ต่างกัน', 'VSTA', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ช่วง', 'NCMN', 'O'),
#   ('ที่นั่ง', 'DONM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรือ', 'NCMN', 'O'),
#   ('เข้าใกล้', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('น้ำทะเล', 'NCMN', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('ใส', 'VATT', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('แนวปะการัง', 'NCMN', 'O'),
#   ('ใกล้', 'VATT', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เสียหาย', 'VSTA', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('เยอะ', 'NCMN', 'O'),
#   ('เหมือนกัน', 'ADVN', 'O'),
#   (')', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นี่', 'PDMN', 'O'),
#   ('คือ', 'VSTA', 'O'),
#   ('โป๊ะ', 'NCMN', 'O'),
#   ('กลาง', 'VATT', 'O'),
#   ('ทะเล', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('ขึ้นไป', 'VSTA', 'O'),
#   ('รอ', 'VSTA', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('เรือหางยาว', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('ชาวเล', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('รับ', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'B-LOCATION'),
#   ('พัทยา', 'NCMN', 'I-LOCATION'),
#   ('บีช', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('บน', 'RPRE', 'O'),
#   ('โป๊ะ', 'NCMN', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'B-LOCATION'),
#   ('พัทยา', 'NCMN', 'I-LOCATION'),
#   ('บีช', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('โซน', 'NCMN', 'O'),
#   ('ขาย', 'VACT', 'O'),
#   ('ตั๋ว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('บน', 'RPRE', 'O'),
#   ('โป๊ะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ค่อนข้าง', 'ADVN', 'O'),
#   ('วุ่นวาย', 'VACT', 'O'),
#   ('ทีเดียว', 'DCNM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ขึ้นไป', 'VACT', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('คน', 'NCMN', 'O'),
#   ('แรก', 'DONM', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ถ่าย', 'VACT', 'O'),
#   ('ทัน', 'NCMN', 'O'),
#   ('ตอนที่', 'RPRE', 'O'),
#   ('ยัง', 'XVBM', 'O'),
#   ('ไม่ค่อย', 'XVAM', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('นักท่องเที่ยว', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พอ', 'JSBR', 'O'),
#   ('นักท่องเที่ยว', 'VACT', 'O'),
#   ('หลั่งไหล', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('บน', 'RPRE', 'O'),
#   ('โป๊ะ', 'NCMN', 'O'),
#   ('กลาง', 'VATT', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('เดียว', 'DCNM', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('หลากหลาย', 'NCMN', 'O'),
#   ('เรือ', 'NCMN', 'O'),
#   ('สปีด', 'NCMN', 'O'),
#   ('โบ๊ท', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('เสียว', 'XVBM', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('โป๊ะ', 'NCMN', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('รับ', 'VACT', 'O'),
#   ('น้ำหนัก', 'NCMN', 'O'),
#   ('ไหว', 'NCMN', 'O'),
#   ('มั้ย', 'NCMN', 'O'),
#   ('นะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('อยาก', 'NCMN', 'O'),
#   ('ลง', 'XVAE', 'O'),
#   ('เรือหางยาว', 'NCMN', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('บน', 'RPRE', 'O'),
#   ('เกาะ', 'NCMN', 'O'),
#   ('เร็ว', 'ADVN', 'O'),
#   ('ๆ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จัง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ฮ่า', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ทิวทัศน์', 'NCMN', 'O'),
#   ('ก่อน', 'RPRE', 'O'),
#   ('เข้า', 'VACT', 'O'),
#   ('ฝั่ง', 'VACT', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'B-LOCATION'),
#   ('พัทยา', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('สัง', 'VACT', 'O'),
#   ('เกตุ', 'NCMN', 'O'),
#   ('เห็น', 'VSTA', 'O'),
#   ('เรือหางยาว', 'NCMN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('กำลัง', 'XVBM', 'O'),
#   ('ขับ', 'VACT', 'O'),
#   ('เรือ', 'NCMN', 'O'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('ส่ง', 'VACT', 'O'),
#   ('นักท่องเที่ยว', 'NCMN', 'O'),
#   ('ออกจาก', 'JSBR', 'O'),
#   ('เกาะ', 'VACT', 'O'),
#   ('ขับ', 'VACT', 'O'),
#   ('สวน', 'NCMN', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ระหว่างทาง', 'VSTA', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ท่าเรือ', 'VACT', 'B-LOCATION'),
#   ('ปาก', 'NCMN', 'I-LOCATION'),
#   ('บา', 'NCMN', 'I-LOCATION'),
#   ('รา', 'VACT', 'I-LOCATION'),
#   ('สู่', 'RPRE', 'O'),
#   ('เกาะ', 'NCMN', 'B-LOCATION'),
#   ('หลี', 'NCMN', 'I-LOCATION'),
#   ('เป๊ะ', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ทางเรือ', 'NCMN', 'O'),
#   ('แวะ', 'NCMN', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('นักท่องเที่ยว', 'VSTA', 'O'),
#   ('ลง', 'XVAE', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('ถ่ายรูป', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ณ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เกาะ', 'NCMN', 'B-LOCATION'),
#   ('ไข่', 'NCMN', 'I-LOCATION'),
#   (' ', 'PUNC', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('ความ', 'FIXN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('อยาก', 'XVMM', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('หลี', 'NCMN', 'B-LOCATION'),
#   ('เป๊ะ', 'NCMN', 'I-LOCATION'),
#   ('จะ', 'XVBM', 'O'),
#   ('แย่', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('อิดโรย', 'NCMN', 'O'),
#   ('จาก', 'RPRE', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('หลาย', 'DIBQ', 'O'),
#   ('ทอด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('เลย', 'XVBM', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('ได้', 'XVAM', 'O'),
#   ('ชื่นชม', 'VACT', 'O'),
#   ('ทัศนียภาพ', 'NCMN', 'O'),
#   ('หรือ', 'JCRG', 'O'),
#   ('ถ่ายรูป', 'VACT', 'O'),
#   ('จุด', 'NCMN', 'O'),
#   ('แลนด์', 'NCMN', 'O'),
#   ('มาร์ค', 'NCMN', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ลงเรือ', 'VACT', 'O'),
#   ('สักหน่อย', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ไป', 'XVAE', 'O'),
#   ('แชะ', 'VACT', 'O'),
#   ('ภาพ', 'NCMN', 'O'),
#   ('คู่', 'CLTV', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('น้ำทะเล', 'NCMN', 'O'),
#   ('สักนิด', 'NCMN', 'O'),
#   ('เป็น', 'VSTA', 'O'),
#   ('ออเดิร์ฟ', 'NCMN', 'O'),
#   ('ก่อน', 'RPRE', 'O'),
#   ('ถึง', 'RPRE', 'O'),
#   ('หลี', 'NCMN', 'O'),
#   ('เป๊ะ', 'NCMN', 'O'),
#   ('แบบ', 'NCMN', 'O'),
#   ('แสบตา', 'VACT', 'O'),
#   ('กัน', 'ADVN', 'O'),
#   ('สักนิด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แชะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วัน', 'NCMN', 'O'),
#   ('แรก', 'DONM', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หลังจาก', 'JSBR', 'O'),
#   ('การ', 'FIXN', 'O'),
#   ('เดินทาง', 'VACT', 'O'),
#   ('อัน', 'PREL', 'O'),
#   ('เหน็ดเหนื่อย', 'VATT', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ใช้เวลา', 'VSTA', 'O'),
#   ('ชื่นชม', 'NCMN', 'O'),
#   ('ความงาม', 'NCMN', 'O'),
#   ('เดิน', 'NCMN', 'O'),
#   ('สำรวจ', 'VACT', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   ('อยาก', 'XVMM', 'O'),
#   ('จุใจ', 'VACT', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไป', 'VACT', 'O'),
#   ('นอน', 'ADVN', 'O'),
#   ('เอาแรง', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รอเวลา', 'NCMN', 'O'),
#   ('อาหารค่ำ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('วิว', 'NCMN', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('ร้านอาหาร', 'NCMN', 'O'),
#   ('ติด', 'VSTA', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('ที่พัก', 'NCMN', 'O'),
#   ('ของ', 'RPRE', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ละ', 'RPRE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('รูป', 'NCMN', 'O'),
#   ('หน้าตา', 'NCMN', 'O'),
#   ('อาหาร', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ให้', 'JSBR', 'O'),
#   ('ตาย', 'VSTA', 'O'),
#   ('เถอะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พอ', 'JSBR', 'O'),
#   ('อาหาร', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('วาง', 'VACT', 'O'),
#   ('ตรงหน้า', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ความหิว', 'NCMN', 'O'),
#   ('กระหาย', 'VACT', 'O'),
#   ('ควบคู่', 'VSTA', 'O'),
#   ('กับ', 'RPRE', 'O'),
#   ('บรรยากาศ', 'NCMN', 'O'),
#   ('แสงเทียน', 'NCMN', 'O'),
#   ('ตรงหน้า', 'VSTA', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ก็', 'JSBR', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('สนใจ', 'VSTA', 'O'),
#   ('จะ', 'XVBM', 'O'),
#   ('หยิบ', 'VACT', 'O'),
#   ('จับ', 'VACT', 'O'),
#   ('กล้อง', 'NCMN', 'O'),
#   ('ขึ้น', 'XVAE', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('แชะ', 'ADVN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ไม่', 'NEG', 'O'),
#   ('มี', 'VSTA', 'O'),
#   ('รูป', 'NCMN', 'O'),
#   ('หน้าตา', 'DONM', 'O'),
#   ('อาหาร', 'NCMN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ฝาก', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แทบ', 'ADVN', 'O'),
#   ('ทุก', 'DIBQ', 'O'),
#   ('มื้อ', 'NCMN', 'O'),
#   ('ที่อยู่', 'NCMN', 'O'),
#   ('ที่นั่น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ต้อง', 'XVMM', 'O'),
#   ('ขอโทษ', 'VACT', 'O'),
#   ('จิม', 'NCMN', 'O'),
#   ('ๆ', 'PUNC', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เช้า', 'NCMN', 'O'),
#   ('วันรุ่งขึ้น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('หลังจาก', 'JSBR', 'O'),
#   ('นอน', 'NCMN', 'O'),
#   ('เอาแรง', 'VATT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เรา', 'PPRS', 'O'),
#   ('ตื่น', 'VACT', 'O'),
#   ('แต่เช้า', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('ออกมา', 'XVAE', 'O'),
#   ('สูด', 'VACT', 'O'),
#   ('อากาศ', 'NCMN', 'O'),
#   ('บริสุทธิ์', 'NPRP', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เจอ', 'NPRP', 'O'),
#   ('พี่', 'NCMN', 'O'),
#   ('ดำ', 'VATT', 'O'),
#   ('เจ้าถิ่น', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('นอน', 'NCMN', 'O'),
#   ('อาบแดด', 'NCMN', 'O'),
#   ('อยู่', 'VSTA', 'O'),
#   ('หน้า', 'NCMN', 'O'),
#   ('หาด', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('ความ', 'FIXN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('รู้ตัว', 'VSTA', 'O'),
#   ('ว่า', 'JSBR', 'O'),
#   ('ถูก', 'XVAM', 'O'),
#   ('มอง', 'VACT', 'O'),
#   ('อยู่', 'XVAE', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('พี่', 'NCMN', 'O'),
#   ('แก', 'NCMN', 'O'),
#   ('เลย', 'XVAE', 'O'),
#   ('ลุก', 'ADVN', 'O'),
#   ('มา', 'XVAE', 'O'),
#   ('ทักทาย', 'VACT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ดัง', 'RPRE', 'O'),
#   ('ภาพ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('จริงๆ', 'ADVI', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('เจ้าถิ่น', 'NCMN', 'O'),
#   ('(', 'PUNC', 'O'),
#   ('น้อง', 'NCMN', 'O'),
#   ('หมา', 'NCMN', 'O'),
#   (')', 'PUNC', 'O'),
#   ('ที่นี่', 'NCMN', 'O'),
#   ('ค่อนข้าง', 'ADVN', 'O'),
#   ('เยอะ', 'VATT', 'O'),
#   ('มาก', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ใคร', 'PNTR', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('กลัว', 'VACT', 'O'),
#   ('น้อง', 'NCMN', 'O'),
#   ('หมา', 'NCMN', 'O'),
#   ('ทำใจ', 'VACT', 'O'),
#   ('ไว้', 'XVAE', 'O'),
#   ('นะคะ', 'ADVN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('แต่', 'JCRG', 'O'),
#   ('น้อง', 'NCMN', 'O'),
#   ('ทุก', 'DIBQ', 'O'),
#   ('ตัว', 'CNIT', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('น่ารัก', 'NCMN', 'O'),
#   ('และ', 'JCRG', 'O'),
#   ('ใจ', 'NCMN', 'O'),
#   ('ดีมาก', 'VATT', 'O'),
#   ('คะ', 'NCMN', 'O'),
#   (' ', 'PUNC', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('ความ', 'FIXN', 'O'),
#   ('ที่', 'PREL', 'O'),
#   ('หาด', 'NCMN', 'B-LOCATION'),
#   ('ซัน', 'NCMN', 'I-LOCATION'),
#   ('ไร', 'NCMN', 'I-LOCATION'),
#   ('ส์', 'NCMN', 'I-LOCATION'),
#   ('หรือ', 'JCRG', 'O'),
#   ('หาด', 'NCMN', 'B-LOCATION'),
#   ...]]

# %%
data_label = []
for sentence_no in range(len(datatofile)):
    index = 0
    for item in datatofile[sentence_no]:
        item = list(item)
        item.insert(0, sentence_no+1)
        item.insert(1, index)
        item = tuple(item)
        data_label.append(item)
        index += 1

# %%
len(data_label)
# Out:
# 12713

# %%
data_label[:10]
# Out:
# [(1, 0, 'สวัสดี', 'NCMN', 'O'),
#  (1, 1, 'เพื่อน', 'NCMN', 'O'),
#  (1, 2, 'ๆ', 'PUNC', 'O'),
#  (1, 3, 'ครับ', 'NCMN', 'O'),
#  (1, 4, ' ', 'PUNC', 'O'),
#  (1, 5, 'ทริป', 'NCMN', 'O'),
#  (1, 6, 'นี้', 'DDAC', 'O'),
#  (1, 7, 'ไม่', 'NEG', 'O'),
#  (1, 8, 'ได้', 'XVAM', 'O'),
#  (1, 9, 'เตรียมตัว', 'VACT', 'O')]

# %% [markdown]
# # Merge Label Training Data

# %%
i=0
loc = []
while(i < len(data_label)):
    if(data_label[i][4] == "B-LOCATION"):
        item = []
        item.append(data_label[i][0])
        item.append(data_label[i][1])
        word = data_label[i][2]
        while(data_label[i+1][4] == "I-LOCATION"):
            i += 1
            word += data_label[i][2]
        item.append(word)
        item.append("LOCATION")
        item = tuple(item)
    loc.append(item)
    i += 1

# %%
loc_list = list(dict.fromkeys(loc))
loc_list = loc_list[1:]
loc_list
# Out:
# [(1, 48, 'เชียงใหม่', 'LOCATION'),
#  (1, 281, 'ดอยอินทนนท์', 'LOCATION'),
#  (1, 331, 'เชียงใหม่', 'LOCATION'),
#  (1, 396, 'ถ.ห้วยแก้ว', 'LOCATION'),
#  (1, 401, 'กาดสวนแก้ว', 'LOCATION'),
#  (1, 406, 'ดอยอินทนนท์', 'LOCATION'),
#  (1, 528, 'ซอยนิมมาน 17', 'LOCATION'),
#  (1, 554, 'ซอยนิมมาน 17', 'LOCATION'),
#  (1, 615, 'อ.จอมทอง', 'LOCATION'),
#  (1, 641, 'อ.จอมทอง', 'LOCATION'),
#  (1, 683, 'ดอยอินทนนท์', 'LOCATION'),
#  (1, 848, 'บ้านปกเปียง', 'LOCATION'),
#  (1, 886, 'บ้านปกเปียง', 'LOCATION'),
#  (1, 1174, 'น้ำตกวชิรธาน', 'LOCATION'),
#  (1, 1185, 'เมืองเชียงใหม่', 'LOCATION'),
#  (1, 1189, 'สันป่าตอง', 'LOCATION'),
#  (1, 1310, 'เมืองเชียงใหม่', 'LOCATION'),
#  (2, 2, 'ดอยแม่สลอง', 'LOCATION'),
#  (2, 28, 'ดอยอ่างขาง', 'LOCATION'),
#  (2, 35, 'อำเภอแม่อาย', 'LOCATION'),
#  (2, 39, 'อำเภอวชิรปราการ', 'LOCATION'),
#  (2, 42, 'อำเภอฝาง', 'LOCATION'),
#  (2, 46, 'จังหวัดเชียงใหม่', 'LOCATION'),
#  (2, 95, 'สวนส้มธนาธร', 'LOCATION'),
#  (2, 158, 'ดอยอ่างขาง', 'LOCATION'),
#  (2, 295, 'ดอยอ่างขาง', 'LOCATION'),
#  (2, 361, 'จุดชมวิวขอบด้ง ดอยอ่างขาง', 'LOCATION'),
#  (2, 403, 'ภูชี้ฟ้า', 'LOCATION'),
#  (2, 487, 'จุดชมวิวชายแดนไทย - พม่า', 'LOCATION'),
#  (2, 496, 'บ้านนอแล', 'LOCATION'),
#  (2, 536, 'หมู่บ้านนอแล', 'LOCATION'),
#  (2, 567, 'บ้านนอแล', 'LOCATION'),
#  (2, 654, 'บ้านขอบด้ง', 'LOCATION'),
#  (2, 664, 'บ้านนอแล', 'LOCATION'),
#  (2, 672, 'บ้านนอแล', 'LOCATION'),
#  (2, 678, 'บ้านขอบด้ง', 'LOCATION'),
#  (2, 757, 'โรงเรียนบ้านขอบด้ง บ้านขอบด้ง', 'LOCATION'),
#  (2, 849, 'บ้านขอบด้ง', 'LOCATION'),
#  (2, 921, 'บ้านขอบด้ง', 'LOCATION'),
#  (2, 928, 'สถานีเกษตรหลวงอ่างขาง', 'LOCATION'),
#  (2, 1031, 'สวน 80 พรรษา', 'LOCATION'),
#  (2, 1085, 'อ่างขาง', 'LOCATION'),
#  (2, 1146, 'อำเภอฝาง', 'LOCATION'),
#  (2, 1152, 'บ่อน้ำพุร้อนฝาง', 'LOCATION'),
#  (2, 1179, 'ภูชี้ฟ้า', 'LOCATION'),
#  (2, 1192, 'ดอยผาตั้ง', 'LOCATION'),
#  (2, 1206, 'สามเหลี่ยมทองคำ', 'LOCATION'),
#  (2, 1211, 'แม่สาย', 'LOCATION'),
#  (2, 1224, 'ดอยตุง', 'LOCATION'),
#  (2, 1229, 'ดอยแม่สลอง', 'LOCATION'),
#  (2, 1247, 'ดอยอ่างขาง', 'LOCATION'),
#  (2, 1250, 'อำเภอฝาง', 'LOCATION'),
#  (2, 1257, 'อำเภอฝาง', 'LOCATION'),
#  (2, 1335, 'เชียงใหม่', 'LOCATION'),
#  (2, 1337, 'พระธาตุดอยสุเทพ', 'LOCATION'),
#  (2, 1348, 'เมืองเชียงใหม่', 'LOCATION'),
#  (2, 1351, 'สนามบินนานาชาติเชียงใหม่', 'LOCATION'),
#  (2, 1365, 'อำเภอสันป่าตอง', 'LOCATION'),
#  (2, 1373, 'ดอยอินทนนท์', 'LOCATION'),
#  (2, 1382, 'ดอยอินทนนท์', 'LOCATION'),
#  (2, 1385, 'ดอยอินทนนท์', 'LOCATION'),
#  (3, 19, 'สถานีพระนครศรีอยุธยา', 'LOCATION'),
#  (3, 145, 'ตลาดเจ้าพรหม', 'LOCATION'),
#  (3, 320, 'อยุธยา', 'LOCATION'),
#  (3, 345, 'วงเวียนเจดีย์', 'LOCATION'),
#  (3, 439, 'อยุธยา', 'LOCATION'),
#  (3, 447, 'วัดใหญ่ชัยมงคล', 'LOCATION'),
#  (3, 454, 'วัดป่าแก้ว', 'LOCATION'),
#  (3, 458, 'วัดเจ้าพระยาไท', 'LOCATION'),
#  (3, 467, 'แม่น้ำป่าสัก', 'LOCATION'),
#  (3, 516, 'วัดใหญ่ชัยมงคล', 'LOCATION'),
#  (3, 553, 'ตำบลหนองสาหร่าย เมืองสุพรรณบุรี', 'LOCATION'),
#  (3, 577, 'พระเจดีย์ชัยมงคล', 'LOCATION'),
#  (3, 586, 'จังหวัดพระนครศรีอยุธยา', 'LOCATION'),
#  (4, 0, 'ก ร ะ บี่', 'LOCATION'),
#  (4, 112, 'อ่าวนาง', 'LOCATION'),
#  (4, 116, 'ท่าเรืออ่าวน้ำเมา', 'LOCATION'),
#  (4, 129, 'ไร่เลย์', 'LOCATION'),
#  (4, 167, 'เกาะปอดะ', 'LOCATION'),
#  (4, 172, 'ทะเลแหวก', 'LOCATION'),
#  (4, 178, 'ทะเลแหวก', 'LOCATION'),
#  (4, 208, 'ทะเลแหวก', 'LOCATION'),
#  (4, 213, 'เกาะไก่', 'LOCATION'),
#  (4, 224, 'ทะเลแหวก', 'LOCATION'),
#  (4, 265, 'เกาะปอดะ', 'LOCATION'),
#  (4, 318, 'ปอดะ', 'LOCATION'),
#  (4, 382, 'เกาะปอดะ', 'LOCATION'),
#  (4, 755, 'กระบี่', 'LOCATION'),
#  (5, 27, 'ปราณบุรี', 'LOCATION'),
#  (5, 139, 'ภูทับเบิก', 'LOCATION'),
#  (5, 183, 'ปราณบุรี', 'LOCATION'),
#  (5, 254, 'ภูทับเบิก', 'LOCATION'),
#  (5, 636, 'ปราณบุรี', 'LOCATION'),
#  (5, 662, 'ปราณบุรี', 'LOCATION'),
#  (5, 777, 'ปราณบุรี', 'LOCATION'),
#  (5, 792, 'แม่น้ำปราณ', 'LOCATION'),
#  (5, 1016, 'ปราณบุรี', 'LOCATION'),
#  (5, 1031, 'วัดคลองโคน', 'LOCATION'),
#  (5, 1357, 'ปราณบุรี', 'LOCATION'),
#  (6, 23, 'สังขละบุรี', 'LOCATION'),
#  (6, 51, 'สังขละบุรี', 'LOCATION'),
#  (6, 116, 'สังขละบุรี', 'LOCATION'),
#  (6, 124, 'สังขละบุรี', 'LOCATION'),
#  (6, 132, 'สังขละบุรี', 'LOCATION'),
#  (6, 164, 'สะพานมอญ', 'LOCATION'),
#  (6, 175, 'ประเทศไทย', 'LOCATION'),
#  (6, 190, 'สังขละ', 'LOCATION'),
#  (6, 201, 'วัดใต้น้ำ', 'LOCATION'),
#  (6, 205, 'สังขละบุรี', 'LOCATION'),
#  (6, 265, 'อ.สังขละบุรี', 'LOCATION'),
#  (6, 284, 'สังขละบุรี', 'LOCATION'),
#  (6, 291, 'สังขละบุรี', 'LOCATION'),
#  (6, 372, 'สะพานมอญ', 'LOCATION'),
#  (6, 376, 'เจดีย์พุทธคยา', 'LOCATION'),
#  (6, 398, 'ถนนคนเดิน', 'LOCATION'),
#  (6, 472, 'ถนนคนเดิน', 'LOCATION'),
#  (6, 480, 'ถนนคนเดิน', 'LOCATION'),
#  (6, 523, 'วัดใต้น้ำ', 'LOCATION'),
#  (6, 546, 'สังขละ', 'LOCATION'),
#  (6, 555, 'สังขละบุรี', 'LOCATION'),
#  (6, 567, 'สะพานมอญ', 'LOCATION'),
#  (6, 584, 'สะพานมาอญ', 'LOCATION'),
#  (6, 636, 'วัดใต้น้ำ', 'LOCATION'),
#  (6, 710, 'ไทย', 'LOCATION'),
#  (6, 726, 'วัดจมน้ำ', 'LOCATION'),
#  (6, 756, 'เจดีย์3องค์', 'LOCATION'),
#  (6, 768, 'เจดีย์3องค์', 'LOCATION'),
#  (6, 774, 'สังขละ', 'LOCATION'),
#  (6, 790, 'พม่า', 'LOCATION'),
#  (6, 817, 'สังขละ', 'LOCATION'),
#  (6, 986, 'สะพานมอญ', 'LOCATION'),
#  (6, 1043, 'วัดวังก์วิเวการาม', 'LOCATION'),
#  (6, 1051, 'เจดีย์พุทธคยา', 'LOCATION'),
#  (6, 1058, 'สังขละบุรี', 'LOCATION'),
#  (6, 1104, 'สังขละบุรี', 'LOCATION'),
#  (6, 1138, 'สังขละบุรี', 'LOCATION'),
#  (7, 105, 'สนามบินกรุงเทพ', 'LOCATION'),
#  (7, 108, 'หาดใหญ่', 'LOCATION'),
#  (7, 125, 'สนามบินหาดใหญ่', 'LOCATION'),
#  (7, 141, 'ท่าเรือปากบารา', 'LOCATION'),
#  (7, 405, 'ถนนคนเดิน', 'LOCATION'),
#  (7, 643, 'เกาะหินขาว', 'LOCATION'),
#  (7, 729, 'เกาะอาดัง', 'LOCATION'),
#  (7, 847, 'หลีเป๊ะ', 'LOCATION'),
#  (7, 854, 'กทม.', 'LOCATION'),
#  (8, 12, 'หัวหิน', 'LOCATION'),
#  (8, 54, 'กรุงเทพ', 'LOCATION'),
#  (8, 62, 'หัวหิน', 'LOCATION'),
#  (8, 131, 'ญี่ปุ่น', 'LOCATION'),
#  (9, 52, 'ภูเก็ต', 'LOCATION'),
#  (9, 244, 'ไทย', 'LOCATION'),
#  (9, 280, 'เกาะไม้ท่อน', 'LOCATION'),
#  (9, 304, 'เกาะรอก', 'LOCATION'),
#  (9, 311, 'เกาะรอก', 'LOCATION'),
#  (9, 327, 'เกาะรอก', 'LOCATION'),
#  (9, 366, 'ดอนเมือง', 'LOCATION'),
#  (9, 368, 'ภูเก็ต', 'LOCATION'),
#  (9, 430, 'สนามบินภูเก็ต', 'LOCATION'),
#  (9, 655, 'หาดป่าตอง', 'LOCATION'),
#  (9, 859, 'หาดป่าตอง', 'LOCATION'),
#  (9, 890, 'เมืองภูเก็ต', 'LOCATION'),
#  (9, 898, 'ภูเก็ต', 'LOCATION'),
#  (9, 957, 'หาดป่าตอง', 'LOCATION'),
#  (9, 989, 'หาดกะรน', 'LOCATION'),
#  (9, 1011, 'ภูเก็ต', 'LOCATION'),
#  (9, 1029, 'แหลมพรหมเทพ', 'LOCATION'),
#  (9, 1051, 'แหลมพรหมเทพ', 'LOCATION'),
#  (9, 1084, 'หอประภาคาร แหลมพรหมเทพ', 'LOCATION'),
#  (9, 1110, 'ภูเก็ต', 'LOCATION'),
#  (9, 1149, 'วงเวียนนาฬิกา', 'LOCATION'),
#  (9, 1265, 'ภูเก็ต', 'LOCATION'),
#  (9, 1290, 'Phuket Old Town', 'LOCATION'),
#  (9, 1405, 'สามกอง', 'LOCATION'),
#  (9, 1410, 'สามกอง', 'LOCATION'),
#  (9, 1464, 'กทม.', 'LOCATION'),
#  (9, 1470, 'ร้าน แม่จู้', 'LOCATION'),
#  (9, 1480, 'ภูเก็ต', 'LOCATION'),
#  (9, 1489, 'ภูเก็ต', 'LOCATION'),
#  (9, 1523, 'สะพานสารสิน', 'LOCATION'),
#  (9, 1535, 'สะพานสารสิน', 'LOCATION'),
#  (9, 1556, 'สะพารสารสิน', 'LOCATION'),
#  (9, 1577, 'สะพานรักสารสิน', 'LOCATION'),
#  (9, 1610, 'ภูเก็ต', 'LOCATION'),
#  (9, 1628, 'เกาะ ไม้ท่อน', 'LOCATION'),
#  (10, 36, 'หลีเป๊ะ', 'LOCATION'),
#  (10, 119, 'เชียงใหม่', 'LOCATION'),
#  (10, 123, 'หาดใหญ่', 'LOCATION'),
#  (10, 191, 'หาดซันไรส์', 'LOCATION'),
#  (10, 196, 'หาดชาวเล', 'LOCATION'),
#  (10, 428, 'Koh Lipe Walking Street', 'LOCATION'),
#  (10, 439, 'หลีเป๊ะ', 'LOCATION'),
#  (10, 456, 'หาดใหญ่(สงขลา)', 'LOCATION'),
#  (10, 470, 'ตลาดเกษตร', 'LOCATION'),
#  (10, 486, 'ตลาดเกษตร', 'LOCATION'),
#  (10, 494, 'ตลาดเกษตร', 'LOCATION'),
#  (10, 498, 'ท่าเรือปากบารา(สตูล)', 'LOCATION'),
#  (10, 511, 'ท่าเรือปากบารา', 'LOCATION'),
#  (10, 517, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 526, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 621, 'หาดพัทยาบีช', 'LOCATION'),
#  (10, 629, 'หาดพัทยาบีช', 'LOCATION'),
#  (10, 712, 'หาดพัทยา', 'LOCATION'),
#  (10, 737, 'ท่าเรือปากบารา', 'LOCATION'),
#  (10, 742, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 756, 'เกาะไข่', 'LOCATION'),
#  (10, 764, 'หลีเป๊ะ', 'LOCATION'),
#  (10, 994, 'หาดซันไรส์', 'LOCATION'),
#  (10, 999, 'หาดชาวเล', 'LOCATION'),
#  (10, 1026, 'หาดซันไรส์', 'LOCATION'),
#  (10, 1157, 'หาดชาวเล', 'LOCATION'),
#  (10, 1227, 'เชียงใหม่', 'LOCATION'),
#  (10, 1229, 'หาดใหญ่', 'LOCATION'),
#  (10, 1246, 'ตลาดเกษตร', 'LOCATION'),
#  (10, 1283, 'ตลาดเกษตร', 'LOCATION'),
#  (10, 1286, 'ท่าเรือปากบารา', 'LOCATION'),
#  (10, 1297, 'ท่าเรือปากบารา', 'LOCATION'),
#  (10, 1302, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 1344, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 1483, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 1493, 'ท่าเรือปากบารา', 'LOCATION'),
#  (10, 1895, 'เกาะหลีเป๊ะ', 'LOCATION'),
#  (10, 1953, 'Walking Street ฝั่งหาดพัทยา', 'LOCATION'),
#  (10, 2035, 'หาดพัทยา', 'LOCATION'),
#  (10, 2087, 'เกาะหินซ้อน', 'LOCATION'),
#  (10, 2111, 'เกาะรอกลอย', 'LOCATION'),
#  (10, 2125, 'เกาะดง', 'LOCATION'),
#  (10, 2131, 'เกาะดง', 'LOCATION'),
#  (10, 2262, 'เกาะดง', 'LOCATION'),
#  (10, 2267, 'เกาะผึ้ง', 'LOCATION'),
#  (10, 2270, 'เกาะผึ้ง', 'LOCATION'),
#  (10, 2309, 'เกาะผึ้ง', 'LOCATION'),
#  (10, 2314, 'เกาะหินงาม', 'LOCATION'),
#  (10, 2372, 'ร่องน้ำจาบัง', 'LOCATION'),
#  (10, 2599, 'หลีเป๊ะ', 'LOCATION'),
#  (10, 2682, 'หลีเป๊ะ', 'LOCATION')]

# %%
len(loc_list)
# Out:
# 235

# %%
loc_df = pd.DataFrame(loc_list, columns=["Thread", "Index", "Word", "Label"])
loc_df
# Out:
#      Thread  Index          Word     Label
# 0         1     48     เชียงใหม่  LOCATION
# 1         1    281   ดอยอินทนนท์  LOCATION
# 2         1    331     เชียงใหม่  LOCATION
# 3         1    396    ถ.ห้วยแก้ว  LOCATION
# 4         1    401    กาดสวนแก้ว  LOCATION
# ..      ...    ...           ...       ...
# 230      10   2309      เกาะผึ้ง  LOCATION
# 231      10   2314    เกาะหินงาม  LOCATION
# 232      10   2372  ร่องน้ำจาบัง  LOCATION
# 233      10   2599       หลีเป๊ะ  LOCATION
# 234      10   2682       หลีเป๊ะ  LOCATION
#
# [235 rows x 4 columns]

# %%
# loc_df.to_csv('unseen_LocList.csv', index=False)

# %% [markdown]
# ### Features Creating & Training Model

# %%
tt=[]
with open(file_name+"-pos.conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[1]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

with open(file_name+".conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

# %%
def doc2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
    # Features from current word
    features={
        'word.word': word,
        'word.isspace':word.isspace(),
        'postag':postag,
        'word.isdigit()': word.isdigit()
    }
    if i > 0:
        prevword = doc[i-1][0]
        postag1 = doc[i-1][1]
        features['word.prevword'] = prevword
        features['word.previsspace']=prevword.isspace()
        features['word.prepostag'] = postag1
        features['word.prevwordisdigit'] = prevword.isdigit()
    else:
        features['BOS'] = True # Special "Beginning of Sequence" tag
    # Features from next word
    if i < len(doc)-1:
        nextword = doc[i+1][0]
        postag1 = doc[i+1][1]
        features['word.nextword'] = nextword
        features['word.nextisspace']=nextword.isspace()
        features['word.nextpostag'] = postag1
        features['word.nextwordisdigit'] = nextword.isdigit()
    else:
        features['EOS'] = True # Special "End of Sequence" tag
    return features

def extract_features(doc):
    return [doc2features(doc, i) for i in range(len(doc))]

def get_labels(doc):
    return [tag for (token,postag,tag) in doc]

# %%
X_data = [extract_features(doc) for doc in datatofile] # เอา คำ แยกออกมา
y_data = [get_labels(doc) for doc in datatofile] # เอา tag แยกออกมา

# %%
X, X_test, y, y_test = train_test_split(X_data, y_data, test_size=0.1)

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=500,
    all_possible_transitions=True,
    model_filename=file_name+"-pos.model0" # ตั้งชื่อโมเดล
)
crf.fit(X, y); # train

# %%
labels = list(crf.classes_)
labels.remove('O')

# %%
y_pred = crf.predict(X_test)

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)

# %% [markdown]
# # No K-Fold

# %%
print(metrics.flat_classification_report(y_test, y_pred, labels=sorted_labels, digits=3))

# %% [markdown]
# # 10-Fold

# %%
fold_pred = cross_val_predict(crf, X, y, cv=10)

# %%
print(metrics.flat_classification_report(y, fold_pred, labels=sorted_labels, digits=3))

# %% [markdown]
# # Save Model

# %%
model_name = '300_NER_CRF_model.sav'
pickle.dump(crf, open(model_name, 'wb') )

# %% [markdown]
# # Loading Model

# %%
# model_name = '300_NER_CRF_model.sav'
# crf = pickle.load(open(model_name, 'rb'))

# %% [markdown]
# # Merge Label for Predict

# %%
df_tag = pd.read_csv('test_tag.csv') 
df_tag
