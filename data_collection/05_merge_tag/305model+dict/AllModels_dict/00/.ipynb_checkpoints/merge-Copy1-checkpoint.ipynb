# %%
data_path = "/Users/j.kanlaya/Downloads/Mike/data_collection/05_merge_tag/305model+dict/data/"

# %%
file_name="300_clean_dataset" # ชื่อไฟล์คลังข้อมูล
import codecs
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from nltk.tokenize import RegexpTokenizer
from sklearn_crfsuite import scorers,metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_validate,train_test_split, cross_val_predict
import sklearn_crfsuite
import pandas as pd
import numpy as np
import csv
import pickle
import glob
import nltk
import re

# %% [markdown]
# ## import location dictionary

# %%
# dictionary = open('dictionary.txt', 'r', encoding="utf-8").read().splitlines()
# thai_loc = open('./dict_corpus/Thailoc_clean.txt', 'r', encoding="tis-620").read().splitlines()
# loc_place = open('./dict_corpus/tourplace_n.txt', 'r', encoding="tis-620").read().splitlines()
# river = open('./dict_corpus/ชื่อคลอง.txt', 'r', encoding="tis-620").read().splitlines()
# # bkk_road = open('./dict_corpus/ชื่อถนนในกรุงเทพ_ดี_clean.txt', 'r', encoding="tis-620").read().splitlines()
# road = open('./dict_corpus/ถนน_เพิ่มเติม.txt', 'r', encoding="tis-620").read().splitlines()
# sub_dis01 = open('./dict_corpus/ชื่อกิ่งอำเภอ.txt', 'r', encoding="tis-620").read().splitlines()
# sub_dis02 = open('./dict_corpus/ชื่อตำบล.txt', 'r', encoding="tis-620").read().splitlines()
# district = open('./dict_corpus/ชื่ออำเภอ.txt', 'r', encoding="tis-620").read().splitlines()
# province = open('./dict_corpus/ชื่อจังหวัด.txt', 'r', encoding="tis-620").read().splitlines()

# %% [markdown]
# ## def function

# %%
#จัดการประโยคซ้ำ
data_not=[]
def Unique(p):
 text=re.sub("<[^>]*>","",p)
 text=re.sub("\[(.*?)\]","",text)
 text=re.sub("\[\/(.*?)\]","",text)
 if text not in data_not:
  data_not.append(text)
  return True
 else:
  return False
# เตรียมตัวตัด tag ด้วย re
pattern = r'\[(.*?)\](.*?)\[\/(.*?)\]'
tokenizer = RegexpTokenizer(pattern) # ใช้ nltk.tokenize.RegexpTokenizer เพื่อตัด [TIME]8.00[/TIME] ให้เป็น ('TIME','ไง','TIME')

# %%
# จัดการกับ tag ที่ไม่ได้ tag
def toolner_to_tag(text):
 text=text.strip()
 text=re.sub("<[^>]*>","",text)
 text=re.sub("(\[\/(.*?)\])","\\1***",text)#.replace('(\[(.*?)\])','***\\1')#  ตัดการกับพวกไม่มี tag word
 text=re.sub("(\[\w+\])","***\\1",text)
 text2=[]
 for i in text.split('***'):
  if "[" in i:
   text2.append(i)
  else:
   text2.append("[word]"+i+"[/word]")
 text="".join(text2)#re.sub("[word][/word]","","".join(text2))
 return text.replace("[word][/word]","")
# แปลง text ให้เป็น conll2002
def text2conll2002(text,pos=True):
    """
    ใช้แปลงข้อความให้กลายเป็น conll2002
    """
    text=toolner_to_tag(text) # นำไปใส่ tag [word]
    text=text.replace("''",'"')
    text=text.replace("’",'"').replace("‘",'"')#.replace('"',"")
    tag=tokenizer.tokenize(text) # แยก tag ออกมาจากข้อความ
    j=0
    conll2002="" # ประกาศตัวแปรเก็บ conll2002
    for tagopen,text,tagclose in tag: # ลูปใน tag โดยเป็น (tagopen,text,tagclose)
        word_cut=word_tokenize(text,engine="newmm") # ใช้ตัวตัดคำ newmm ของ PyThaiNLP
        i=0
        txt5=""
        while i<len(word_cut): #ลูปตามจำนวน token ที่ตัดในtag
            if word_cut[i]=="''" or word_cut[i]=='"':pass
            elif i==0 and tagopen!='word': # ไม่เป็น tag [word] และเป็น i หรือตัวเริ่มต้น tag
                txt5+=word_cut[i]
                txt5+='\t'+'B-'+tagopen
            elif tagopen!='word':
                txt5+=word_cut[i]
                txt5+='\t'+'I-'+tagopen
            else: # เป็น [word]
                txt5+=word_cut[i]
                txt5+='\t'+'O'
            txt5+='\n'
            #j+=1
            i+=1
        conll2002+=txt5
    if pos==False:
        return conll2002
    return postag(conll2002) # เพิ่ม postag ใส่
# ใช้สำหรับกำกับ pos tag เพื่อใช้กับ NER
# print(text2conll2002(t,pos=False))
def postag(text):
    listtxt=[i for i in text.split('\n') if i!='']
    list_word=[]
    for data in listtxt:
        list_word.append(data.split('\t')[0])
    #print(text)
    list_word=pos_tag(list_word,engine="perceptron")
    text=""
    i=0
    for data in listtxt:
        text+=data.split('\t')[0]+'\t'+list_word[i][1]+'\t'+data.split('\t')[1]+'\n'
        i+=1
    return text
# อ่านข้อมูลจากไฟล์
def get_data(fileopen):
	"""
    สำหรับใช้อ่านทั้งหมดทั้งในไฟล์ทีละรรทัดออกมาเป็น list
    """
	with codecs.open(fileopen, 'r',encoding='utf-8-sig') as f:
		lines = f.read().splitlines()
	return [a for a in lines if Unique(a)] # เอาไม่ซ้ำกัน

def alldata(lists):
    text=""
    for data in lists:
        text+=text2conll2002(data)
        text+='\n'
    return text

def alldata_list(lists):
    data_all=[]
    for data in lists:
        data_num=[]
        try:
            txt=text2conll2002(data,pos=True).split('\n') # นำไปแปลงเป็น conll2002
            for d in txt:
                tt=d.split('\t')
                if d!="":
                    if len(tt)==3:
                        data_num.append((tt[0],tt[1],tt[2]))
                    else:
                        data_num.append((tt[0],tt[1]))
            #print(data_num)
            data_all.append(data_num)
        except:
            print(data)
    #print(data_all)
    return data_all

def alldata_list_str(lists):
	string=""
	for data in lists:
		string1=""
		for j in data:
			string1+=j[0]+"	"+j[1]+"	"+j[2]+"\n"
		string1+="\n"
		string+=string1
	return string

def get_data_tag(listd):
	list_all=[]
	c=[]
	for i in listd:
		if i !='':
			c.append((i.split("\t")[0],i.split("\t")[1],i.split("\t")[2]))
		else:
			list_all.append(c)
			c=[]
	return list_all
def getall(lista):
    ll=[]
    for i in lista:
        o=True
        for j in ll:
            if re.sub("\[(.*?)\]","",i)==re.sub("\[(.*?)\]","",j):
                o=False
                break
        if o==True:
            ll.append(i)
    return ll

# %%
data1=getall(get_data(data_path+file_name+".txt")) # นำคลังเข้าไป แยกออกเป็น list ละบรรทัด
datatofile=alldata_list(data1) # นำไปผ่านขั้นตอน 1 2 3 4

# %%
# print(len(datatofile))
# print(datatofile[0][:10])

# %%
# datatofile

# %% [markdown]
# ## Insert ThreadID & index

# %%
file = open("/Users/j.kanlaya/Downloads/Mike/data_collection/06_database/01_Thread_Data_Table/threadID_list.txt", "r")
#  39803812,
#  39789616,
#  39902457,
#  40003970,
#  40084831,
#  40025165,
#  39920755,
#  39615945,
#  40043821,
#  40091067,
#  40102588,
#  39747044,
#  39915124,
#  39684459,
#  39724476,
#  39775559,
#  39698499,
#  39521826,
#  39708809,
#  40019760,
#  39564558,
#  39448862,
#  39442869,
#  39542285,
#  39736196,
#  39493177,
#  39594946,
#  39340315,
#  39469635,
#  39346047,
#  39282195,
#  39364957,
#  39337305,
#  39441068,
#  39331484,
#  39232587,
#  39365201,
#  39369578,
#  39300005,
#  39168504,
#  39294991,
#  39147373,
#  39196267,
#  39051502,
#  39108673,
#  39208860,
#  39056811,
#  39067904,
#  39036822,
#  39087267,
#  39036234,
#  38989201,
#  39059630,
#  39016387,
#  39020929,
#  39117759,
#  38947248,
#  38975426,
#  38951918,
#  38893605,
#  38958204,
#  38936865,
#  38950160,
#  38788801,
#  38884136,
#  38884681,
#  38851696,
#  38863132,
#  38809718,
#  38805994,
#  38819995,
#  38721581,
#  38664165,
#  38769111,
#  38598513,
#  38807316,
#  38574909,
#  38622677,
#  38492304,
#  38405742,
#  38448189,
#  38444396,
#  38421591,
#  38396572,
#  38255627,
#  38362459,
#  38249266,
#  38190914]

# %%
# threadID_list[0]

# %%
data_label = []
for sentence_no in range(len(datatofile)):
    index = 0
    for item in datatofile[sentence_no]:
        item = list(item)
        item.insert(0, threadID_list[sentence_no])
        item.insert(1, sentence_no+1)
        item.insert(2, index)
        item = tuple(item)
        data_label.append(item)
        index += 1

# %%
# len(data_label)

# %%
# data_label[:10]

# %% [markdown]
# # Merge Label Training Data

# %%
i=0
loc = []
while(i < len(data_label)):
    if(data_label[i][5] == "B-LOCATION"):
        item = []
        item.append(data_label[i][0]) #append thread id
        item.append(data_label[i][1]) #append sentence no.
        item.append(data_label[i][2]) #append index
        word = data_label[i][3]
        while(data_label[i+1][5] == "I-LOCATION"):
            i += 1
            word += data_label[i][3]
        item.append(word)
        item.append("LOCATION")
        item = tuple(item)
    loc.append(item)
    i += 1

# %%
loc_list = list(dict.fromkeys(loc))
loc_list = loc_list[1:]
loc_list
# Out:
# [(37357879, 1, 99, 'ทับสะแก จังหวัดประจวบคีรีขันธ์', 'LOCATION'),
#  (37357879, 1, 129, 'ฟิวเจอร์พาร์ครังสิต', 'LOCATION'),
#  (37357879, 1, 138, 'ชะอำ', 'LOCATION'),
#  (37357879, 1, 142, 'อ่าวมะนาว', 'LOCATION'),
#  (37357879, 1, 993, 'เมืองไทย', 'LOCATION'),
#  (37271619,
#   2,
#   15,
#   'หมู่บ้านท่าระแนะ ตำบลหนองคันทรง อ.เมือง จ.ตราด',
#   'LOCATION'),
#  (37271619, 2, 71, 'ตราด', 'LOCATION'),
#  (37271619, 2, 123, 'ตราด', 'LOCATION'),
#  (37271619, 2, 128, 'เกาะช้าง', 'LOCATION'),
#  (37271619, 2, 156, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 207, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 267, 'หมู่บ้านท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 398, 'ท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 489, 'ตราด', 'LOCATION'),
#  (37271619, 2, 574, 'ชุมชนบ้านท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 600, 'จังหวัดตราด', 'LOCATION'),
#  (37271619, 2, 727, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 755, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 809, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 938, 'บ้านท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 1365, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 1503, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 1512, 'ตำบลท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 1713, 'ลานตะบูน ที่บ้านท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 1816, 'ลานตะบูนนนนนน', 'LOCATION'),
#  (37271619, 2, 1883, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 1950, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 2060, 'ลานตะบูน', 'LOCATION'),
#  (37271619, 2, 2154, 'ตราด', 'LOCATION'),
#  (37271619, 2, 2219, 'จังหวัดตราด', 'LOCATION'),
#  (37271619, 2, 2223, 'ท่าระแนะ', 'LOCATION'),
#  (37271619, 2, 2347, 'ตำบลหนองคันทรง', 'LOCATION'),
#  (37271619, 2, 2423, 'วัดหนองคันทรง', 'LOCATION'),
#  (37271619, 2, 2511, 'วัดหนองคันทรง', 'LOCATION'),
#  (37271619, 2, 2648, 'ตำบลหนองคันทรง', 'LOCATION'),
#  (37271619, 2, 3171, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 3223, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 3281, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 3304, 'ตราด', 'LOCATION'),
#  (37271619, 2, 3314, 'เมืองตราดมัน', 'LOCATION'),
#  (37271619, 2, 3333, 'ชลบุรี', 'LOCATION'),
#  (37271619, 2, 3335, 'ระยอง', 'LOCATION'),
#  (37271619, 2, 3337, 'จันทบุรี', 'LOCATION'),
#  (37271619, 2, 3347, 'เมืองตราด', 'LOCATION'),
#  (37271619, 2, 3383, 'ตราด', 'LOCATION'),
#  (37284754, 3, 51, 'จังหวัดเชียงราย', 'LOCATION'),
#  (37284754, 3, 97, 'เชียงราย', 'LOCATION'),
#  (37284754, 3, 120, 'สนามบินสุวรรณภูมิ', 'LOCATION'),
#  (37284754, 3, 124, 'สนามบินแม่ฟ้าหลวง เชียงราย', 'LOCATION'),
#  (37284754, 3, 222, 'สนามบินแม่ฟ้าหลวง เชียงราย', 'LOCATION'),
#  (37284754, 3, 347, 'เมืองเชียงราย', 'LOCATION'),
#  (37284754, 3, 351, 'หอนาฬิกา', 'LOCATION'),
#  (37284754, 3, 362, 'เชียงราย', 'LOCATION'),
#  (37284754, 3, 787, 'สวนตุงและโคมนครเชียงราย เทศบาลนครเชียงราย', 'LOCATION'),
#  (37284754, 3, 1071, 'อ.แม่ลาว', 'LOCATION'),
#  (37284754, 3, 1323, 'วัดร่องขุ่น', 'LOCATION'),
#  (37284754, 3, 1605, 'วัดร่องเสือเต้น', 'LOCATION'),
#  (37284754, 3, 1640, 'วัดร่องขุ่น', 'LOCATION'),
#  (37284754, 3, 1756, 'วัดห้วยปลากั้ง', 'LOCATION'),
#  (37284754, 3, 1761, 'เจ้าแม่กวนอิม วัดห้วยปลากั้ง', 'LOCATION'),
#  (37284754, 3, 1773, 'สวัสดีเชียงราย Cat Cafe', 'LOCATION'),
#  (37284754, 3, 2009, 'ดอยตุง', 'LOCATION'),
#  (37284754, 3, 2019, 'วัดพระธาตุดอยตุง', 'LOCATION'),
#  (37284754, 3, 2045, 'แม่สาย', 'LOCATION'),
#  (37284754, 3, 2119, 'วัดพระธาตุดอยตุง', 'LOCATION'),
#  (37284754, 3, 2170, 'หอนาฬิกา', 'LOCATION'),
#  (37284754, 3, 2370, 'สนามบินเชียงใหม่', 'LOCATION'),
#  (37284754, 3, 2453, 'กรุงเทพฯ', 'LOCATION'),
#  (37284754, 3, 2508, 'สนามบินสุวรรณภูมิ', 'LOCATION'),
#  (37230161, 4, 4, 'กระบี่', 'LOCATION'),
#  (37233347, 5, 61, 'เมกาบางนา', 'LOCATION'),
#  (37223370, 11, 35, 'Safari World', 'LOCATION'),
#  (37223370, 11, 149, 'Safari World', 'LOCATION'),
#  (37223370, 11, 184, 'Safari World', 'LOCATION'),
#  (37223370,
#   11,
#   192,
#   '99 99 ถนนปัญญาอินทรา แขวงคลองสามวา เขตสามวานอก กรุงเทพฯ',
#   'LOCATION'),
#  (37223370, 11, 222, 'Safari World', 'LOCATION'),
#  (37223370, 11, 1081, 'พัทยา', 'LOCATION'),
#  (37223370, 11, 1434, 'จุตจักร', 'LOCATION'),
#  (37223370, 11, 1590, 'Safari World', 'LOCATION'),
#  (37223370, 11, 1786, 'รัชดา', 'LOCATION'),
#  (37223370, 11, 2212, 'Safari World', 'LOCATION'),
#  (37223370, 11, 2251, 'Safari World', 'LOCATION'),
#  (37193771, 13, 2191, 'ลพบุรี', 'LOCATION'),
#  (37193771, 13, 2193, 'อยุธยา', 'LOCATION'),
#  (37193771, 13, 2195, 'สุโขทัย', 'LOCATION'),
#  (37193771, 13, 2197, 'เชียงใหม่', 'LOCATION'),
#  (37193771, 13, 2199, 'เชียงราย', 'LOCATION'),
#  (37150758, 14, 11, 'บ้านรักไทย', 'LOCATION'),
#  (37150758, 14, 58, 'แม่ฮ่องสอน', 'LOCATION'),
#  (37150758, 14, 63, 'ปางอุ๋ง', 'LOCATION'),
#  (37150758, 14, 65, 'บ้านรักไทย', 'LOCATION'),
#  (37150758, 14, 72, 'ปาย', 'LOCATION'),
#  (37150758, 14, 76, 'เชียงใหม่', 'LOCATION'),
#  (37150758, 14, 80, 'เชียงดาว', 'LOCATION'),
#  (37150758, 14, 84, 'แม่แตง', 'LOCATION'),
#  (37150758, 14, 89, 'แม่ริม', 'LOCATION'),
#  (37150758, 14, 101, 'บ้านรักไทย', 'LOCATION'),
#  (37097958, 20, 37, 'เกาะเมือง', 'LOCATION'),
#  (37097958, 20, 42, 'เกาะเมือง', 'LOCATION'),
#  (37097958, 20, 46, 'สะพานปรีดี', 'LOCATION'),
#  (37097958, 20, 50, 'ศาลากลางจังหวัดหลังเก่า', 'LOCATION'),
#  (37097958, 20, 56, 'ศาลหลักเมือง', 'LOCATION'),
#  (37097958, 20, 59, 'คุ้มขุนแผน', 'LOCATION'),
#  (37097958, 20, 62, 'วิหารพระมงคลบพิตร', 'LOCATION'),
#  (37097958, 20, 67, 'วัดพระศรีสรรเพ็ชญ์', 'LOCATION'),
#  (37097958, 20, 78, 'วัดพระราม', 'LOCATION'),
#  (37097958, 20, 115, 'ตลาดย้อนยุค', 'LOCATION'),
#  (37097958, 20, 118, 'ถนนคนเดิน', 'LOCATION'),
#  (37097958, 20, 122, 'ถนนกินเส้น', 'LOCATION'),
#  (37032964, 21, 19, 'เมืองไทย', 'LOCATION'),
#  (37032964, 21, 51, 'ไทย', 'LOCATION'),
#  (37032964, 21, 64, 'เกาหลี', 'LOCATION'),
#  (37032964, 21, 72, 'อเมริกา', 'LOCATION'),
#  (37032964, 21, 74, 'ญี่ปุ่น', 'LOCATION'),
#  (37032964, 21, 93, 'เกาหลี', 'LOCATION'),
#  (37032964, 21, 241, 'ประเทศไทย', 'LOCATION'),
#  (37048572, 22, 48, 'เดอะไนท์ พระราม9 ', 'LOCATION'),
#  (37046013, 23, 39, 'เกาะช้าง', 'LOCATION'),
#  (37133463, 24, 52, 'วังน้ำเขียว', 'LOCATION'),
#  (37133463, 24, 91, 'ม่อนแจ่ม', 'LOCATION'),
#  (37083162, 25, 0, 'มหาสารคาม', 'LOCATION'),
#  (37083162, 25, 52, 'กันทรวิชัย', 'LOCATION'),
#  (37083162, 25, 55, 'เชียงยืน', 'LOCATION'),
#  (37083162, 25, 61, 'บ้านหนองซอน', 'LOCATION'),
#  (37083162, 25, 148, 'มหาสารคาม', 'LOCATION'),
#  (37083162, 25, 164, 'ลาว', 'LOCATION'),
#  (37083162, 25, 217, 'วัดป่าบ้านหนองซอน', 'LOCATION'),
#  (37083162, 25, 327, 'พิษณุโลก', 'LOCATION'),
#  (37083162, 25, 404, 'จ.มหาสารคาม', 'LOCATION'),
#  (37083162, 25, 446, 'มหาสารคาม', 'LOCATION'),
#  (37010980, 26, 9, 'จังหวัดอุบลราชธานี', 'LOCATION'),
#  (37010980, 26, 44, 'ประเทศไทย', 'LOCATION'),
#  (37010980, 26, 187, 'Palio เขาใหญ่', 'LOCATION'),
#  (37019382, 27, 6, 'พัทยา', 'LOCATION'),
#  (37019382, 27, 12, 'เชียงคาน', 'LOCATION'),
#  (37019382, 27, 14, 'เวียงจันทร์', 'LOCATION'),
#  (37019382, 27, 17, 'คำชะโนด', 'LOCATION'),
#  (37019382, 27, 64, 'เชียงคาน', 'LOCATION'),
#  (37019382, 27, 67, 'เชียงคาน', 'LOCATION'),
#  (37019382, 27, 76, 'ริมโขง', 'LOCATION'),
#  (37019382, 27, 80, 'วัดผาตากเสื้อ', 'LOCATION'),
#  (36875160, 34, 363, 'โรงเรียนนายร้อย จปร.จ.นครนายก', 'LOCATION'),
#  (36875160,
#   34,
#   370,
#   'สถานพักฟื้นและพักผ่อนที่สวนสนประดิพัทธ์ จ.ประจวบฯ',
#   'LOCATION'),
#  (36875160, 34, 383, 'สถานพักฟื้นและพักผ่อนล้านนา จ.เชียงใหม่', 'LOCATION'),
#  (36875160, 34, 393, 'มูลนิธิแม่ฟ้าหลวง ในพระบรมราชูปถัมภ์', 'LOCATION'),
#  (36875160, 34, 401, 'บ้านสวนแผ่นดินแม่ สุพรรณ', 'LOCATION'),
#  (36875160, 34, 409, 'กลุ่มท่องเที่ยวชุมชนตำบลบ้านแหลม', 'LOCATION'),
#  (36875160, 34, 418, 'พิพิธภัณฑ์กองทัพอากาศ', 'LOCATION'),
#  (36875160,
#   34,
#   430,
#   'องค์การพิพิธภัณฑ์วิทยาศาสตร์แห่งชาติ (อพวช)',
#   'LOCATION'),
#  (36875160, 34, 438, 'กิจการน้ำพุร้อนสันกำแพง', 'LOCATION'),
#  (36875160, 34, 446, 'Museum Siam', 'LOCATION'),
#  (36875160, 34, 451, 'โครงการฟาร์มทะเลตัวอย่างตามพระราชดำริ', 'LOCATION'),
#  (36875160, 34, 459, 'องค์การสวนสัตว์', 'LOCATION'),
#  (36875160, 34, 463, 'ไปรษณีย์ไทย', 'LOCATION'),
#  (36887224, 35, 12, 'ไทย', 'LOCATION'),
#  (36887224, 35, 59, 'กรุงเทพ', 'LOCATION'),
#  (36887224, 35, 61, 'อยุธยา', 'LOCATION'),
#  (36887224, 35, 74, 'ภูเก็ต', 'LOCATION'),
#  (36887224, 35, 78, 'กระบี่', 'LOCATION'),
#  (36887224, 35, 90, 'กระบี่', 'LOCATION'),
#  (36887224, 35, 92, 'เชียงใหม่', 'LOCATION'),
#  (36887224, 35, 99, 'เชียงใหม่', 'LOCATION'),
#  (36887224, 35, 106, 'ปาย', 'LOCATION'),
#  (36887224, 35, 110, 'กรุงเทพ', 'LOCATION'),
#  (36948254, 38, 302, 'ราชบุรี', 'LOCATION'),
#  (36948254, 38, 312, 'วัดหนองหอย', 'LOCATION'),
#  (36949870, 39, 10, 'เชียงใหม่', 'LOCATION'),
#  (36949870, 39, 23, 'เชียงใหม่', 'LOCATION'),
#  (36949870, 39, 241, 'ตลาดประตูเมืองเชียงใหม่', 'LOCATION'),
#  (36949870, 39, 250, 'ไนท์บาซ่า', 'LOCATION'),
#  (36949870, 39, 301, 'ตลาดประตูเชียงใหม่', 'LOCATION'),
#  (36949870, 39, 335, 'สวนสาธารณะหนองบวกหาด', 'LOCATION'),
#  (36949870, 39, 367, 'เซ็นทรัลเฟสติวอลเชียงใหม่', 'LOCATION'),
#  (36949870, 39, 412, 'ไนท์ซาฟารี', 'LOCATION'),
#  (36949870, 39, 569, 'ไนท์บาซ่า', 'LOCATION'),
#  (36949870, 39, 742, 'ดอยสุเทพ', 'LOCATION'),
#  (36949870, 39, 1078, 'พระตำหนักภูพิงค์', 'LOCATION'),
#  (36949870, 39, 1127, 'ดอยสุเทพ', 'LOCATION'),
#  (36788359, 57, 3814, 'จังหวัดระยอง', 'LOCATION'),
#  (36788359, 57, 3848, 'จันทบุรี', 'LOCATION'),
#  (36788359, 57, 3937, 'จันทบุรี', 'LOCATION'),
#  (36788359, 57, 3942, 'จันทบุรี', 'LOCATION'),
#  (36788359, 57, 4168, 'สมุทรปราการ', 'LOCATION'),
#  (36876378, 58, 14, 'จังหวัดน่าน', 'LOCATION'),
#  (36876378, 58, 47, 'น่าน', 'LOCATION'),
#  (36876378, 58, 105, 'น่าน', 'LOCATION'),
#  (36876378, 58, 129, 'น่าน', 'LOCATION'),
#  (36876378, 58, 281, 'จังหวัดน่าน', 'LOCATION'),
#  (36876378, 58, 402, 'อำเภอปัว', 'LOCATION'),
#  (36876378, 58, 410, 'เมืองน่าน', 'LOCATION'),
#  (36876378, 58, 445, 'สะพานตากผ้าซิ่น', 'LOCATION'),
#  (36876378, 58, 472, 'อำเภอปัว', 'LOCATION'),
#  (36876378, 58, 507, 'พิพิทธพัณฑสถานแห่งชาติ น่าน', 'LOCATION'),
#  (36876378, 58, 533, 'ถนนคนเดินเมืองน่าน', 'LOCATION'),
#  (36876378, 58, 546, 'สนามหลวง', 'LOCATION'),
#  (36876378, 58, 551, 'พระบรมมหาราชวัง', 'LOCATION'),
#  (36876378, 58, 581, 'วัดภูมินทร์', 'LOCATION'),
#  (36876378, 58, 627, 'เมืองน่าน', 'LOCATION'),
#  (36876378, 58, 645, 'น่าน', 'LOCATION'),
#  (36876378, 58, 673, 'เสาดิน นาน้อย', 'LOCATION'),
#  (36876378, 58, 692, 'อำเภอนาน้อย', 'LOCATION'),
#  (36876378, 58, 700, 'เมืองน่าน', 'LOCATION'),
#  (36876378, 58, 733, 'น่าน', 'LOCATION'),
#  (36876378, 58, 757, 'น่าน', 'LOCATION'),
#  (36876378, 58, 789, 'ไทเป', 'LOCATION'),
#  (36876378, 58, 805, 'ไทเป', 'LOCATION'),
#  (36808113, 59, 5, 'สนามบินสุราษฯ', 'LOCATION'),
#  (36808113, 59, 54, 'เกาะสมุย', 'LOCATION'),
#  (36808113, 59, 77, 'เกาะนางยวน', 'LOCATION'),
#  (36808113, 59, 81, 'เกาะเต่า', 'LOCATION'),
#  (36808113, 59, 93, 'หมู่เกาะอ่างทอง', 'LOCATION'),
#  (36808113, 59, 105, 'หมู่เกาะอ่างทอง', 'LOCATION'),
#  (36808113, 59, 120, 'เกาะพงัน', 'LOCATION'),
#  (36808113, 59, 151, 'เกาะสมุย', 'LOCATION'),
#  (36774221, 60, 24, 'เกาะรัตนโกสินทร์', 'LOCATION'),
#  (36774221, 60, 276, 'พระที่นั่งดุสิตมหาปราสาท', 'LOCATION'),
#  (36774221, 60, 388, 'สนามหลวง', 'LOCATION'),
#  (36774221, 60, 390, 'วัดพระแก้ว', 'LOCATION'),
#  (36774221, 60, 394, 'ศาลหลักเมือง', 'LOCATION'),
#  (36774221, 60, 477, 'เกาะรัตนโกสินทร์', 'LOCATION'),
#  (36774221, 60, 772, 'เกาะรัตนโกสินทร์', 'LOCATION'),
#  (36871793, 62, 1058, 'หมู่บ้านห้วยห้อม อำเภอแม่ลาน้อย', 'LOCATION'),
#  (36871793, 62, 1070, 'ตำบลห้วยห้อม อำเภอเเม่ลาน้อย', 'LOCATION'),
#  (36871793, 62, 1081, 'อำเภอแม่ลาน้อย', 'LOCATION'),
#  (36871793, 62, 1139, 'ห้วยห้อม', 'LOCATION'),
#  (36871793, 62, 1166, 'อ.ขุนยวม', 'LOCATION'),
#  (36871793, 62, 1200, 'หมู่บ้านผาผ่า อำเภอสบเมย', 'LOCATION'),
#  (36871793, 62, 1212, 'บ้านห้วยห้อม', 'LOCATION'),
#  (36871793, 62, 1223, 'อำเภอแม่สะเรียง', 'LOCATION'),
#  (36871793, 62, 1239, 'หมู่บ้านบุญ', 'LOCATION'),
#  (36871793, 62, 1306, 'อนุสาวรีย์ครูบาผาผ่า', 'LOCATION'),
#  (36871793, 62, 1312, 'พระธาตุผาผ่า', 'LOCATION'),
#  (36871793, 62, 1318, 'เมืองสบเมย', 'LOCATION'),
#  (36871793, 62, 1324, 'แม่สะเรียง', 'LOCATION'),
#  (36871793, 62, 1429, 'หมู่บ้านแม่เหาะ อำเภอแม่สะเรียง', 'LOCATION'),
#  (36871793, 62, 1455, 'จังหวัดเชียงใหม่', 'LOCATION'),
#  (36871793, 62, 1459, 'ตำบลแม่เหาะ', 'LOCATION'),
#  (36871793, 62, 1507, 'น้ำตกแม่สวรรค์น้อย', 'LOCATION'),
#  (36871793, 62, 1727, 'เมืองไทย', 'LOCATION'),
#  (36815843, 63, 30, 'สมุย', 'LOCATION'),
#  (36815843, 63, 67, 'ดอนเมือง', 'LOCATION'),
#  (36815843, 63, 112, 'หาดเฉวง', 'LOCATION'),
#  (36815843, 63, 192, 'เซ็นทรัลฯ', 'LOCATION'),
#  (36815843, 63, 270, 'หาดเฉวง', 'LOCATION'),
#  (36815843, 63, 404, 'เซ็นทรัลฯ', 'LOCATION'),
#  (36815843, 63, 454, 'บ่อผุด หาดบางรักษ์', 'LOCATION'),
#  (36815843, 63, 505, 'หาดบางรักษ์', 'LOCATION'),
#  (36815843, 63, 513, 'เฉวง', 'LOCATION'),
#  (36815843, 63, 601, 'ถนนคนเดิน', 'LOCATION'),
#  (36815843, 63, 606, 'fisherman village', 'LOCATION'),
#  (36815843, 63, 743, 'เฉวง', 'LOCATION'),
#  (36815843, 63, 751, 'วัดบ่อผุดฯ', 'LOCATION'),
#  (36815843, 63, 830, 'สมุย', 'LOCATION'),
#  (36815843, 63, 861, 'เชียงใหม่', 'LOCATION'),
#  (36815843, 63, 913, 'ไปรษณีย์เฉวง', 'LOCATION'),
#  (36815843, 63, 932, 'สมุย', 'LOCATION'),
#  (36753313, 64, 197, 'หัวหิน', 'LOCATION'),
#  (36753313, 64, 281, 'กรุงเทพฯ', 'LOCATION'),
#  (36753313, 64, 291, 'ตลาดโต้รุ่ง', 'LOCATION'),
#  (36753313, 64, 293, 'เพลินวาน', 'LOCATION'),
#  (36753313, 64, 301, 'ตลาดจักจั่น', 'LOCATION'),
#  (36753313, 64, 304, 'วังพระราชนิเวศน์ฯ', 'LOCATION'),
#  (36753313, 64, 319, 'ตลาดโต้รุ่ง', 'LOCATION'),
#  (36753313, 64, 344, 'ชะอำ', 'LOCATION'),
#  (36753313, 64, 349, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 351, 'จังหวัดเพชรบุรี', 'LOCATION'),
#  (36753313, 64, 441, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 443, 'เกาะล้าน พัทยา', 'LOCATION'),
#  (36753313, 64, 504, 'พัทยากลาง', 'LOCATION'),
#  (36753313, 64, 513, 'หาดจอมเทียน', 'LOCATION'),
#  (36753313, 64, 567, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 601, 'เกาะล้าน', 'LOCATION'),
#  (36753313, 64, 616, 'แหลมบาลีฮาย', 'LOCATION'),
#  (36753313, 64, 649, 'เกาะล้าน', 'LOCATION'),
#  (36753313, 64, 664, 'หาดตาแหวน', 'LOCATION'),
#  (36753313, 64, 694, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 697, 'เขาพระตำหนัก', 'LOCATION'),
#  (36753313, 64, 704, 'สวนนงนุช', 'LOCATION'),
#  (36753313, 64, 707, 'ตลาดน้ำ4ภาค', 'LOCATION'),
#  (36753313, 64, 711, 'ไร่องุ่น', 'LOCATION'),
#  (36753313, 64, 714, 'เขาชีจรรย์', 'LOCATION'),
#  (36753313, 64, 719, 'วิหารเซียน', 'LOCATION'),
#  (36753313, 64, 722, 'เมืองโบราณ มิโมซ่า', 'LOCATION'),
#  (36753313, 64, 738, 'ท่าเรือยอร์ช', 'LOCATION'),
#  (36753313, 64, 742, 'walking street', 'LOCATION'),
#  (36753313, 64, 767, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 780, 'บางแสน', 'LOCATION'),
#  (36753313, 64, 785, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 793, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 803, 'บางแสน', 'LOCATION'),
#  (36753313, 64, 835, 'อ่างศิลา', 'LOCATION'),
#  (36753313, 64, 838, 'ตลาดหนองมน', 'LOCATION'),
#  (36753313, 64, 843, 'สะพานปลา', 'LOCATION'),
#  (36753313, 64, 846, 'เกาะเสม็ด', 'LOCATION'),
#  (36753313, 64, 866, 'เกาะเสม็ด', 'LOCATION'),
#  (36753313, 64, 984, 'จังหวัดระยอง', 'LOCATION'),
#  (36753313, 64, 991, 'ท่าเรือบ้านเพ', 'LOCATION'),
#  (36753313, 64, 999, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 1035, 'หาดทรายขาว', 'LOCATION'),
#  (36753313, 64, 1038, 'อ่าวไผ่', 'LOCATION'),
#  (36753313, 64, 1041, 'อ่าวลุงดำ', 'LOCATION'),
#  (36753313, 64, 1045, 'อ่าวทับทิม', 'LOCATION'),
#  (36753313, 64, 1048, 'อ่าววงเดือน', 'LOCATION'),
#  (36753313, 64, 1061, 'เกาะช้าง', 'LOCATION'),
#  (36753313, 64, 1112, 'จังหวัดตราด', 'LOCATION'),
#  (36753313, 64, 1212, 'หาดคลองพร้าว', 'LOCATION'),
#  (36753313, 64, 1216, 'น้ำตกคลองพลู', 'LOCATION'),
#  (36753313, 64, 1220, 'จุดชมวิว บ้านช้างไทย', 'LOCATION'),
#  (36753313, 64, 1240, 'เกาะช้าง', 'LOCATION'),
#  (36753313, 64, 1255, 'เกาะกูด', 'LOCATION'),
#  (36753313, 64, 1277, 'เกาะกูด', 'LOCATION'),
#  (36753313, 64, 1350, 'เกาะกูด', 'LOCATION'),
#  (36753313, 64, 1406, 'จังหวัดตราด', 'LOCATION'),
#  (36753313, 64, 1410, 'ท่าเรือน้ำลึกแหลมศอก', 'LOCATION'),
#  (36753313, 64, 1482, 'เกาะกูด', 'LOCATION'),
#  (36753313, 64, 1499, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1501, 'อ่าวมาหยา', 'LOCATION'),
#  (36753313, 64, 1506, 'เกาะพีพี', 'LOCATION'),
#  (36753313, 64, 1510, 'เกาะตะปู', 'LOCATION'),
#  (36753313, 64, 1513, 'เกาะปันหยี', 'LOCATION'),
#  (36753313, 64, 1526, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1538, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1558, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1581, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1591, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1630, 'เกาะภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1635, 'หาดป่าตอง', 'LOCATION'),
#  (36753313, 64, 1638, 'หาดกะตะ', 'LOCATION'),
#  (36753313, 64, 1641, 'หาดกะรน', 'LOCATION'),
#  (36753313, 64, 1658, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1674, 'กระบี่', 'LOCATION'),
#  (36753313, 64, 1676, 'พังงา', 'LOCATION'),
#  (36753313, 64, 1678, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 1693, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1707, 'อ่าวมาหยา', 'LOCATION'),
#  (36753313, 64, 1712, 'หมู่เกาะพีพี', 'LOCATION'),
#  (36753313, 64, 1716, 'อ่าวมาหยา', 'LOCATION'),
#  (36753313, 64, 1721, 'หมู่เกาะพีพี', 'LOCATION'),
#  (36753313, 64, 1791, 'เกาะตะปู', 'LOCATION'),
#  (36753313, 64, 1794, 'ปันหยี', 'LOCATION'),
#  (36753313, 64, 1825, 'เกาะตะปู', 'LOCATION'),
#  (36753313, 64, 1891, 'จ.พังงา', 'LOCATION'),
#  (36753313, 64, 1898, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1903, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 1912, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 1914, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 1956, 'ทะเลแหวก', 'LOCATION'),
#  (36753313, 64, 1959, 'อ่าวพระนาง', 'LOCATION'),
#  (36753313, 64, 1962, 'อ่าวไร่เลย์', 'LOCATION'),
#  (36753313, 64, 1967, 'เกาะปอดะ', 'LOCATION'),
#  (36753313, 64, 1972, 'จังหวัดกระบี่', 'LOCATION'),
#  (36753313, 64, 2003, 'ประเทศไทย', 'LOCATION'),
#  (36753313, 64, 2016, 'อ่าวนาง', 'LOCATION'),
#  (36753313, 64, 2021, 'อ่าวพระนาง', 'LOCATION'),
#  (36753313, 64, 2036, 'อ่าวนาง', 'LOCATION'),
#  (36753313, 64, 2042, 'เมืองกระบี่', 'LOCATION'),
#  (36753313, 64, 2072, 'ป่าตอง', 'LOCATION'),
#  (36753313, 64, 2114, 'ทะเลแหวก', 'LOCATION'),
#  (36753313, 64, 2117, 'อ่าวไรเลย์', 'LOCATION'),
#  (36753313, 64, 2127, 'จังหวัดกระบี่', 'LOCATION'),
#  (36753313, 64, 2169, 'สระมรกต', 'LOCATION'),
#  (36753313, 64, 2172, 'เกาะรอก', 'LOCATION'),
#  (36753313, 64, 2954, 'สิเกา', 'LOCATION'),
#  (36753313, 64, 2960, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 2997, 'สิเกา', 'LOCATION'),
#  (36753313, 64, 3001, 'ปากเมง', 'LOCATION'),
#  (36753313, 64, 3013, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 3018, 'ถ้ำมรกต', 'LOCATION'),
#  (36753313, 64, 3118, 'ถ้ำมรกต', 'LOCATION'),
#  (36753313, 64, 3121, 'ปากเมง', 'LOCATION'),
#  (36753313, 64, 3125, 'สิเกา', 'LOCATION'),
#  (36753313, 64, 3128, 'เมืองตรัง', 'LOCATION'),
#  (36753313, 64, 3136, 'ถ้ำเขากอบ', 'LOCATION'),
#  (36753313, 64, 3150, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 3153, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 3165, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 3168, 'เมืองตรัง', 'LOCATION'),
#  (36753313, 64, 3171, 'สิเกา', 'LOCATION'),
#  (36753313, 64, 3174, 'ปากเมง', 'LOCATION'),
#  (36753313, 64, 3195, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3199, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3201, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3205, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3252, 'ทะเลแหวก', 'LOCATION'),
#  (36753313, 64, 3270, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3290, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3294, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3365, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 3367, 'สุราษฏร์ธานี', 'LOCATION'),
#  (36753313, 64, 3370, 'กรุงเทพ', 'LOCATION'),
#  (36753313, 64, 3371, 'ชุมพร', 'LOCATION'),
#  (36753313, 64, 3381, 'ท่าเรือลมพระยา', 'LOCATION'),
#  (36753313, 64, 3403, 'ท่าเรือลมพระยา', 'LOCATION'),
#  (36753313, 64, 3414, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3416, 'นางยวน', 'LOCATION'),
#  (36753313, 64, 3433, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3445, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3490, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3492, 'หมู่เกาะอ่างทอง', 'LOCATION'),
#  (36753313, 64, 3495, 'เกาะพะงัน', 'LOCATION'),
#  (36753313, 64, 3514, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3533, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3547, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3561, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3569, 'หมู่เกาะอ่างทอง', 'LOCATION'),
#  (36753313, 64, 3598, 'เกาะสมุย', 'LOCATION'),
#  (36753313, 64, 3603, 'เกาะพงัน', 'LOCATION'),
#  (36753313, 64, 3625, 'เกาะพะงัน', 'LOCATION'),
#  (36753313, 64, 3666, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3670, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3683, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3707, 'หมู่เกาะอ่างทอง', 'LOCATION'),
#  (36753313, 64, 3725, 'หัวหิน', 'LOCATION'),
#  (36753313, 64, 3728, 'ชะอำ', 'LOCATION'),
#  (36753313, 64, 3731, 'พัทยา', 'LOCATION'),
#  (36753313, 64, 3733, 'เกาะล้าน', 'LOCATION'),
#  (36753313, 64, 3736, 'บางแสน', 'LOCATION'),
#  (36753313, 64, 3766, 'เกาะช้าง', 'LOCATION'),
#  (36753313, 64, 3769, 'เกาะกูด', 'LOCATION'),
#  (36753313, 64, 3772, 'เกาะเต่า', 'LOCATION'),
#  (36753313, 64, 3775, 'เกาะนางยวน', 'LOCATION'),
#  (36753313, 64, 3779, 'สมุย', 'LOCATION'),
#  (36753313, 64, 3781, 'เกาะพงัน', 'LOCATION'),
#  (36753313, 64, 3785, 'อ่างทอง', 'LOCATION'),
#  (36753313, 64, 3787, 'จังหวัดตราด', 'LOCATION'),
#  (36753313, 64, 3790, 'ระยอง', 'LOCATION'),
#  (36753313, 64, 3818, 'เกาะพีพี', 'LOCATION'),
#  (36753313, 64, 3822, 'สิมิลัน', 'LOCATION'),
#  (36753313, 64, 3824, 'ตาชัย', 'LOCATION'),
#  (36753313, 64, 3827, 'สุรินทร์', 'LOCATION'),
#  (36753313, 64, 3829, 'ตะปู', 'LOCATION'),
#  (36753313, 64, 3834, 'หลีเป๊ะ', 'LOCATION'),
#  (36753313, 64, 3837, 'สิเกา', 'LOCATION'),
#  (36753313, 64, 3840, 'ทะเลแหวก', 'LOCATION'),
#  (36753313, 64, 3843, 'ไร่เลย์', 'LOCATION'),
#  (36753313, 64, 3847, 'กระบี่', 'LOCATION'),
#  (36753313, 64, 3849, 'พังงา', 'LOCATION'),
#  (36753313, 64, 3851, 'ภูเก็ต', 'LOCATION'),
#  (36753313, 64, 3853, 'ตรัง', 'LOCATION'),
#  (36753313, 64, 3855, 'สตูล', 'LOCATION'),
#  (36753313, 64, 4003, 'เยอรมัน', 'LOCATION'),
#  (36753313, 64, 4005, 'Frankfurt', 'LOCATION'),
#  (36753313, 64, 4007, 'Cologne', 'LOCATION'),
#  (36753313, 64, 4009, 'Dusseldorf', 'LOCATION'),
#  (36753313, 64, 4031, 'เนเธอแลนด์', 'LOCATION'),
#  (36753313, 64, 4032, 'Saans Schans', 'LOCATION'),
#  (36753313, 64, 4036, 'Amsterdam', 'LOCATION'),
#  (36753313, 64, 4058, 'เบลเยี่ยม', 'LOCATION'),
#  (36753313, 64, 4060, 'Antwerp', 'LOCATION'),
#  ...]

# %%
# len(loc_list)

# %%
loc_df = pd.DataFrame(loc_list, columns=["Thread_id", "Thread_index", "Index", "Word", "Label"])
loc_df
# Out:
#       Thread_id  Thread_index  Index                            Word     Label
# 0      37357879             1     99  ทับสะแก จังหวัดประจวบคีรีขันธ์  LOCATION
# 1      37357879             1    129             ฟิวเจอร์พาร์ครังสิต  LOCATION
# 2      37357879             1    138                            ชะอำ  LOCATION
# 3      37357879             1    142                       อ่าวมะนาว  LOCATION
# 4      37357879             1    993                        เมืองไทย  LOCATION
# ...         ...           ...    ...                             ...       ...
# 7616   38190914           305    431                    เขื่อนบางพระ  LOCATION
# 7617   38190914           305    439                   จังหวัดชลบุรี  LOCATION
# 7618   38190914           305    465                          J-Park  LOCATION
# 7619   38190914           305    511                    อำเภอศรีราชา  LOCATION
# 7620   38190914           305    685                         ศรีราชา  LOCATION
#
# [7621 rows x 5 columns]

# %%
# loc_df.to_csv('305_loc_actual.csv', index=False)

# %% [markdown]
# ### Features Creating & Training Model

# %%
tt=[]
with open(file_name+"-pos.conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[1]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

with open(file_name+".conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

# %%
def doc2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
#     dic_check = True if word in dictionary else False
#     loc_check = True if word in loc_place else False
#     river_check = True if word in river else False
#     road_check = True if word in road else False
#     subDis01_check = True if word in sub_dis01 else False
#     subDis02_check = True if word in sub_dis02 else False
#     district_check = True if word in district else False
#     province_check = True if word in province else False
    
    # Features from current word
    features={
        'word.word': word,
        'word.isspace':word.isspace(),
        'postag':postag,
        'word.isdigit()': word.isdigit(),
#         'dic_check': dic_check,
#         'loc_check': loc_check,
#         'river_check': river_check,
#         'road_check': road_check,
#         'subDis01_check': subDis01_check,
#         'subDis02_check': subDis02_check, 
#         'district_check': district_check,
#         'province_check': province_check
    }
    # Features from previous word
    if i > 0:
        prevword = doc[i-1][0]
        postag1 = doc[i-1][1]
#         prev_dic_check = True if prevword in dictionary else False
#         prev_loc_check = True if prevword in loc_place else False
#         prev_river_check = True if prevword in river else False
#         prev_road_check = True if prevword in road else False
#         prev_subDis01_check = True if prevword in sub_dis01 else False
#         prev_subDis02_check = True if prevword in sub_dis02 else False
#         prev_district_check = True if prevword in district else False
#         prev_province_check = True if prevword in province else False
        
        features['word.prevword'] = prevword
        features['word.previsspace']= prevword.isspace()
        features['word.prepostag'] = postag1
        features['word.prevwordisdigit'] = prevword.isdigit()
#         features['word.prev_dic_check'] = prev_dic_check
#         features['word.prev_loc_check'] = prev_loc_check
#         features['word.prev_river_check'] = prev_river_check
#         features['word.prev_road_check'] = prev_road_check
#         features['word.prev_subDis01_check'] = prev_subDis01_check
#         features['word.prev_subDis02_check'] = prev_subDis02_check
#         features['word.prev_district_check'] = prev_district_check
#         features['word.prev_province_check'] = prev_province_check
        
    else:
        features['BOS'] = True # Special "Beginning of Sequence" tag
    # Features from next word
    if i < len(doc)-1:
        nextword = doc[i+1][0]
        postag1 = doc[i+1][1]
#         next_dic_check = True if nextword in dictionary else False
#         next_loc_check = True if nextword in loc_place else False
#         next_river_check = True if nextword in river else False
#         next_road_check = True if nextword in road else False
#         next_subDis01_check = True if nextword in sub_dis01 else False
#         next_subDis02_check = True if nextword in sub_dis02 else False
#         next_district_check = True if nextword in district else False
#         next_province_check = True if nextword in province else False
        
        features['word.nextword'] = nextword
        features['word.nextisspace']=nextword.isspace()
        features['word.nextpostag'] = postag1
        features['word.nextwordisdigit'] = nextword.isdigit()
#         features['word.next_dic_check'] = next_dic_check
#         features['word.next_loc_check'] = next_loc_check
#         features['word.next_river_check'] = next_river_check
#         features['word.next_road_check'] = next_road_check
#         features['word.next_subDis01_check'] = next_subDis01_check
#         features['word.next_subDis02_check'] = next_subDis02_check
#         features['word.next_district_check'] = next_district_check
#         features['word.next_province_check'] = next_province_check
    else:
        features['EOS'] = True # Special "End of Sequence" tag
    return features

def extract_features(doc):
    return [doc2features(doc, i) for i in range(len(doc))]

def get_labels(doc):
    return [tag for (token,postag,tag) in doc]

# %%
X_data = [extract_features(doc) for doc in datatofile] # เอา คำ แยกออกมา
y_data = [get_labels(doc) for doc in datatofile] # เอา tag แยกออกมา

# %%
X, X_test, y, y_test = train_test_split(X_data, y_data, test_size=0.1)

# %%
# crf = sklearn_crfsuite.CRF(
#     algorithm='lbfgs',
#     c1=0.1,
#     c2=0.1,
#     max_iterations=500,
#     all_possible_transitions=True,
#     model_filename=file_name+"-pos.model0" # ตั้งชื่อโมเดล
# )
# crf.fit(X, y); # train

# %% [markdown]
# # Loading Model

# %%
model_path = '/Users/j.kanlaya/Downloads/Mike/data_collection/05_merge_tag/305model+dict/AllModels_dict/00/'
model_name = '305_dict.sav'
crf = pickle.load(open(model_path + model_name, 'rb'))

# %%
labels = list(crf.classes_)
# labels.remove('O')
# labels.remove('B-HOTEL')
# labels.remove('I-HOTEL')
# labels.remove('B-RESTAURANT')
# labels.remove('I-RESTAURANT')

# %%
y_pred = crf.predict(X_test)

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)

# %% [markdown]
# # No K-Fold

# %%
print(metrics.flat_classification_report(y_test, y_pred, labels=sorted_labels, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            O      0.997     0.997     0.997     41207
#      B-HOTEL      0.982     0.982     0.982        56
#      I-HOTEL      0.988     0.997     0.993       333
#   B-LOCATION      0.937     0.895     0.915       742
#   I-LOCATION      0.923     0.942     0.932      1301
# B-RESTAURANT      0.988     0.943     0.965        88
# I-RESTAURANT      0.988     0.959     0.974       345
#
#     accuracy                          0.993     44072
#    macro avg      0.972     0.959     0.965     44072
# weighted avg      0.993     0.993     0.993     44072

# %% [markdown]
# # 10-Fold

# %%
fold_pred = cross_val_predict(crf, X, y, cv=10)

# %%
print(metrics.flat_classification_report(y, fold_pred, labels=sorted_labels, digits=3))

# %%
fold_pred = cross_val_predict(crf, X, y, cv=10)

# %%
print(metrics.flat_classification_report(y, fold_pred, labels=sorted_labels, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#   B-LOCATION      0.821     0.624     0.709      6970
#   I-LOCATION      0.825     0.663     0.736     12243
#
#    micro avg      0.824     0.649     0.726     19213
#    macro avg      0.823     0.644     0.722     19213
# weighted avg      0.824     0.649     0.726     19213

# %% [markdown]
# # Save Model

# %%
# model_name = '305_dict.sav'
# pickle.dump(crf, open(model_name, 'wb') )
