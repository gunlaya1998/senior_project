# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('DB_Ranking_Province.csv')
df
# Out:
#     provinceId     provinceTh              provinceEn  \
# 0            1  กรุงเทพมหานคร  Krung Thep Maha Nakhon
# 1            2         กระบี่                   Krabi
# 2            3      กาญจนบุรี            Kanchanaburi
# 3            4      กาฬสินธุ์                 Kalasin
# 4            5      กำแพงเพชร          Kamphaeng Phet
# ..         ...            ...                     ...
# 72          73     อำนาจเจริญ           Amnat Charoen
# 73          74       อุดรธานี              Udon Thani
# 74          75      อุตรดิตถ์               Uttaradit
# 75          76      อุทัยธานี             Uthai Thani
# 76          77    อุบลราชธานี        Ubon Ratchathani
#
#                                        provinceDescTh
# 0   กรุงเทพฯ ดุจเทพสร้าง เมืองศูนย์กลางการปกครอง ว...
# 1   ถิ่นหอยเก่า เขาตระหง่าน ธารสวย รวยเกาะ เพาะปลู...
# 2   แคว้นโบราณ ด่านเจดีย์ มณีเมืองกาญจน์ สะพานข้าม...
# 3   เมืองฟ้าแดดสงยาง โปงลางเลิศล้ำ วัฒนธรรมผู้ไทย ...
# ...

# %%
df.iloc[0]
# Out:
# provinceId                                                        1
# provinceTh                                            กรุงเทพมหานคร
# provinceEn                                   Krung Thep Maha Nakhon
# provinceDescTh    กรุงเทพฯ ดุจเทพสร้าง เมืองศูนย์กลางการปกครอง ว...
# Name: 0, dtype: object

# %%
pl = []
for i in range(len(df)):
    tmp = {}
    tmp['id'] = df.iloc[i]['provinceId']
    tmp['provinceName'] = df.iloc[i]['provinceTh']    
    
    pl.append(tmp)
pl
# Out:
# [{'id': 1, 'provinceName': 'กรุงเทพมหานคร'},
#  {'id': 2, 'provinceName': 'กระบี่'},
#  {'id': 3, 'provinceName': 'กาญจนบุรี'},
#  {'id': 4, 'provinceName': 'กาฬสินธุ์'},
#  {'id': 5, 'provinceName': 'กำแพงเพชร'},
#  {'id': 6, 'provinceName': 'ขอนแก่น'},
#  {'id': 7, 'provinceName': 'จันทบุรี'},
#  {'id': 8, 'provinceName': 'ฉะเชิงเทรา'},
#  {'id': 9, 'provinceName': 'ชลบุรี'},
#  {'id': 10, 'provinceName': 'ชัยนาท'},
#  {'id': 11, 'provinceName': 'ชัยภูมิ'},
#  {'id': 12, 'provinceName': 'ชุมพร'},
#  {'id': 13, 'provinceName': 'เชียงราย'},
#  {'id': 14, 'provinceName': 'เชียงใหม่'},
#  {'id': 15, 'provinceName': 'ตรัง'},
#  {'id': 16, 'provinceName': 'ตราด'},
#  {'id': 17, 'provinceName': 'ตาก'},
#  {'id': 18, 'provinceName': 'นครนายก'},
#  {'id': 19, 'provinceName': 'นครปฐม'},
#  {'id': 20, 'provinceName': 'นครพนม'},
#  {'id': 21, 'provinceName': 'นครราชสีมา'},
#  {'id': 22, 'provinceName': 'นครศรีธรรมราช'},
#  {'id': 23, 'provinceName': 'นครสวรรค์'},
# ...
